# %% [markdown]
# ### Build more performance model

# %%
# library
import numpy as np
import pandas as pd
import os
import re
import random
import string
from IPython.display import display

# Token trasformation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# setting config file to upload file path
from config import file_txt

with open(file_txt, 'r') as file:
   text = file.read()

# %%
# Removes formatting and multiple spaces
def text_form(text):
   txt_clean = re.sub(r'\s+', ' ', text)
   txt_words = re.findall(r'\b\w+\b', txt_clean)
   return txt_words

txt_words = text_form(text)
print(f'Number of words:',len(txt_words))
# Out:
# Number of words: 69690

# %%
# rows in line
def read_txt(file_txt):
   txt = []
   with open (file_txt) as f:
      for line in f:
         line = line.strip()
         if line != '': txt.append(line)
   return txt

rows_list = read_txt(file_txt)
print('Number of lines: ', len(rows_list))
# Out:
# Number of lines:  5941

# %%
# removing special characters and transform words in token
def clean_txt(txt):
   cleaned_text = []
   for line in txt:
      line = line.lower()
      line = re.sub(r"['!@#$%^&*(){}?/`~<>+=-\\]", "", line)
      tokens = word_tokenize(line, language="english", preserve_line=True)
      words = [word for word in tokens if word.isalpha()]
      cleaned_text+= words
   return cleaned_text

cleaned_txt = clean_txt(rows_list)
print(f'number of tokenized words:',len(cleaned_txt))
# Out:
# number of tokenized words: 67384

# %%
display(cleaned_txt[:30])
# Out:
# ['chapter',
#  'i',
#  'am',
#  'by',
#  'birth',
#  'a',
#  'genevese',
#  'and',
#  'my',
#  'family',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'distinguished',
#  'of',
#  'that',
#  'my',
#  'ancestors',
#  'had',
#  'been',
#  'for',
#  'many',
#  'years',
#  'counsellors',
#  'and',
#  'syndics',
#  'and',
#  'my']

# %%
def MC_model4(cleaned_txt, n_gram=4):
    markov_model = {}
    for i in range(len(cleaned_txt)-n_gram):
        curr_state, next_state = "", ""
        for j in range(n_gram):
            curr_state += cleaned_txt[i+j] + " "
            next_state += cleaned_txt[i+j+1] + " "  # Fixing index for next_state
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if curr_state not in markov_model:
            markov_model[curr_state] = {}
            markov_model[curr_state][next_state] = 1
        else:
            if next_state in markov_model[curr_state]:
                markov_model[curr_state][next_state] += 1
            else:
                markov_model[curr_state][next_state] = 1
    
    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count/total
        
    return markov_model

# %%
# testing model1 by uploading ours tokenized words list 
MC4 = MC_model4(cleaned_txt)
print(f'Number of states:',len(MC4))
# Out:
# Number of states: 66230

# %%
display(MC4)
# Out:
# {'chapter i am by': {'i am by birth': 1.0},
#  'i am by birth': {'am by birth a': 1.0},
#  'am by birth a': {'by birth a genevese': 1.0},
#  'by birth a genevese': {'birth a genevese and': 1.0},
#  'birth a genevese and': {'a genevese and my': 1.0},
#  'a genevese and my': {'genevese and my family': 1.0},
#  'genevese and my family': {'and my family is': 1.0},
#  'and my family is': {'my family is one': 1.0},
#  'my family is one': {'family is one of': 1.0},
#  'family is one of': {'is one of the': 1.0},
#  'is one of the': {'one of the most': 1.0},
#  'one of the most': {'of the most distinguished': 1.0},
#  'of the most distinguished': {'the most distinguished of': 0.5,
#   'the most distinguished he': 0.5},
#  'the most distinguished of': {'most distinguished of that': 1.0},
#  'most distinguished of that': {'distinguished of that my': 1.0},
#  'distinguished of that my': {'of that my ancestors': 1.0},
#  'of that my ancestors': {'that my ancestors had': 1.0},
#  'that my ancestors had': {'my ancestors had been': 1.0},
#  'my ancestors had been': {'ancestors had been for': 1.0},
#  'ancestors had been for': {'had been for many': 1.0},
#  'had been for many': {'been for many years': 1.0},
#  'been for many years': {'for many years counsellors': 1.0},
#  'for many years counsellors': {'many years counsellors and': 1.0},
#  'many years counsellors and': {'years counsellors and syndics': 1.0},
#  'years counsellors and syndics': {'counsellors and syndics and': 1.0},
#  'counsellors and syndics and': {'and syndics and my': 1.0},
#  'and syndics and my': {'syndics and my father': 1.0},
#  'syndics and my father': {'and my father had': 1.0},
#  'and my father had': {'my father had filled': 1.0},
#  'my father had filled': {'father had filled several': 1.0},
#  'father had filled several': {'had filled several public': 1.0},
#  'had filled several public': {'filled several public situations': 1.0},
#  'filled several public situations': {'several public situations with': 1.0},
#  'several public situations with': {'public situations with honour': 1.0},
#  'public situations with honour': {'situations with honour and': 1.0},
#  'situations with honour and': {'with honour and he': 1.0},
#  'with honour and he': {'honour and he was': 1.0},
#  'honour and he was': {'and he was respected': 1.0},
#  'and he was respected': {'he was respected by': 1.0},
#  'he was respected by': {'was respected by all': 1.0},
#  'was respected by all': {'respected by all who': 1.0},
#  'respected by all who': {'by all who knew': 1.0},
#  'by all who knew': {'all who knew him': 1.0},
#  'all who knew him': {'who knew him for': 1.0},
#  'who knew him for': {'knew him for his': 1.0},
#  'knew him for his': {'him for his integrity': 1.0},
#  'him for his integrity': {'for his integrity and': 1.0},
#  'for his integrity and': {'his integrity and indefatigable': 1.0},
#  'his integrity and indefatigable': {'integrity and indefatigable attention': 1.0},
#  'integrity and indefatigable attention': {'and indefatigable attention to': 1.0},
#  'and indefatigable attention to': {'indefatigable attention to public': 1.0},
#  'indefatigable attention to public': {'attention to public he': 1.0},
#  'attention to public he': {'to public he passed': 1.0},
#  'to public he passed': {'public he passed his': 1.0},
#  'public he passed his': {'he passed his younger': 1.0},
#  'he passed his younger': {'passed his younger days': 1.0},
#  'passed his younger days': {'his younger days perpetually': 1.0},
#  'his younger days perpetually': {'younger days perpetually occupied': 1.0},
#  'younger days perpetually occupied': {'days perpetually occupied by': 1.0},
#  'days perpetually occupied by': {'perpetually occupied by the': 1.0},
#  'perpetually occupied by the': {'occupied by the affairs': 1.0},
#  'occupied by the affairs': {'by the affairs of': 1.0},
#  'by the affairs of': {'the affairs of his': 1.0},
#  'the affairs of his': {'affairs of his country': 1.0},
#  'affairs of his country': {'of his country a': 1.0},
#  'of his country a': {'his country a variety': 1.0},
#  'his country a variety': {'country a variety of': 1.0},
#  'country a variety of': {'a variety of circumstances': 1.0},
#  'a variety of circumstances': {'variety of circumstances had': 1.0},
#  'variety of circumstances had': {'of circumstances had prevented': 1.0},
#  'of circumstances had prevented': {'circumstances had prevented his': 1.0},
#  'circumstances had prevented his': {'had prevented his marrying': 1.0},
#  'had prevented his marrying': {'prevented his marrying early': 1.0},
#  'prevented his marrying early': {'his marrying early nor': 1.0},
#  'his marrying early nor': {'marrying early nor was': 1.0},
#  'marrying early nor was': {'early nor was it': 1.0},
#  'early nor was it': {'nor was it until': 1.0},
#  'nor was it until': {'was it until the': 1.0},
#  'was it until the': {'it until the decline': 1.0},
#  'it until the decline': {'until the decline of': 1.0},
#  'until the decline of': {'the decline of life': 1.0},
#  'the decline of life': {'decline of life that': 0.5,
#   'decline of life having': 0.5},
#  'decline of life that': {'of life that he': 1.0},
#  'of life that he': {'life that he became': 1.0},
#  'life that he became': {'that he became a': 1.0},
#  'that he became a': {'he became a husband': 1.0},
#  'he became a husband': {'became a husband and': 1.0},
#  'became a husband and': {'a husband and the': 1.0},
#  'a husband and the': {'husband and the father': 1.0},
#  'husband and the father': {'and the father of': 1.0},
#  'and the father of': {'the father of a': 1.0},
#  'the father of a': {'father of a family': 1.0},
#  'father of a family': {'of a family as': 1.0},
#  'of a family as': {'a family as the': 1.0},
#  'a family as the': {'family as the circumstances': 1.0},
#  'family as the circumstances': {'as the circumstances of': 1.0},
#  'as the circumstances of': {'the circumstances of his': 1.0},
#  'the circumstances of his': {'circumstances of his marriage': 1.0},
#  'circumstances of his marriage': {'of his marriage illustrate': 1.0},
#  'of his marriage illustrate': {'his marriage illustrate his': 1.0},
#  'his marriage illustrate his': {'marriage illustrate his character': 1.0},
#  'marriage illustrate his character': {'illustrate his character i': 1.0},
#  'illustrate his character i': {'his character i can': 1.0},
#  'his character i can': {'character i can not': 1.0},
#  'character i can not': {'i can not refrain': 1.0},
#  'i can not refrain': {'can not refrain from': 1.0},
#  'can not refrain from': {'not refrain from relating': 1.0},
#  'not refrain from relating': {'refrain from relating one': 1.0},
#  'refrain from relating one': {'from relating one of': 1.0},
#  'from relating one of': {'relating one of his': 1.0},
#  'relating one of his': {'one of his most': 1.0},
#  'one of his most': {'of his most intimate': 1.0},
#  'of his most intimate': {'his most intimate friends': 1.0},
#  'his most intimate friends': {'most intimate friends was': 1.0},
#  'most intimate friends was': {'intimate friends was a': 1.0},
#  'intimate friends was a': {'friends was a merchant': 1.0},
#  'friends was a merchant': {'was a merchant who': 1.0},
#  'was a merchant who': {'a merchant who from': 1.0},
#  'a merchant who from': {'merchant who from a': 1.0},
#  'merchant who from a': {'who from a flourishing': 1.0},
#  'who from a flourishing': {'from a flourishing state': 1.0},
#  'from a flourishing state': {'a flourishing state fell': 1.0},
#  'a flourishing state fell': {'flourishing state fell through': 1.0},
#  'flourishing state fell through': {'state fell through numerous': 1.0},
#  'state fell through numerous': {'fell through numerous mischances': 1.0},
#  'fell through numerous mischances': {'through numerous mischances into': 1.0},
#  'through numerous mischances into': {'numerous mischances into this': 1.0},
#  'numerous mischances into this': {'mischances into this man': 1.0},
#  'mischances into this man': {'into this man whose': 1.0},
#  'into this man whose': {'this man whose name': 1.0},
#  'this man whose name': {'man whose name was': 1.0},
#  'man whose name was': {'whose name was beaufort': 1.0},
#  'whose name was beaufort': {'name was beaufort was': 1.0},
#  'name was beaufort was': {'was beaufort was of': 1.0},
#  'was beaufort was of': {'beaufort was of a': 1.0},
#  'beaufort was of a': {'was of a proud': 1.0},
#  'was of a proud': {'of a proud and': 1.0},
#  'of a proud and': {'a proud and unbending': 1.0},
#  'a proud and unbending': {'proud and unbending disposition': 1.0},
#  'proud and unbending disposition': {'and unbending disposition and': 1.0},
#  'and unbending disposition and': {'unbending disposition and could': 1.0},
#  'unbending disposition and could': {'disposition and could not': 1.0},
#  'disposition and could not': {'and could not bear': 1.0},
#  'and could not bear': {'could not bear to': 1.0},
#  'could not bear to': {'not bear to live': 1.0},
#  'not bear to live': {'bear to live in': 1.0},
#  'bear to live in': {'to live in poverty': 1.0},
#  'to live in poverty': {'live in poverty and': 1.0},
#  'live in poverty and': {'in poverty and oblivion': 1.0},
#  'in poverty and oblivion': {'poverty and oblivion in': 1.0},
#  'poverty and oblivion in': {'and oblivion in the': 1.0},
#  'and oblivion in the': {'oblivion in the same': 1.0},
#  'oblivion in the same': {'in the same country': 1.0},
#  'in the same country': {'the same country where': 1.0},
#  'the same country where': {'same country where he': 1.0},
#  'same country where he': {'country where he had': 1.0},
#  'country where he had': {'where he had formerly': 1.0},
#  'where he had formerly': {'he had formerly been': 1.0},
#  'he had formerly been': {'had formerly been distinguished': 1.0},
#  'had formerly been distinguished': {'formerly been distinguished for': 1.0},
#  'formerly been distinguished for': {'been distinguished for his': 1.0},
#  'been distinguished for his': {'distinguished for his rank': 1.0},
#  'distinguished for his rank': {'for his rank and': 1.0},
#  'for his rank and': {'his rank and having': 1.0},
#  'his rank and having': {'rank and having paid': 1.0},
#  'rank and having paid': {'and having paid his': 1.0},
#  'and having paid his': {'having paid his debts': 1.0},
#  'having paid his debts': {'paid his debts therefore': 1.0},
#  'paid his debts therefore': {'his debts therefore in': 1.0},
#  'his debts therefore in': {'debts therefore in the': 1.0},
#  'debts therefore in the': {'therefore in the most': 1.0},
#  'therefore in the most': {'in the most honourable': 0.5,
#   'in the most cordial': 0.5},
#  'in the most honourable': {'the most honourable manner': 1.0},
#  'the most honourable manner': {'most honourable manner he': 1.0},
#  'most honourable manner he': {'honourable manner he retreated': 1.0},
#  'honourable manner he retreated': {'manner he retreated with': 1.0},
#  'manner he retreated with': {'he retreated with his': 1.0},
#  'he retreated with his': {'retreated with his daughter': 1.0},
#  'retreated with his daughter': {'with his daughter to': 1.0},
#  'with his daughter to': {'his daughter to the': 1.0},
#  'his daughter to the': {'daughter to the town': 1.0},
#  'daughter to the town': {'to the town of': 1.0},
#  'to the town of': {'the town of lucerne': 1.0},
#  'the town of lucerne': {'town of lucerne where': 1.0},
#  'town of lucerne where': {'of lucerne where he': 1.0},
#  'of lucerne where he': {'lucerne where he lived': 1.0},
#  'lucerne where he lived': {'where he lived unknown': 1.0},
#  'where he lived unknown': {'he lived unknown and': 1.0},
#  'he lived unknown and': {'lived unknown and in': 1.0},
#  'lived unknown and in': {'unknown and in my': 1.0},
#  'unknown and in my': {'and in my father': 1.0},
#  'and in my father': {'in my father loved': 1.0},
#  'in my father loved': {'my father loved beaufort': 1.0},
#  'my father loved beaufort': {'father loved beaufort with': 1.0},
#  'father loved beaufort with': {'loved beaufort with the': 1.0},
#  'loved beaufort with the': {'beaufort with the truest': 1.0},
#  'beaufort with the truest': {'with the truest friendship': 1.0},
#  'with the truest friendship': {'the truest friendship and': 1.0},
#  'the truest friendship and': {'truest friendship and was': 1.0},
#  'truest friendship and was': {'friendship and was deeply': 1.0},
#  'friendship and was deeply': {'and was deeply grieved': 1.0},
#  'and was deeply grieved': {'was deeply grieved by': 1.0},
#  'was deeply grieved by': {'deeply grieved by his': 1.0},
#  'deeply grieved by his': {'grieved by his retreat': 1.0},
#  'grieved by his retreat': {'by his retreat in': 1.0},
#  'by his retreat in': {'his retreat in these': 1.0},
#  'his retreat in these': {'retreat in these unfortunate': 1.0},
#  'retreat in these unfortunate': {'in these unfortunate circumstances': 1.0},
#  'in these unfortunate circumstances': {'these unfortunate circumstances he': 1.0},
#  'these unfortunate circumstances he': {'unfortunate circumstances he bitterly': 1.0},
#  'unfortunate circumstances he bitterly': {'circumstances he bitterly deplored': 1.0},
#  'circumstances he bitterly deplored': {'he bitterly deplored the': 1.0},
#  'he bitterly deplored the': {'bitterly deplored the false': 1.0},
#  'bitterly deplored the false': {'deplored the false pride': 1.0},
#  'deplored the false pride': {'the false pride which': 1.0},
#  'the false pride which': {'false pride which led': 1.0},
#  'false pride which led': {'pride which led his': 1.0},
#  'pride which led his': {'which led his friend': 1.0},
#  'which led his friend': {'led his friend to': 1.0},
#  'led his friend to': {'his friend to a': 1.0},
#  'his friend to a': {'friend to a conduct': 1.0},
#  'friend to a conduct': {'to a conduct so': 1.0},
#  'to a conduct so': {'a conduct so little': 1.0},
#  'a conduct so little': {'conduct so little worthy': 1.0},
#  'conduct so little worthy': {'so little worthy of': 1.0},
#  'so little worthy of': {'little worthy of the': 1.0},
#  'little worthy of the': {'worthy of the affection': 1.0},
#  'worthy of the affection': {'of the affection that': 1.0},
#  'of the affection that': {'the affection that united': 1.0},
#  'the affection that united': {'affection that united he': 1.0},
#  'affection that united he': {'that united he lost': 1.0},
#  'that united he lost': {'united he lost no': 1.0},
#  'united he lost no': {'he lost no time': 1.0},
#  'he lost no time': {'lost no time in': 1.0},
#  'lost no time in': {'no time in endeavouring': 1.0},
#  'no time in endeavouring': {'time in endeavouring to': 1.0},
#  'time in endeavouring to': {'in endeavouring to seek': 1.0},
#  'in endeavouring to seek': {'endeavouring to seek him': 1.0},
#  'endeavouring to seek him': {'to seek him out': 1.0},
#  'to seek him out': {'seek him out with': 1.0},
#  'seek him out with': {'him out with the': 1.0},
#  'him out with the': {'out with the hope': 1.0},
#  'out with the hope': {'with the hope of': 1.0},
#  'with the hope of': {'the hope of persuading': 1.0},
#  'the hope of persuading': {'hope of persuading him': 1.0},
#  'hope of persuading him': {'of persuading him to': 1.0},
#  'of persuading him to': {'persuading him to begin': 1.0},
#  'persuading him to begin': {'him to begin the': 1.0},
#  'him to begin the': {'to begin the world': 1.0},
#  'to begin the world': {'begin the world again': 1.0},
#  'begin the world again': {'the world again through': 1.0},
#  'the world again through': {'world again through his': 1.0},
#  'world again through his': {'again through his credit': 1.0},
#  'again through his credit': {'through his credit and': 1.0},
#  'through his credit and': {'his credit and beaufort': 1.0},
#  'his credit and beaufort': {'credit and beaufort had': 1.0},
#  'credit and beaufort had': {'and beaufort had taken': 1.0},
#  'and beaufort had taken': {'beaufort had taken effectual': 1.0},
#  'beaufort had taken effectual': {'had taken effectual measures': 1.0},
#  'had taken effectual measures': {'taken effectual measures to': 1.0},
#  'taken effectual measures to': {'effectual measures to conceal': 1.0},
#  'effectual measures to conceal': {'measures to conceal himself': 1.0},
#  'measures to conceal himself': {'to conceal himself and': 1.0},
#  'to conceal himself and': {'conceal himself and it': 1.0},
#  'conceal himself and it': {'himself and it was': 1.0},
#  'himself and it was': {'and it was ten': 1.0},
#  'and it was ten': {'it was ten months': 1.0},
#  'it was ten months': {'was ten months before': 1.0},
#  'was ten months before': {'ten months before my': 1.0},
#  'ten months before my': {'months before my father': 1.0},
#  'months before my father': {'before my father discovered': 1.0},
#  'before my father discovered': {'my father discovered his': 1.0},
#  'my father discovered his': {'father discovered his overjoyed': 1.0},
#  'father discovered his overjoyed': {'discovered his overjoyed at': 1.0},
#  'discovered his overjoyed at': {'his overjoyed at this': 1.0},
#  'his overjoyed at this': {'overjoyed at this discovery': 1.0},
#  'overjoyed at this discovery': {'at this discovery he': 1.0},
#  'at this discovery he': {'this discovery he hastened': 1.0},
#  'this discovery he hastened': {'discovery he hastened to': 1.0},
#  'discovery he hastened to': {'he hastened to the': 1.0},
#  'he hastened to the': {'hastened to the house': 1.0},
#  'hastened to the house': {'to the house which': 1.0},
#  'to the house which': {'the house which was': 0.5, 'the house which i': 0.5},
#  'the house which was': {'house which was situated': 1.0},
#  'house which was situated': {'which was situated in': 1.0},
#  'which was situated in': {'was situated in a': 1.0},
#  'was situated in a': {'situated in a mean': 1.0},
#  'situated in a mean': {'in a mean street': 1.0},
#  'in a mean street': {'a mean street near': 1.0},
#  'a mean street near': {'mean street near the': 1.0},
#  'mean street near the': {'street near the but': 1.0},
#  'street near the but': {'near the but when': 1.0},
#  'near the but when': {'the but when he': 1.0},
#  'the but when he': {'but when he entered': 1.0},
#  'but when he entered': {'when he entered misery': 1.0},
#  'when he entered misery': {'he entered misery and': 1.0},
#  'he entered misery and': {'entered misery and despair': 1.0},
#  'entered misery and despair': {'misery and despair alone': 1.0},
#  'misery and despair alone': {'and despair alone welcomed': 1.0},
#  'and despair alone welcomed': {'despair alone welcomed beaufort': 1.0},
#  'despair alone welcomed beaufort': {'alone welcomed beaufort had': 1.0},
#  'alone welcomed beaufort had': {'welcomed beaufort had saved': 1.0},
#  'welcomed beaufort had saved': {'beaufort had saved but': 1.0},
#  'beaufort had saved but': {'had saved but a': 1.0},
#  'had saved but a': {'saved but a very': 1.0},
#  'saved but a very': {'but a very small': 1.0},
#  'but a very small': {'a very small sum': 1.0},
#  'a very small sum': {'very small sum of': 1.0},
#  'very small sum of': {'small sum of money': 1.0},
#  'small sum of money': {'sum of money from': 1.0},
#  'sum of money from': {'of money from the': 1.0},
#  'of money from the': {'money from the wreck': 1.0},
#  'money from the wreck': {'from the wreck of': 1.0},
#  'from the wreck of': {'the wreck of his': 1.0},
#  'the wreck of his': {'wreck of his fortunes': 1.0},
#  'wreck of his fortunes': {'of his fortunes but': 1.0},
#  'of his fortunes but': {'his fortunes but it': 1.0},
#  'his fortunes but it': {'fortunes but it was': 1.0},
#  'fortunes but it was': {'but it was sufficient': 1.0},
#  'but it was sufficient': {'it was sufficient to': 1.0},
#  'it was sufficient to': {'was sufficient to provide': 1.0},
#  'was sufficient to provide': {'sufficient to provide him': 1.0},
#  'sufficient to provide him': {'to provide him with': 1.0},
#  'to provide him with': {'provide him with sustenance': 1.0},
#  'provide him with sustenance': {'him with sustenance for': 1.0},
#  'him with sustenance for': {'with sustenance for some': 1.0},
#  'with sustenance for some': {'sustenance for some months': 1.0},
#  'sustenance for some months': {'for some months and': 1.0},
#  'for some months and': {'some months and in': 1.0},
#  'some months and in': {'months and in the': 1.0},
#  'months and in the': {'and in the meantime': 1.0},
#  'and in the meantime': {'in the meantime he': 0.6666666666666666,
#   'in the meantime i': 0.3333333333333333},
#  'in the meantime he': {'the meantime he hoped': 0.3333333333333333,
#   'the meantime he enjoyed': 0.3333333333333333,
#   'the meantime he told': 0.3333333333333333},
#  'the meantime he hoped': {'meantime he hoped to': 1.0},
#  'meantime he hoped to': {'he hoped to procure': 1.0},
#  'he hoped to procure': {'hoped to procure some': 1.0},
#  'hoped to procure some': {'to procure some respectable': 1.0},
#  'to procure some respectable': {'procure some respectable employment': 1.0},
#  'procure some respectable employment': {'some respectable employment in': 1.0},
#  'some respectable employment in': {'respectable employment in a': 1.0},
#  'respectable employment in a': {'employment in a merchants': 1.0},
#  'employment in a merchants': {'in a merchants the': 1.0},
#  'in a merchants the': {'a merchants the interval': 1.0},
#  'a merchants the interval': {'merchants the interval was': 1.0},
#  'merchants the interval was': {'the interval was consequently': 1.0},
#  'the interval was consequently': {'interval was consequently spent': 1.0},
#  'interval was consequently spent': {'was consequently spent in': 1.0},
#  'was consequently spent in': {'consequently spent in inaction': 1.0},
#  'consequently spent in inaction': {'spent in inaction his': 1.0},
#  'spent in inaction his': {'in inaction his grief': 1.0},
#  'in inaction his grief': {'inaction his grief only': 1.0},
#  'inaction his grief only': {'his grief only became': 1.0},
#  'his grief only became': {'grief only became more': 1.0},
#  'grief only became more': {'only became more deep': 1.0},
#  'only became more deep': {'became more deep and': 1.0},
#  'became more deep and': {'more deep and rankling': 1.0},
#  'more deep and rankling': {'deep and rankling when': 1.0},
#  'deep and rankling when': {'and rankling when he': 1.0},
#  'and rankling when he': {'rankling when he had': 1.0},
#  'rankling when he had': {'when he had leisure': 1.0},
#  'when he had leisure': {'he had leisure for': 1.0},
#  'he had leisure for': {'had leisure for reflection': 1.0},
#  'had leisure for reflection': {'leisure for reflection and': 1.0},
#  'leisure for reflection and': {'for reflection and at': 1.0},
#  'for reflection and at': {'reflection and at length': 1.0},
#  'reflection and at length': {'and at length it': 1.0},
#  'and at length it': {'at length it took': 1.0},
#  'at length it took': {'length it took so': 1.0},
#  'length it took so': {'it took so fast': 1.0},
#  'it took so fast': {'took so fast hold': 1.0},
#  'took so fast hold': {'so fast hold of': 1.0},
#  'so fast hold of': {'fast hold of his': 1.0},
#  'fast hold of his': {'hold of his mind': 1.0},
#  'hold of his mind': {'of his mind that': 1.0},
#  'of his mind that': {'his mind that at': 1.0},
#  'his mind that at': {'mind that at the': 1.0},
#  'mind that at the': {'that at the end': 1.0},
#  'that at the end': {'at the end of': 1.0},
#  'at the end of': {'the end of three': 0.5, 'the end of two': 0.5},
#  'the end of three': {'end of three months': 1.0},
#  'end of three months': {'of three months he': 1.0},
#  'of three months he': {'three months he lay': 1.0},
#  'three months he lay': {'months he lay on': 1.0},
#  'months he lay on': {'he lay on a': 1.0},
#  'he lay on a': {'lay on a bed': 1.0},
#  'lay on a bed': {'on a bed of': 1.0},
#  'on a bed of': {'a bed of sickness': 1.0},
#  'a bed of sickness': {'bed of sickness incapable': 1.0},
#  'bed of sickness incapable': {'of sickness incapable of': 1.0},
#  'of sickness incapable of': {'sickness incapable of any': 1.0},
#  'sickness incapable of any': {'incapable of any exertion': 1.0},
#  'incapable of any exertion': {'of any exertion his': 1.0},
#  'of any exertion his': {'any exertion his daughter': 1.0},
#  'any exertion his daughter': {'exertion his daughter attended': 1.0},
#  'exertion his daughter attended': {'his daughter attended him': 1.0},
#  'his daughter attended him': {'daughter attended him with': 1.0},
#  'daughter attended him with': {'attended him with the': 1.0},
#  'attended him with the': {'him with the greatest': 1.0},
#  'him with the greatest': {'with the greatest tenderness': 1.0},
#  'with the greatest tenderness': {'the greatest tenderness but': 1.0},
#  'the greatest tenderness but': {'greatest tenderness but she': 1.0},
#  'greatest tenderness but she': {'tenderness but she saw': 1.0},
#  'tenderness but she saw': {'but she saw with': 1.0},
#  'but she saw with': {'she saw with despair': 1.0},
#  'she saw with despair': {'saw with despair that': 1.0},
#  'saw with despair that': {'with despair that their': 1.0},
#  'with despair that their': {'despair that their little': 1.0},
#  'despair that their little': {'that their little fund': 1.0},
#  'that their little fund': {'their little fund was': 1.0},
#  'their little fund was': {'little fund was rapidly': 1.0},
#  'little fund was rapidly': {'fund was rapidly decreasing': 1.0},
#  'fund was rapidly decreasing': {'was rapidly decreasing and': 1.0},
#  'was rapidly decreasing and': {'rapidly decreasing and that': 1.0},
#  'rapidly decreasing and that': {'decreasing and that there': 1.0},
#  'decreasing and that there': {'and that there was': 1.0},
#  'and that there was': {'that there was no': 1.0},
#  'that there was no': {'there was no other': 1.0},
#  'there was no other': {'was no other prospect': 1.0},
#  'was no other prospect': {'no other prospect of': 1.0},
#  'no other prospect of': {'other prospect of but': 1.0},
#  'other prospect of but': {'prospect of but caroline': 1.0},
#  'prospect of but caroline': {'of but caroline beaufort': 1.0},
#  'of but caroline beaufort': {'but caroline beaufort possessed': 1.0},
#  'but caroline beaufort possessed': {'caroline beaufort possessed a': 1.0},
#  'caroline beaufort possessed a': {'beaufort possessed a mind': 1.0},
#  'beaufort possessed a mind': {'possessed a mind of': 1.0},
#  'possessed a mind of': {'a mind of an': 1.0},
#  'a mind of an': {'mind of an uncommon': 1.0},
#  'mind of an uncommon': {'of an uncommon mould': 1.0},
#  'of an uncommon mould': {'an uncommon mould and': 1.0},
#  'an uncommon mould and': {'uncommon mould and her': 1.0},
#  'uncommon mould and her': {'mould and her courage': 1.0},
#  'mould and her courage': {'and her courage rose': 1.0},
#  'and her courage rose': {'her courage rose to': 1.0},
#  'her courage rose to': {'courage rose to support': 1.0},
#  'courage rose to support': {'rose to support her': 1.0},
#  'rose to support her': {'to support her in': 1.0},
#  'to support her in': {'support her in her': 1.0},
#  'support her in her': {'her in her she': 1.0},
#  'her in her she': {'in her she procured': 1.0},
#  'in her she procured': {'her she procured plain': 1.0},
#  'her she procured plain': {'she procured plain work': 1.0},
#  'she procured plain work': {'procured plain work she': 1.0},
#  'procured plain work she': {'plain work she plaited': 1.0},
#  'plain work she plaited': {'work she plaited straw': 1.0},
#  'work she plaited straw': {'she plaited straw and': 1.0},
#  'she plaited straw and': {'plaited straw and by': 1.0},
#  'plaited straw and by': {'straw and by various': 1.0},
#  'straw and by various': {'and by various means': 1.0},
#  'and by various means': {'by various means contrived': 1.0},
#  'by various means contrived': {'various means contrived to': 1.0},
#  'various means contrived to': {'means contrived to earn': 1.0},
#  'means contrived to earn': {'contrived to earn a': 1.0},
#  'contrived to earn a': {'to earn a pittance': 1.0},
#  'to earn a pittance': {'earn a pittance scarcely': 1.0},
#  'earn a pittance scarcely': {'a pittance scarcely sufficient': 1.0},
#  'a pittance scarcely sufficient': {'pittance scarcely sufficient to': 1.0},
#  'pittance scarcely sufficient to': {'scarcely sufficient to support': 1.0},
#  'scarcely sufficient to support': {'sufficient to support life': 1.0},
#  'sufficient to support life': {'to support life several': 1.0},
#  'to support life several': {'support life several months': 1.0},
#  'support life several months': {'life several months passed': 1.0},
#  'life several months passed': {'several months passed in': 1.0},
#  'several months passed in': {'months passed in this': 1.0},
#  'months passed in this': {'passed in this her': 1.0},
#  'passed in this her': {'in this her father': 1.0},
#  'in this her father': {'this her father grew': 1.0},
#  'this her father grew': {'her father grew worse': 1.0},
#  'her father grew worse': {'father grew worse her': 1.0},
#  'father grew worse her': {'grew worse her time': 1.0},
#  'grew worse her time': {'worse her time was': 1.0},
#  'worse her time was': {'her time was more': 1.0},
#  'her time was more': {'time was more entirely': 1.0},
#  'time was more entirely': {'was more entirely occupied': 1.0},
#  'was more entirely occupied': {'more entirely occupied in': 1.0},
#  'more entirely occupied in': {'entirely occupied in attending': 1.0},
#  'entirely occupied in attending': {'occupied in attending him': 1.0},
#  'occupied in attending him': {'in attending him her': 1.0},
#  'in attending him her': {'attending him her means': 1.0},
#  'attending him her means': {'him her means of': 1.0},
#  'him her means of': {'her means of subsistence': 1.0},
#  'her means of subsistence': {'means of subsistence decreased': 1.0},
#  'means of subsistence decreased': {'of subsistence decreased and': 1.0},
#  'of subsistence decreased and': {'subsistence decreased and in': 1.0},
#  'subsistence decreased and in': {'decreased and in the': 1.0},
#  'decreased and in the': {'and in the tenth': 1.0},
#  'and in the tenth': {'in the tenth month': 1.0},
#  'in the tenth month': {'the tenth month her': 1.0},
#  'the tenth month her': {'tenth month her father': 1.0},
#  'tenth month her father': {'month her father died': 1.0},
#  'month her father died': {'her father died in': 1.0},
#  'her father died in': {'father died in her': 1.0},
#  'father died in her': {'died in her arms': 1.0},
#  'died in her arms': {'in her arms leaving': 1.0},
#  'in her arms leaving': {'her arms leaving her': 1.0},
#  'her arms leaving her': {'arms leaving her an': 1.0},
#  'arms leaving her an': {'leaving her an orphan': 1.0},
#  'leaving her an orphan': {'her an orphan and': 1.0},
#  'her an orphan and': {'an orphan and a': 1.0},
#  'an orphan and a': {'orphan and a this': 0.5, 'orphan and a she': 0.5},
#  'orphan and a this': {'and a this last': 1.0},
#  'and a this last': {'a this last blow': 1.0},
#  'a this last blow': {'this last blow overcame': 1.0},
#  'this last blow overcame': {'last blow overcame her': 1.0},
#  'last blow overcame her': {'blow overcame her and': 1.0},
#  'blow overcame her and': {'overcame her and she': 1.0},
#  'overcame her and she': {'her and she knelt': 1.0},
#  'her and she knelt': {'and she knelt by': 1.0},
#  'and she knelt by': {'she knelt by beauforts': 1.0},
#  'she knelt by beauforts': {'knelt by beauforts coffin': 1.0},
#  'knelt by beauforts coffin': {'by beauforts coffin weeping': 1.0},
#  'by beauforts coffin weeping': {'beauforts coffin weeping bitterly': 1.0},
#  'beauforts coffin weeping bitterly': {'coffin weeping bitterly when': 1.0},
#  'coffin weeping bitterly when': {'weeping bitterly when my': 1.0},
#  'weeping bitterly when my': {'bitterly when my father': 1.0},
#  'bitterly when my father': {'when my father entered': 1.0},
#  'when my father entered': {'my father entered the': 1.0},
#  'my father entered the': {'father entered the he': 1.0},
#  'father entered the he': {'entered the he came': 1.0},
#  'entered the he came': {'the he came like': 1.0},
#  'the he came like': {'he came like a': 1.0},
#  'he came like a': {'came like a protecting': 1.0},
#  'came like a protecting': {'like a protecting spirit': 1.0},
#  'like a protecting spirit': {'a protecting spirit to': 1.0},
#  'a protecting spirit to': {'protecting spirit to the': 1.0},
#  'protecting spirit to the': {'spirit to the poor': 1.0},
#  'spirit to the poor': {'to the poor girl': 1.0},
#  'to the poor girl': {'the poor girl who': 1.0},
#  'the poor girl who': {'poor girl who committed': 1.0},
#  'poor girl who committed': {'girl who committed herself': 1.0},
#  'girl who committed herself': {'who committed herself to': 1.0},
#  'who committed herself to': {'committed herself to his': 1.0},
#  'committed herself to his': {'herself to his care': 1.0},
#  'herself to his care': {'to his care and': 1.0},
#  'to his care and': {'his care and after': 1.0},
#  'his care and after': {'care and after the': 1.0},
#  'care and after the': {'and after the interment': 1.0},
#  'and after the interment': {'after the interment of': 1.0},
#  'after the interment of': {'the interment of his': 1.0},
#  'the interment of his': {'interment of his friend': 1.0},
#  'interment of his friend': {'of his friend he': 1.0},
#  'of his friend he': {'his friend he conducted': 1.0},
#  'his friend he conducted': {'friend he conducted her': 1.0},
#  'friend he conducted her': {'he conducted her to': 1.0},
#  'he conducted her to': {'conducted her to geneva': 1.0},
#  'conducted her to geneva': {'her to geneva and': 1.0},
#  'her to geneva and': {'to geneva and placed': 1.0},
#  'to geneva and placed': {'geneva and placed her': 1.0},
#  'geneva and placed her': {'and placed her under': 1.0},
#  'and placed her under': {'placed her under the': 1.0},
#  'placed her under the': {'her under the protection': 1.0},
#  'her under the protection': {'under the protection of': 1.0},
#  'under the protection of': {'the protection of a': 1.0},
#  'the protection of a': {'protection of a two': 1.0},
#  'protection of a two': {'of a two years': 1.0},
#  'of a two years': {'a two years after': 1.0},
#  'a two years after': {'two years after this': 1.0},
#  'two years after this': {'years after this event': 1.0},
#  'years after this event': {'after this event caroline': 1.0},
#  'after this event caroline': {'this event caroline became': 1.0},
#  'this event caroline became': {'event caroline became his': 1.0},
#  'event caroline became his': {'caroline became his wife': 1.0},
#  'caroline became his wife': {'became his wife there': 1.0},
#  'became his wife there': {'his wife there was': 1.0},
#  'his wife there was': {'wife there was a': 1.0},
#  'wife there was a': {'there was a considerable': 1.0},
#  'there was a considerable': {'was a considerable difference': 1.0},
#  'was a considerable difference': {'a considerable difference between': 1.0},
#  'a considerable difference between': {'considerable difference between the': 1.0},
#  'considerable difference between the': {'difference between the ages': 1.0},
#  'difference between the ages': {'between the ages of': 1.0},
#  'between the ages of': {'the ages of my': 1.0},
#  'the ages of my': {'ages of my parents': 1.0},
#  'ages of my parents': {'of my parents but': 1.0},
#  'of my parents but': {'my parents but this': 1.0},
#  'my parents but this': {'parents but this circumstance': 1.0},
#  'parents but this circumstance': {'but this circumstance seemed': 1.0},
#  'but this circumstance seemed': {'this circumstance seemed to': 1.0},
#  'this circumstance seemed to': {'circumstance seemed to unite': 1.0},
#  'circumstance seemed to unite': {'seemed to unite them': 1.0},
#  'seemed to unite them': {'to unite them only': 1.0},
#  'to unite them only': {'unite them only closer': 1.0},
#  'unite them only closer': {'them only closer in': 1.0},
#  'them only closer in': {'only closer in bonds': 1.0},
#  'only closer in bonds': {'closer in bonds of': 1.0},
#  'closer in bonds of': {'in bonds of devoted': 1.0},
#  'in bonds of devoted': {'bonds of devoted there': 1.0},
#  'bonds of devoted there': {'of devoted there was': 1.0},
#  'of devoted there was': {'devoted there was a': 1.0},
#  'devoted there was a': {'there was a sense': 1.0},
#  'there was a sense': {'was a sense of': 1.0},
#  'was a sense of': {'a sense of justice': 1.0},
#  'a sense of justice': {'sense of justice in': 1.0},
#  'sense of justice in': {'of justice in my': 1.0},
#  'of justice in my': {'justice in my fathers': 1.0},
#  'justice in my fathers': {'in my fathers upright': 1.0},
#  'in my fathers upright': {'my fathers upright mind': 1.0},
#  'my fathers upright mind': {'fathers upright mind which': 1.0},
#  'fathers upright mind which': {'upright mind which rendered': 1.0},
#  'upright mind which rendered': {'mind which rendered it': 1.0},
#  'mind which rendered it': {'which rendered it necessary': 1.0},
#  'which rendered it necessary': {'rendered it necessary that': 1.0},
#  'rendered it necessary that': {'it necessary that he': 1.0},
#  'it necessary that he': {'necessary that he should': 1.0},
#  'necessary that he should': {'that he should approve': 1.0},
#  'that he should approve': {'he should approve highly': 1.0},
#  'he should approve highly': {'should approve highly to': 1.0},
#  'should approve highly to': {'approve highly to love': 1.0},
#  'approve highly to love': {'highly to love perhaps': 1.0},
#  'highly to love perhaps': {'to love perhaps during': 1.0},
#  'to love perhaps during': {'love perhaps during former': 1.0},
#  'love perhaps during former': {'perhaps during former years': 1.0},
#  'perhaps during former years': {'during former years he': 1.0},
#  'during former years he': {'former years he had': 1.0},
#  'former years he had': {'years he had suffered': 1.0},
#  'years he had suffered': {'he had suffered from': 1.0},
#  'he had suffered from': {'had suffered from the': 1.0},
#  'had suffered from the': {'suffered from the unworthiness': 1.0},
#  'suffered from the unworthiness': {'from the unworthiness of': 1.0},
#  'from the unworthiness of': {'the unworthiness of one': 1.0},
#  'the unworthiness of one': {'unworthiness of one beloved': 1.0},
#  'unworthiness of one beloved': {'of one beloved and': 1.0},
#  'of one beloved and': {'one beloved and so': 1.0},
#  'one beloved and so': {'beloved and so was': 1.0},
#  'beloved and so was': {'and so was disposed': 1.0},
#  'and so was disposed': {'so was disposed to': 1.0},
#  'so was disposed to': {'was disposed to set': 1.0},
#  'was disposed to set': {'disposed to set a': 1.0},
#  'disposed to set a': {'to set a greater': 1.0},
#  'to set a greater': {'set a greater value': 1.0},
#  'set a greater value': {'a greater value on': 1.0},
#  'a greater value on': {'greater value on tried': 1.0},
#  'greater value on tried': {'value on tried there': 1.0},
#  'value on tried there': {'on tried there was': 1.0},
#  'on tried there was': {'tried there was a': 1.0},
#  'tried there was a': {'there was a show': 1.0},
#  'there was a show': {'was a show of': 1.0},
#  'was a show of': {'a show of gratitude': 1.0},
#  'a show of gratitude': {'show of gratitude and': 1.0},
#  'show of gratitude and': {'of gratitude and worship': 1.0},
#  'of gratitude and worship': {'gratitude and worship in': 1.0},
#  'gratitude and worship in': {'and worship in his': 1.0},
#  'and worship in his': {'worship in his attachment': 1.0},
#  'worship in his attachment': {'in his attachment to': 1.0},
#  'in his attachment to': {'his attachment to my': 1.0},
#  'his attachment to my': {'attachment to my mother': 1.0},
#  'attachment to my mother': {'to my mother differing': 1.0},
#  'to my mother differing': {'my mother differing wholly': 1.0},
#  'my mother differing wholly': {'mother differing wholly from': 1.0},
#  'mother differing wholly from': {'differing wholly from the': 1.0},
#  'differing wholly from the': {'wholly from the doting': 1.0},
#  'wholly from the doting': {'from the doting fondness': 1.0},
#  'from the doting fondness': {'the doting fondness of': 1.0},
#  'the doting fondness of': {'doting fondness of age': 1.0},
#  'doting fondness of age': {'fondness of age for': 1.0},
#  'fondness of age for': {'of age for it': 1.0},
#  'of age for it': {'age for it was': 1.0},
#  'age for it was': {'for it was inspired': 1.0},
#  'for it was inspired': {'it was inspired by': 1.0},
#  'it was inspired by': {'was inspired by reverence': 1.0},
#  'was inspired by reverence': {'inspired by reverence for': 1.0},
#  'inspired by reverence for': {'by reverence for her': 1.0},
#  'by reverence for her': {'reverence for her virtues': 1.0},
#  'reverence for her virtues': {'for her virtues and': 1.0},
#  'for her virtues and': {'her virtues and a': 1.0},
#  'her virtues and a': {'virtues and a desire': 1.0},
#  'virtues and a desire': {'and a desire to': 1.0},
#  'and a desire to': {'a desire to be': 1.0},
#  'a desire to be': {'desire to be the': 1.0},
#  'desire to be the': {'to be the means': 1.0},
#  'to be the means': {'be the means of': 1.0},
#  'be the means of': {'the means of in': 1.0},
#  'the means of in': {'means of in some': 1.0},
#  'means of in some': {'of in some degree': 1.0},
#  'of in some degree': {'in some degree recompensing': 1.0},
#  'in some degree recompensing': {'some degree recompensing her': 1.0},
#  'some degree recompensing her': {'degree recompensing her for': 1.0},
#  'degree recompensing her for': {'recompensing her for the': 1.0},
#  'recompensing her for the': {'her for the sorrows': 1.0},
#  'her for the sorrows': {'for the sorrows she': 1.0},
#  'for the sorrows she': {'the sorrows she had': 1.0},
#  'the sorrows she had': {'sorrows she had endured': 1.0},
#  'sorrows she had endured': {'she had endured but': 1.0},
#  'she had endured but': {'had endured but which': 1.0},
#  'had endured but which': {'endured but which gave': 1.0},
#  'endured but which gave': {'but which gave inexpressible': 1.0},
#  'but which gave inexpressible': {'which gave inexpressible grace': 1.0},
#  'which gave inexpressible grace': {'gave inexpressible grace to': 1.0},
#  'gave inexpressible grace to': {'inexpressible grace to his': 1.0},
#  'inexpressible grace to his': {'grace to his behaviour': 1.0},
#  'grace to his behaviour': {'to his behaviour to': 1.0},
#  'to his behaviour to': {'his behaviour to everything': 1.0},
#  'his behaviour to everything': {'behaviour to everything was': 1.0},
#  'behaviour to everything was': {'to everything was made': 1.0},
#  'to everything was made': {'everything was made to': 1.0},
#  'everything was made to': {'was made to yield': 1.0},
#  'was made to yield': {'made to yield to': 1.0},
#  'made to yield to': {'to yield to her': 1.0},
#  'to yield to her': {'yield to her wishes': 1.0},
#  'yield to her wishes': {'to her wishes and': 1.0},
#  'to her wishes and': {'her wishes and her': 1.0},
#  'her wishes and her': {'wishes and her he': 1.0},
#  'wishes and her he': {'and her he strove': 1.0},
#  'and her he strove': {'her he strove to': 1.0},
#  'her he strove to': {'he strove to shelter': 1.0},
#  'he strove to shelter': {'strove to shelter her': 1.0},
#  'strove to shelter her': {'to shelter her as': 1.0},
#  'to shelter her as': {'shelter her as a': 1.0},
#  'shelter her as a': {'her as a fair': 1.0},
#  'her as a fair': {'as a fair exotic': 1.0},
#  'as a fair exotic': {'a fair exotic is': 1.0},
#  'a fair exotic is': {'fair exotic is sheltered': 1.0},
#  'fair exotic is sheltered': {'exotic is sheltered by': 1.0},
#  'exotic is sheltered by': {'is sheltered by the': 1.0},
#  'is sheltered by the': {'sheltered by the gardener': 1.0},
#  'sheltered by the gardener': {'by the gardener from': 1.0},
#  'by the gardener from': {'the gardener from every': 1.0},
#  'the gardener from every': {'gardener from every rougher': 1.0},
#  'gardener from every rougher': {'from every rougher wind': 1.0},
#  'from every rougher wind': {'every rougher wind and': 1.0},
#  'every rougher wind and': {'rougher wind and to': 1.0},
#  'rougher wind and to': {'wind and to surround': 1.0},
#  'wind and to surround': {'and to surround her': 1.0},
#  'and to surround her': {'to surround her with': 1.0},
#  'to surround her with': {'surround her with all': 1.0},
#  'surround her with all': {'her with all that': 1.0},
#  'her with all that': {'with all that could': 1.0},
#  'with all that could': {'all that could tend': 1.0},
#  'all that could tend': {'that could tend to': 1.0},
#  'that could tend to': {'could tend to excite': 1.0},
#  'could tend to excite': {'tend to excite pleasurable': 1.0},
#  'tend to excite pleasurable': {'to excite pleasurable emotion': 1.0},
#  'to excite pleasurable emotion': {'excite pleasurable emotion in': 1.0},
#  'excite pleasurable emotion in': {'pleasurable emotion in her': 1.0},
#  'pleasurable emotion in her': {'emotion in her soft': 1.0},
#  'emotion in her soft': {'in her soft and': 1.0},
#  'in her soft and': {'her soft and benevolent': 1.0},
#  'her soft and benevolent': {'soft and benevolent her': 1.0},
#  'soft and benevolent her': {'and benevolent her health': 1.0},
#  'and benevolent her health': {'benevolent her health and': 1.0},
#  'benevolent her health and': {'her health and even': 1.0},
#  'her health and even': {'health and even the': 1.0},
#  'health and even the': {'and even the tranquillity': 1.0},
#  'and even the tranquillity': {'even the tranquillity of': 1.0},
#  'even the tranquillity of': {'the tranquillity of her': 1.0},
#  'the tranquillity of her': {'tranquillity of her hitherto': 1.0},
#  'tranquillity of her hitherto': {'of her hitherto constant': 1.0},
#  'of her hitherto constant': {'her hitherto constant spirit': 1.0},
#  'her hitherto constant spirit': {'hitherto constant spirit had': 1.0},
#  'hitherto constant spirit had': {'constant spirit had been': 1.0},
#  'constant spirit had been': {'spirit had been shaken': 1.0},
#  'spirit had been shaken': {'had been shaken by': 1.0},
#  'had been shaken by': {'been shaken by what': 1.0},
#  'been shaken by what': {'shaken by what she': 1.0},
#  'shaken by what she': {'by what she had': 1.0},
#  'by what she had': {'what she had gone': 1.0},
#  'what she had gone': {'she had gone during': 1.0},
#  'she had gone during': {'had gone during the': 1.0},
#  'had gone during the': {'gone during the two': 1.0},
#  'gone during the two': {'during the two years': 1.0},
#  'during the two years': {'the two years that': 1.0},
#  'the two years that': {'two years that had': 1.0},
#  'two years that had': {'years that had elapsed': 1.0},
#  'years that had elapsed': {'that had elapsed previous': 1.0},
#  'that had elapsed previous': {'had elapsed previous to': 1.0},
#  'had elapsed previous to': {'elapsed previous to their': 1.0},
#  'elapsed previous to their': {'previous to their marriage': 1.0},
#  'previous to their marriage': {'to their marriage my': 1.0},
#  'to their marriage my': {'their marriage my father': 1.0},
#  'their marriage my father': {'marriage my father had': 1.0},
#  'marriage my father had': {'my father had gradually': 1.0},
#  'my father had gradually': {'father had gradually relinquished': 1.0},
#  'father had gradually relinquished': {'had gradually relinquished all': 1.0},
#  'had gradually relinquished all': {'gradually relinquished all his': 1.0},
#  'gradually relinquished all his': {'relinquished all his public': 1.0},
#  'relinquished all his public': {'all his public functions': 1.0},
#  'all his public functions': {'his public functions and': 1.0},
#  'his public functions and': {'public functions and immediately': 1.0},
#  'public functions and immediately': {'functions and immediately after': 1.0},
#  'functions and immediately after': {'and immediately after their': 1.0},
#  'and immediately after their': {'immediately after their union': 1.0},
#  'immediately after their union': {'after their union they': 1.0},
#  'after their union they': {'their union they sought': 1.0},
#  'their union they sought': {'union they sought the': 1.0},
#  'union they sought the': {'they sought the pleasant': 1.0},
#  'they sought the pleasant': {'sought the pleasant climate': 1.0},
#  'sought the pleasant climate': {'the pleasant climate of': 1.0},
#  'the pleasant climate of': {'pleasant climate of italy': 1.0},
#  'pleasant climate of italy': {'climate of italy and': 1.0},
#  'climate of italy and': {'of italy and the': 1.0},
#  'of italy and the': {'italy and the change': 1.0},
#  'italy and the change': {'and the change of': 1.0},
#  'and the change of': {'the change of scene': 1.0},
#  'the change of scene': {'change of scene and': 1.0},
#  'change of scene and': {'of scene and interest': 0.5,
#   'of scene and varied': 0.5},
#  'of scene and interest': {'scene and interest attendant': 1.0},
#  'scene and interest attendant': {'and interest attendant on': 1.0},
#  'and interest attendant on': {'interest attendant on a': 1.0},
#  'interest attendant on a': {'attendant on a tour': 1.0},
#  'attendant on a tour': {'on a tour through': 1.0},
#  'on a tour through': {'a tour through that': 1.0},
#  'a tour through that': {'tour through that land': 1.0},
#  'tour through that land': {'through that land of': 1.0},
#  'through that land of': {'that land of wonders': 1.0},
#  'that land of wonders': {'land of wonders as': 1.0},
#  'land of wonders as': {'of wonders as a': 1.0},
#  'of wonders as a': {'wonders as a restorative': 1.0},
#  'wonders as a restorative': {'as a restorative for': 1.0},
#  'as a restorative for': {'a restorative for her': 1.0},
#  'a restorative for her': {'restorative for her weakened': 1.0},
#  'restorative for her weakened': {'for her weakened frame': 1.0},
#  'for her weakened frame': {'her weakened frame from': 1.0},
#  'her weakened frame from': {'weakened frame from italy': 1.0},
#  'weakened frame from italy': {'frame from italy they': 1.0},
#  'frame from italy they': {'from italy they visited': 1.0},
#  'from italy they visited': {'italy they visited germany': 1.0},
#  'italy they visited germany': {'they visited germany and': 1.0},
#  'they visited germany and': {'visited germany and i': 1.0},
#  'visited germany and i': {'germany and i their': 1.0},
#  'germany and i their': {'and i their eldest': 1.0},
#  'and i their eldest': {'i their eldest child': 1.0},
#  'i their eldest child': {'their eldest child was': 1.0},
#  'their eldest child was': {'eldest child was born': 0.5,
#   'eldest child was but': 0.5},
#  'eldest child was born': {'child was born at': 1.0},
#  'child was born at': {'was born at naples': 1.0},
#  'was born at naples': {'born at naples and': 1.0},
#  'born at naples and': {'at naples and as': 1.0},
#  'at naples and as': {'naples and as an': 1.0},
#  'naples and as an': {'and as an infant': 1.0},
#  'and as an infant': {'as an infant accompanied': 1.0},
#  'as an infant accompanied': {'an infant accompanied them': 1.0},
#  'an infant accompanied them': {'infant accompanied them in': 1.0},
#  'infant accompanied them in': {'accompanied them in their': 1.0},
#  'accompanied them in their': {'them in their i': 1.0},
#  'them in their i': {'in their i remained': 1.0},
#  'in their i remained': {'their i remained for': 1.0},
#  'their i remained for': {'i remained for several': 1.0},
#  'i remained for several': {'remained for several years': 1.0},
#  'remained for several years': {'for several years their': 1.0},
#  'for several years their': {'several years their only': 1.0},
#  'several years their only': {'years their only much': 1.0},
#  'years their only much': {'their only much as': 1.0},
#  'their only much as': {'only much as they': 1.0},
#  'only much as they': {'much as they were': 1.0},
#  'much as they were': {'as they were attached': 1.0},
#  'as they were attached': {'they were attached to': 1.0},
#  'they were attached to': {'were attached to each': 1.0},
#  'were attached to each': {'attached to each other': 1.0},
#  'attached to each other': {'to each other they': 0.5,
#   'to each other from': 0.5},
#  'to each other they': {'each other they seemed': 1.0},
#  'each other they seemed': {'other they seemed to': 1.0},
#  'other they seemed to': {'they seemed to draw': 1.0},
#  'they seemed to draw': {'seemed to draw inexhaustible': 1.0},
#  'seemed to draw inexhaustible': {'to draw inexhaustible stores': 1.0},
#  'to draw inexhaustible stores': {'draw inexhaustible stores of': 1.0},
#  'draw inexhaustible stores of': {'inexhaustible stores of affection': 1.0},
#  'inexhaustible stores of affection': {'stores of affection from': 1.0},
#  'stores of affection from': {'of affection from a': 1.0},
#  'of affection from a': {'affection from a very': 1.0},
#  'affection from a very': {'from a very mine': 1.0},
#  'from a very mine': {'a very mine of': 1.0},
#  'a very mine of': {'very mine of love': 1.0},
#  'very mine of love': {'mine of love to': 1.0},
#  'mine of love to': {'of love to bestow': 1.0},
#  'of love to bestow': {'love to bestow them': 1.0},
#  'love to bestow them': {'to bestow them upon': 1.0},
#  'to bestow them upon': {'bestow them upon my': 1.0},
#  'bestow them upon my': {'them upon my mothers': 1.0},
#  'them upon my mothers': {'upon my mothers tender': 1.0},
#  'upon my mothers tender': {'my mothers tender caresses': 1.0},
#  'my mothers tender caresses': {'mothers tender caresses and': 1.0},
#  'mothers tender caresses and': {'tender caresses and my': 1.0},
#  'tender caresses and my': {'caresses and my fathers': 1.0},
#  'caresses and my fathers': {'and my fathers smile': 1.0},
#  'and my fathers smile': {'my fathers smile of': 1.0},
#  'my fathers smile of': {'fathers smile of benevolent': 1.0},
#  'fathers smile of benevolent': {'smile of benevolent pleasure': 1.0},
#  'smile of benevolent pleasure': {'of benevolent pleasure while': 1.0},
#  'of benevolent pleasure while': {'benevolent pleasure while regarding': 1.0},
#  'benevolent pleasure while regarding': {'pleasure while regarding me': 1.0},
#  'pleasure while regarding me': {'while regarding me are': 1.0},
#  'while regarding me are': {'regarding me are my': 1.0},
#  'regarding me are my': {'me are my first': 1.0},
#  'me are my first': {'are my first i': 1.0},
#  'are my first i': {'my first i was': 1.0},
#  'my first i was': {'first i was their': 1.0},
#  'first i was their': {'i was their plaything': 1.0},
#  'i was their plaything': {'was their plaything and': 1.0},
#  'was their plaything and': {'their plaything and their': 1.0},
#  'their plaything and their': {'plaything and their idol': 1.0},
#  'plaything and their idol': {'and their idol and': 1.0},
#  'and their idol and': {'their idol and something': 1.0},
#  'their idol and something': {'idol and something better': 1.0},
#  'idol and something better': {'and something better their': 1.0},
#  'and something better their': {'something better their child': 1.0},
#  'something better their child': {'better their child the': 1.0},
#  'better their child the': {'their child the innocent': 1.0},
#  'their child the innocent': {'child the innocent and': 1.0},
#  'child the innocent and': {'the innocent and helpless': 1.0},
#  'the innocent and helpless': {'innocent and helpless creature': 1.0},
#  'innocent and helpless creature': {'and helpless creature bestowed': 1.0},
#  'and helpless creature bestowed': {'helpless creature bestowed on': 1.0},
#  'helpless creature bestowed on': {'creature bestowed on them': 1.0},
#  'creature bestowed on them': {'bestowed on them by': 1.0},
#  'bestowed on them by': {'on them by heaven': 1.0},
#  'on them by heaven': {'them by heaven whom': 1.0},
#  'them by heaven whom': {'by heaven whom to': 1.0},
#  'by heaven whom to': {'heaven whom to bring': 1.0},
#  'heaven whom to bring': {'whom to bring up': 1.0},
#  'whom to bring up': {'to bring up to': 1.0},
#  'to bring up to': {'bring up to good': 1.0},
#  'bring up to good': {'up to good and': 1.0},
#  'up to good and': {'to good and whose': 1.0},
#  'to good and whose': {'good and whose future': 1.0},
#  'good and whose future': {'and whose future lot': 1.0},
#  'and whose future lot': {'whose future lot it': 1.0},
#  'whose future lot it': {'future lot it was': 1.0},
#  'future lot it was': {'lot it was in': 1.0},
#  'lot it was in': {'it was in their': 1.0},
#  'it was in their': {'was in their hands': 1.0},
#  'was in their hands': {'in their hands to': 1.0},
#  'in their hands to': {'their hands to direct': 1.0},
#  'their hands to direct': {'hands to direct to': 1.0},
#  'hands to direct to': {'to direct to happiness': 1.0},
#  'to direct to happiness': {'direct to happiness or': 1.0},
#  'direct to happiness or': {'to happiness or misery': 1.0},
#  'to happiness or misery': {'happiness or misery according': 1.0},
#  'happiness or misery according': {'or misery according as': 1.0},
#  'or misery according as': {'misery according as they': 1.0},
#  'misery according as they': {'according as they fulfilled': 1.0},
#  'according as they fulfilled': {'as they fulfilled their': 1.0},
#  'as they fulfilled their': {'they fulfilled their duties': 1.0},
#  'they fulfilled their duties': {'fulfilled their duties towards': 1.0},
#  'fulfilled their duties towards': {'their duties towards with': 1.0},
#  'their duties towards with': {'duties towards with this': 1.0},
#  'duties towards with this': {'towards with this deep': 1.0},
#  'towards with this deep': {'with this deep consciousness': 1.0},
#  'with this deep consciousness': {'this deep consciousness of': 1.0},
#  'this deep consciousness of': {'deep consciousness of what': 1.0},
#  'deep consciousness of what': {'consciousness of what they': 1.0},
#  'consciousness of what they': {'of what they owed': 1.0},
#  'of what they owed': {'what they owed towards': 1.0},
#  'what they owed towards': {'they owed towards the': 1.0},
#  'they owed towards the': {'owed towards the being': 1.0},
#  'owed towards the being': {'towards the being to': 1.0},
#  'towards the being to': {'the being to which': 1.0},
#  'the being to which': {'being to which they': 1.0},
#  'being to which they': {'to which they had': 1.0},
#  'to which they had': {'which they had given': 1.0},
#  'which they had given': {'they had given life': 1.0},
#  'they had given life': {'had given life added': 1.0},
#  'had given life added': {'given life added to': 1.0},
#  'given life added to': {'life added to the': 1.0},
#  'life added to the': {'added to the active': 1.0},
#  'added to the active': {'to the active spirit': 1.0},
#  'to the active spirit': {'the active spirit of': 1.0},
#  'the active spirit of': {'active spirit of tenderness': 1.0},
#  'active spirit of tenderness': {'spirit of tenderness that': 1.0},
#  'spirit of tenderness that': {'of tenderness that animated': 1.0},
#  'of tenderness that animated': {'tenderness that animated both': 1.0},
#  'tenderness that animated both': {'that animated both it': 1.0},
#  'that animated both it': {'animated both it may': 1.0},
#  'animated both it may': {'both it may be': 1.0},
#  'both it may be': {'it may be imagined': 1.0},
#  'it may be imagined': {'may be imagined that': 1.0},
#  'may be imagined that': {'be imagined that while': 1.0},
#  'be imagined that while': {'imagined that while during': 1.0},
#  'imagined that while during': {'that while during every': 1.0},
#  'that while during every': {'while during every hour': 1.0},
#  'while during every hour': {'during every hour of': 1.0},
#  'during every hour of': {'every hour of my': 1.0},
#  'every hour of my': {'hour of my infant': 1.0},
#  'hour of my infant': {'of my infant life': 1.0},
#  'of my infant life': {'my infant life i': 1.0},
#  'my infant life i': {'infant life i received': 1.0},
#  'infant life i received': {'life i received a': 1.0},
#  'life i received a': {'i received a lesson': 1.0},
#  'i received a lesson': {'received a lesson of': 1.0},
#  'received a lesson of': {'a lesson of patience': 1.0},
#  'a lesson of patience': {'lesson of patience of': 1.0},
#  'lesson of patience of': {'of patience of charity': 1.0},
#  'of patience of charity': {'patience of charity and': 1.0},
#  'patience of charity and': {'of charity and of': 1.0},
#  'of charity and of': {'charity and of i': 1.0},
#  'charity and of i': {'and of i was': 1.0},
#  'and of i was': {'of i was so': 1.0},
#  'of i was so': {'i was so guided': 1.0},
#  'i was so guided': {'was so guided by': 1.0},
#  'was so guided by': {'so guided by a': 1.0},
#  'so guided by a': {'guided by a silken': 1.0},
#  'guided by a silken': {'by a silken cord': 1.0},
#  'by a silken cord': {'a silken cord that': 1.0},
#  'a silken cord that': {'silken cord that all': 1.0},
#  'silken cord that all': {'cord that all seemed': 1.0},
#  'cord that all seemed': {'that all seemed but': 1.0},
#  'that all seemed but': {'all seemed but one': 1.0},
#  'all seemed but one': {'seemed but one train': 1.0},
#  'seemed but one train': {'but one train of': 1.0},
#  'but one train of': {'one train of enjoyment': 1.0},
#  'one train of enjoyment': {'train of enjoyment to': 1.0},
#  ...}

# %% [markdown]
# Increasing the number of engrams increases the number of possible combinations of words that are considered as "states" in the Markov model. \
# For example, with 1 engram (or unigram), every single word is considered a state. So if you have a text with N different words, you will have approximately N states in your model. \
# With 2 engrams (bigrams), the states are pairs of consecutive words. So, if you have a text with N different words, you will have approximately N^2 states in your model.
#
# As the number of engrams increases, the context considered to predict the next word increases, but the complexity of the model also increases, as the number of possible combinations grows exponentially relative to the number of words in the text.

# %%
# def function
def generate_text(markov_model, limit = 100, start='i am'):
   n = 0
   curr_state = start
   next_state = None
   phrase = ""
   phrase += curr_state + " " # initialise variables before the while loop
   while n<limit:
      # randomly select a state from the possible next states with prob evaluate in Markov Model with random.choice()
      next_state = random.choices(list(markov_model[curr_state].keys()), list(markov_model[curr_state].values()))
      curr_state = next_state[0]
      phrase += curr_state + " "
      n += 1 # update the states
   return phrase

# %%
# try sometimes and see how the model work
for i in range(6):
   print(str(i)+".\t", generate_text(MC4,start= 'by birth a genevese', limit=8))
# Out:
# 0.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most
# 1.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most
# 2.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most
# 3.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most
# 4.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most
# 5.	 by birth a genevese birth a genevese and a genevese and my genevese and my family and my family is my family is one family is one of is one of the one of the most

# %% [markdown]
# here we have a problem: words are not well concatenated because of repetitions. We need to find a solution and modify the model

# %%
def MC_model4(cleaned_txt, n_gram=4):
    markov_model = {}
    for i in range(len(cleaned_txt)-n_gram):
        curr_state, next_state = "", ""
        words_added = set()  # Set to keep track of words already added
        for j in range(n_gram):
            curr_word = cleaned_txt[i+j]
            next_word = cleaned_txt[i+j+1] if (i+j+1) < len(cleaned_txt) else ""  # Handling end of text
            curr_state += curr_word + " "
            if next_word not in words_added:
                next_state += next_word + " "
                words_added.add(next_word)  # Adding next word to the set
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if next_state:  # Check if next_state is not empty
            if curr_state not in markov_model:
                markov_model[curr_state] = {}
                markov_model[curr_state][next_state] = 1
            else:
                if next_state in markov_model[curr_state]:
                    markov_model[curr_state][next_state] += 1
                else:
                    markov_model[curr_state][next_state] = 1
    
    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count / total
        
    return markov_model

# %%
import random

def generate_text(markov_model, limit=100, start='i am'):
    n = 0
    curr_state = start
    prev_words = set(start.split())
    phrase = ""
    phrase += curr_state + " "  
    while n < limit:
        if curr_state not in markov_model:
            break  
        # Randomly select a state from the possible next states with probability evaluated in Markov Model
        next_state_options = list(markov_model[curr_state].keys())
        next_state = random.choices(next_state_options, list(markov_model[curr_state].values()))[0]

        # Check for repeated words
        next_words = next_state.split()
        next_words = [word for word in next_words if word not in prev_words]
        next_state = " ".join(next_words)

        if next_state == "":
            break

        phrase += next_state + " "
        curr_state = next_state
        prev_words.update(next_words) 
        n += 1  
    return phrase

# %%
# testing model1 by uploading ours tokenized words list 
MC4 = MC_model4(cleaned_txt)
print(f'Number of states:',len(MC4))
# display(MC4)
# Out:
# Number of states: 66230

# %%
for i in range(6):
   print(str(i)+".\t", generate_text(MC4,start= 'genevese and my family', limit=8))
# Out:
# 0.	 genevese and my family is
# 1.	 genevese and my family is
# 2.	 genevese and my family is
# 3.	 genevese and my family is
# 4.	 genevese and my family is
# 5.	 genevese and my family is
