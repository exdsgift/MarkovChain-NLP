# %% [markdown]
# ### Build more performance model

# %%
# library
import numpy as np
import pandas as pd
import os
import re
import random
import string
from IPython.display import display

# Token trasformation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# setting config file to upload file path
from config import file_txt

with open(file_txt, 'r') as file:
   text = file.read()

# %%
# Removes formatting and multiple spaces
def text_form(text):
   txt_clean = re.sub(r'\s+', ' ', text)
   txt_words = re.findall(r'\b\w+\b', txt_clean)
   return txt_words

txt_words = text_form(text)
print(f'Number of words:',len(txt_words))
# Out:
# Number of words: 69690

# %%
# rows in line
def read_txt(file_txt):
   txt = []
   with open (file_txt) as f:
      for line in f:
         line = line.strip()
         if line != '': txt.append(line)
   return txt

rows_list = read_txt(file_txt)
print('Number of lines: ', len(rows_list))
# Out:
# Number of lines:  5941

# %% [markdown]
# # removing special characters and transform words in token
# def clean_txt(txt):
#    cleaned_text = []
#    for line in txt:
#       line = line.lower()
#       line = re.sub(r"['!@#$%^&*(){}?/`~<>+=-\\]", "", line)
#       tokens = word_tokenize(line, language="english", preserve_line=True)
#       words = [word for word in tokens if word.isalpha()]
#       cleaned_text+= words
#    return cleaned_text
#
# cleaned_txt = clean_txt(rows_list)
# print(f'number of tokenized words:',len(cleaned_txt))

# %%
display(cleaned_txt[:30])
# Out:
# ['chapter',
#  'i',
#  'am',
#  'by',
#  'birth',
#  'a',
#  'genevese',
#  'and',
#  'my',
#  'family',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'distinguished',
#  'of',
#  'that',
#  'my',
#  'ancestors',
#  'had',
#  'been',
#  'for',
#  'many',
#  'years',
#  'counsellors',
#  'and',
#  'syndics',
#  'and',
#  'my']

# %%
def MC_model4(cleaned_txt, n_gram=3):
    markov_model = {}
    for i in range(len(cleaned_txt)-n_gram):
        curr_state, next_state = "", ""
        for j in range(n_gram):
            curr_state += cleaned_txt[i+j] + " "
            next_state += cleaned_txt[i+j+1] + " "  # Fixing index for next_state
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if curr_state not in markov_model:
            markov_model[curr_state] = {}
            markov_model[curr_state][next_state] = 1
        else:
            if next_state in markov_model[curr_state]:
                markov_model[curr_state][next_state] += 1
            else:
                markov_model[curr_state][next_state] = 1
    
    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count/total
        
    return markov_model

# %%
# testing model1 by uploading ours tokenized words list 
MC4 = MC_model4(cleaned_txt)
print(f'Number of states:',len(MC4))
# Out:
# Number of states: 60643

# %%
display(MC4)
# Out:
# {'chapter i am': {'i am by': 1.0},
#  'i am by': {'am by birth': 0.5, 'am by a': 0.5},
#  'am by birth': {'by birth a': 1.0},
#  'by birth a': {'birth a genevese': 1.0},
#  'birth a genevese': {'a genevese and': 1.0},
#  'a genevese and': {'genevese and my': 1.0},
#  'genevese and my': {'and my family': 1.0},
#  'and my family': {'my family is': 0.5, 'my family have': 0.5},
#  'my family is': {'family is one': 1.0},
#  'family is one': {'is one of': 1.0},
#  'is one of': {'one of the': 0.5, 'one of those': 0.5},
#  'one of the': {'of the most': 0.058823529411764705,
#   'of the phenomena': 0.058823529411764705,
#   'of the servants': 0.058823529411764705,
#   'of the others': 0.058823529411764705,
#   'of the trees': 0.058823529411764705,
#   'of the best': 0.11764705882352941,
#   'of the women': 0.058823529411764705,
#   'of the windows': 0.058823529411764705,
#   'of the causes': 0.058823529411764705,
#   'of the first': 0.11764705882352941,
#   'of the folds': 0.058823529411764705,
#   'of the remotest': 0.058823529411764705,
#   'of the peasants': 0.058823529411764705,
#   'of the men': 0.058823529411764705,
#   'of the turnkeys': 0.058823529411764705},
#  'of the most': {'the most distinguished': 0.2857142857142857,
#   'the most familiar': 0.14285714285714285,
#   'the most miserable': 0.14285714285714285,
#   'the most terrible': 0.14285714285714285,
#   'the most horrible': 0.14285714285714285,
#   'the most hardy': 0.14285714285714285},
#  'the most distinguished': {'most distinguished of': 0.3333333333333333,
#   'most distinguished he': 0.3333333333333333,
#   'most distinguished natural': 0.3333333333333333},
#  'most distinguished of': {'distinguished of that': 1.0},
#  'distinguished of that': {'of that my': 1.0},
#  'of that my': {'that my ancestors': 1.0},
#  'that my ancestors': {'my ancestors had': 1.0},
#  'my ancestors had': {'ancestors had been': 1.0},
#  'ancestors had been': {'had been for': 1.0},
#  'had been for': {'been for many': 1.0},
#  'been for many': {'for many years': 0.5, 'for many months': 0.5},
#  'for many years': {'many years counsellors': 0.25,
#   'many years and': 0.25,
#   'many years in': 0.25,
#   'many years when': 0.25},
#  'many years counsellors': {'years counsellors and': 1.0},
#  'years counsellors and': {'counsellors and syndics': 1.0},
#  'counsellors and syndics': {'and syndics and': 1.0},
#  'and syndics and': {'syndics and my': 1.0},
#  'syndics and my': {'and my father': 1.0},
#  'and my father': {'my father had': 0.3333333333333333,
#   'my father continued': 0.3333333333333333,
#   'my father i': 0.3333333333333333},
#  'my father had': {'father had filled': 0.14285714285714285,
#   'father had gradually': 0.14285714285714285,
#   'father had gone': 0.14285714285714285,
#   'father had taken': 0.42857142857142855,
#   'father had often': 0.14285714285714285},
#  'father had filled': {'had filled several': 1.0},
#  'had filled several': {'filled several public': 1.0},
#  'filled several public': {'several public situations': 1.0},
#  'several public situations': {'public situations with': 1.0},
#  'public situations with': {'situations with honour': 1.0},
#  'situations with honour': {'with honour and': 1.0},
#  'with honour and': {'honour and he': 1.0},
#  'honour and he': {'and he was': 1.0},
#  'and he was': {'he was respected': 0.5, 'he was also': 0.5},
#  'he was respected': {'was respected by': 1.0},
#  'was respected by': {'respected by all': 1.0},
#  'respected by all': {'by all who': 1.0},
#  'by all who': {'all who knew': 1.0},
#  'all who knew': {'who knew him': 0.5, 'who knew her': 0.5},
#  'who knew him': {'knew him for': 1.0},
#  'knew him for': {'him for his': 1.0},
#  'him for his': {'for his integrity': 1.0},
#  'for his integrity': {'his integrity and': 1.0},
#  'his integrity and': {'integrity and indefatigable': 1.0},
#  'integrity and indefatigable': {'and indefatigable attention': 1.0},
#  'and indefatigable attention': {'indefatigable attention to': 1.0},
#  'indefatigable attention to': {'attention to public': 1.0},
#  'attention to public': {'to public he': 1.0},
#  'to public he': {'public he passed': 1.0},
#  'public he passed': {'he passed his': 1.0},
#  'he passed his': {'passed his younger': 1.0},
#  'passed his younger': {'his younger days': 1.0},
#  'his younger days': {'younger days perpetually': 1.0},
#  'younger days perpetually': {'days perpetually occupied': 1.0},
#  'days perpetually occupied': {'perpetually occupied by': 1.0},
#  'perpetually occupied by': {'occupied by the': 1.0},
#  'occupied by the': {'by the affairs': 1.0},
#  'by the affairs': {'the affairs of': 1.0},
#  'the affairs of': {'affairs of his': 1.0},
#  'affairs of his': {'of his country': 1.0},
#  'of his country': {'his country a': 0.5, 'his country and': 0.5},
#  'his country a': {'country a variety': 1.0},
#  'country a variety': {'a variety of': 1.0},
#  'a variety of': {'variety of circumstances': 0.5,
#   'variety of combustibles': 0.5},
#  'variety of circumstances': {'of circumstances had': 1.0},
#  'of circumstances had': {'circumstances had prevented': 1.0},
#  'circumstances had prevented': {'had prevented his': 1.0},
#  'had prevented his': {'prevented his marrying': 1.0},
#  'prevented his marrying': {'his marrying early': 1.0},
#  'his marrying early': {'marrying early nor': 1.0},
#  'marrying early nor': {'early nor was': 1.0},
#  'early nor was': {'nor was it': 1.0},
#  'nor was it': {'was it until': 1.0},
#  'was it until': {'it until the': 1.0},
#  'it until the': {'until the decline': 1.0},
#  'until the decline': {'the decline of': 1.0},
#  'the decline of': {'decline of life': 0.6666666666666666,
#   'decline of that': 0.3333333333333333},
#  'decline of life': {'of life that': 0.5, 'of life having': 0.5},
#  'of life that': {'life that he': 1.0},
#  'life that he': {'that he became': 1.0},
#  'that he became': {'he became a': 1.0},
#  'he became a': {'became a husband': 1.0},
#  'became a husband': {'a husband and': 1.0},
#  'a husband and': {'husband and the': 0.5, 'husband and lovely': 0.5},
#  'husband and the': {'and the father': 1.0},
#  'and the father': {'the father of': 1.0},
#  'the father of': {'father of a': 0.25,
#   'father of their': 0.25,
#   'father of safie': 0.5},
#  'father of a': {'of a family': 1.0},
#  'of a family': {'a family as': 1.0},
#  'a family as': {'family as the': 1.0},
#  'family as the': {'as the circumstances': 1.0},
#  'as the circumstances': {'the circumstances of': 1.0},
#  'the circumstances of': {'circumstances of his': 0.5,
#   'circumstances of the': 0.5},
#  'circumstances of his': {'of his marriage': 1.0},
#  'of his marriage': {'his marriage illustrate': 1.0},
#  'his marriage illustrate': {'marriage illustrate his': 1.0},
#  'marriage illustrate his': {'illustrate his character': 1.0},
#  'illustrate his character': {'his character i': 1.0},
#  'his character i': {'character i can': 1.0},
#  'character i can': {'i can not': 1.0},
#  'i can not': {'can not refrain': 0.045454545454545456,
#   'can not pretend': 0.045454545454545456,
#   'can not go': 0.045454545454545456,
#   'can not live': 0.045454545454545456,
#   'can not describe': 0.18181818181818182,
#   'can not inspire': 0.045454545454545456,
#   'can not consent': 0.045454545454545456,
#   'can not do': 0.045454545454545456,
#   'can not see': 0.045454545454545456,
#   'can not sometimes': 0.045454545454545456,
#   'can not guess': 0.045454545454545456,
#   'can not doubt': 0.045454545454545456,
#   'can not recollect': 0.045454545454545456,
#   'can not forbear': 0.045454545454545456,
#   'can not withstand': 0.045454545454545456,
#   'can not lead': 0.045454545454545456,
#   'can not ask': 0.045454545454545456,
#   'can not find': 0.045454545454545456,
#   'can not believe': 0.045454545454545456},
#  'can not refrain': {'not refrain from': 1.0},
#  'not refrain from': {'refrain from relating': 1.0},
#  'refrain from relating': {'from relating one': 1.0},
#  'from relating one': {'relating one of': 1.0},
#  'relating one of': {'one of his': 1.0},
#  'one of his': {'of his most': 0.5, 'of his own': 0.5},
#  'of his most': {'his most intimate': 1.0},
#  'his most intimate': {'most intimate friends': 1.0},
#  'most intimate friends': {'intimate friends was': 1.0},
#  'intimate friends was': {'friends was a': 1.0},
#  'friends was a': {'was a merchant': 1.0},
#  'was a merchant': {'a merchant who': 1.0},
#  'a merchant who': {'merchant who from': 1.0},
#  'merchant who from': {'who from a': 1.0},
#  'who from a': {'from a flourishing': 1.0},
#  'from a flourishing': {'a flourishing state': 1.0},
#  'a flourishing state': {'flourishing state fell': 1.0},
#  'flourishing state fell': {'state fell through': 1.0},
#  'state fell through': {'fell through numerous': 1.0},
#  'fell through numerous': {'through numerous mischances': 1.0},
#  'through numerous mischances': {'numerous mischances into': 1.0},
#  'numerous mischances into': {'mischances into this': 1.0},
#  'mischances into this': {'into this man': 1.0},
#  'into this man': {'this man whose': 1.0},
#  'this man whose': {'man whose name': 1.0},
#  'man whose name': {'whose name was': 1.0},
#  'whose name was': {'name was beaufort': 1.0},
#  'name was beaufort': {'was beaufort was': 1.0},
#  'was beaufort was': {'beaufort was of': 1.0},
#  'beaufort was of': {'was of a': 1.0},
#  'was of a': {'of a proud': 0.25,
#   'of a calmer': 0.25,
#   'of a nature': 0.25,
#   'of a lustrous': 0.25},
#  'of a proud': {'a proud and': 1.0},
#  'a proud and': {'proud and unbending': 1.0},
#  'proud and unbending': {'and unbending disposition': 1.0},
#  'and unbending disposition': {'unbending disposition and': 1.0},
#  'unbending disposition and': {'disposition and could': 1.0},
#  'disposition and could': {'and could not': 1.0},
#  'and could not': {'could not bear': 0.3333333333333333,
#   'could not such': 0.3333333333333333,
#   'could not free': 0.3333333333333333},
#  'could not bear': {'not bear to': 1.0},
#  'not bear to': {'bear to live': 1.0},
#  'bear to live': {'to live in': 1.0},
#  'to live in': {'live in poverty': 1.0},
#  'live in poverty': {'in poverty and': 1.0},
#  'in poverty and': {'poverty and oblivion': 0.5, 'poverty and want': 0.5},
#  'poverty and oblivion': {'and oblivion in': 1.0},
#  'and oblivion in': {'oblivion in the': 1.0},
#  'oblivion in the': {'in the same': 1.0},
#  'in the same': {'the same country': 0.08333333333333333,
#   'the same pursuit': 0.08333333333333333,
#   'the same place': 0.16666666666666666,
#   'the same house': 0.08333333333333333,
#   'the same manner': 0.25,
#   'the same routine': 0.08333333333333333,
#   'the same language': 0.08333333333333333,
#   'the same incoherent': 0.08333333333333333,
#   'the same ship': 0.08333333333333333},
#  'the same country': {'same country where': 1.0},
#  'same country where': {'country where he': 1.0},
#  'country where he': {'where he had': 1.0},
#  'where he had': {'he had formerly': 0.3333333333333333,
#   'he had lived': 0.3333333333333333,
#   'he had disappeared': 0.3333333333333333},
#  'he had formerly': {'had formerly been': 1.0},
#  'had formerly been': {'formerly been distinguished': 0.5,
#   'formerly been our': 0.5},
#  'formerly been distinguished': {'been distinguished for': 1.0},
#  'been distinguished for': {'distinguished for his': 1.0},
#  'distinguished for his': {'for his rank': 1.0},
#  'for his rank': {'his rank and': 1.0},
#  'his rank and': {'rank and having': 1.0},
#  'rank and having': {'and having paid': 1.0},
#  'and having paid': {'having paid his': 1.0},
#  'having paid his': {'paid his debts': 1.0},
#  'paid his debts': {'his debts therefore': 1.0},
#  'his debts therefore': {'debts therefore in': 1.0},
#  'debts therefore in': {'therefore in the': 1.0},
#  'therefore in the': {'in the most': 1.0},
#  'in the most': {'the most honourable': 0.09090909090909091,
#   'the most melancholy': 0.09090909090909091,
#   'the most comprehensive': 0.09090909090909091,
#   'the most interesting': 0.09090909090909091,
#   'the most cordial': 0.09090909090909091,
#   'the most beautiful': 0.09090909090909091,
#   'the most ardent': 0.09090909090909091,
#   'the most savage': 0.09090909090909091,
#   'the most perfect': 0.09090909090909091,
#   'the most detestable': 0.09090909090909091,
#   'the most imminent': 0.09090909090909091},
#  'the most honourable': {'most honourable manner': 1.0},
#  'most honourable manner': {'honourable manner he': 1.0},
#  'honourable manner he': {'manner he retreated': 1.0},
#  'manner he retreated': {'he retreated with': 1.0},
#  'he retreated with': {'retreated with his': 1.0},
#  'retreated with his': {'with his daughter': 1.0},
#  'with his daughter': {'his daughter to': 0.3333333333333333,
#   'his daughter in': 0.3333333333333333,
#   'his daughter insultingly': 0.3333333333333333},
#  'his daughter to': {'daughter to the': 0.5, 'daughter to think': 0.5},
#  'daughter to the': {'to the town': 1.0},
#  'to the town': {'the town of': 0.5, 'the town for': 0.5},
#  'the town of': {'town of lucerne': 0.5, 'town of from': 0.5},
#  'town of lucerne': {'of lucerne where': 1.0},
#  'of lucerne where': {'lucerne where he': 1.0},
#  'lucerne where he': {'where he lived': 1.0},
#  'where he lived': {'he lived unknown': 1.0},
#  'he lived unknown': {'lived unknown and': 1.0},
#  'lived unknown and': {'unknown and in': 1.0},
#  'unknown and in': {'and in my': 1.0},
#  'and in my': {'in my father': 0.3333333333333333,
#   'in my condition': 0.3333333333333333,
#   'in my dying': 0.3333333333333333},
#  'in my father': {'my father loved': 1.0},
#  'my father loved': {'father loved beaufort': 1.0},
#  'father loved beaufort': {'loved beaufort with': 1.0},
#  'loved beaufort with': {'beaufort with the': 1.0},
#  'beaufort with the': {'with the truest': 1.0},
#  'with the truest': {'the truest friendship': 1.0},
#  'the truest friendship': {'truest friendship and': 1.0},
#  'truest friendship and': {'friendship and was': 1.0},
#  'friendship and was': {'and was deeply': 1.0},
#  'and was deeply': {'was deeply grieved': 1.0},
#  'was deeply grieved': {'deeply grieved by': 1.0},
#  'deeply grieved by': {'grieved by his': 1.0},
#  'grieved by his': {'by his retreat': 1.0},
#  'by his retreat': {'his retreat in': 1.0},
#  'his retreat in': {'retreat in these': 1.0},
#  'retreat in these': {'in these unfortunate': 1.0},
#  'in these unfortunate': {'these unfortunate circumstances': 1.0},
#  'these unfortunate circumstances': {'unfortunate circumstances he': 1.0},
#  'unfortunate circumstances he': {'circumstances he bitterly': 1.0},
#  'circumstances he bitterly': {'he bitterly deplored': 1.0},
#  'he bitterly deplored': {'bitterly deplored the': 1.0},
#  'bitterly deplored the': {'deplored the false': 1.0},
#  'deplored the false': {'the false pride': 1.0},
#  'the false pride': {'false pride which': 1.0},
#  'false pride which': {'pride which led': 1.0},
#  'pride which led': {'which led his': 1.0},
#  'which led his': {'led his friend': 1.0},
#  'led his friend': {'his friend to': 1.0},
#  'his friend to': {'friend to a': 1.0},
#  'friend to a': {'to a conduct': 1.0},
#  'to a conduct': {'a conduct so': 1.0},
#  'a conduct so': {'conduct so little': 1.0},
#  'conduct so little': {'so little worthy': 1.0},
#  'so little worthy': {'little worthy of': 1.0},
#  'little worthy of': {'worthy of the': 1.0},
#  'worthy of the': {'of the affection': 1.0},
#  'of the affection': {'the affection that': 1.0},
#  'the affection that': {'affection that united': 1.0},
#  'affection that united': {'that united he': 1.0},
#  'that united he': {'united he lost': 1.0},
#  'united he lost': {'he lost no': 1.0},
#  'he lost no': {'lost no time': 1.0},
#  'lost no time': {'no time in': 1.0},
#  'no time in': {'time in endeavouring': 1.0},
#  'time in endeavouring': {'in endeavouring to': 1.0},
#  'in endeavouring to': {'endeavouring to seek': 0.5,
#   'endeavouring to bestow': 0.5},
#  'endeavouring to seek': {'to seek him': 0.5, 'to seek a': 0.5},
#  'to seek him': {'seek him out': 1.0},
#  'seek him out': {'him out with': 1.0},
#  'him out with': {'out with the': 1.0},
#  'out with the': {'with the hope': 1.0},
#  'with the hope': {'the hope of': 1.0},
#  'the hope of': {'hope of persuading': 0.5, 'hope of night': 0.5},
#  'hope of persuading': {'of persuading him': 1.0},
#  'of persuading him': {'persuading him to': 1.0},
#  'persuading him to': {'him to begin': 1.0},
#  'him to begin': {'to begin the': 1.0},
#  'to begin the': {'begin the world': 1.0},
#  'begin the world': {'the world again': 1.0},
#  'the world again': {'world again through': 1.0},
#  'world again through': {'again through his': 1.0},
#  'again through his': {'through his credit': 1.0},
#  'through his credit': {'his credit and': 1.0},
#  'his credit and': {'credit and beaufort': 1.0},
#  'credit and beaufort': {'and beaufort had': 1.0},
#  'and beaufort had': {'beaufort had taken': 1.0},
#  'beaufort had taken': {'had taken effectual': 1.0},
#  'had taken effectual': {'taken effectual measures': 1.0},
#  'taken effectual measures': {'effectual measures to': 1.0},
#  'effectual measures to': {'measures to conceal': 1.0},
#  'measures to conceal': {'to conceal himself': 1.0},
#  'to conceal himself': {'conceal himself and': 1.0},
#  'conceal himself and': {'himself and it': 1.0},
#  'himself and it': {'and it was': 1.0},
#  'and it was': {'it was ten': 0.1,
#   'it was with': 0.2,
#   'it was indeed': 0.1,
#   'it was judged': 0.1,
#   'it was understood': 0.1,
#   'it was now': 0.1,
#   'it was likely': 0.1,
#   'it was he': 0.1,
#   'it was during': 0.1},
#  'it was ten': {'was ten months': 1.0},
#  'was ten months': {'ten months before': 1.0},
#  'ten months before': {'months before my': 1.0},
#  'months before my': {'before my father': 0.5, 'before my arrival': 0.5},
#  'before my father': {'my father discovered': 1.0},
#  'my father discovered': {'father discovered his': 1.0},
#  'father discovered his': {'discovered his overjoyed': 1.0},
#  'discovered his overjoyed': {'his overjoyed at': 1.0},
#  'his overjoyed at': {'overjoyed at this': 1.0},
#  'overjoyed at this': {'at this discovery': 1.0},
#  'at this discovery': {'this discovery he': 1.0},
#  'this discovery he': {'discovery he hastened': 1.0},
#  'discovery he hastened': {'he hastened to': 1.0},
#  'he hastened to': {'hastened to the': 0.5, 'hastened to paris': 0.5},
#  'hastened to the': {'to the house': 1.0},
#  'to the house': {'the house which': 0.6666666666666666,
#   'the house about': 0.3333333333333333},
#  'the house which': {'house which was': 0.5, 'house which i': 0.5},
#  'house which was': {'which was situated': 1.0},
#  'which was situated': {'was situated in': 1.0},
#  'was situated in': {'situated in a': 1.0},
#  'situated in a': {'in a mean': 1.0},
#  'in a mean': {'a mean street': 1.0},
#  'a mean street': {'mean street near': 1.0},
#  'mean street near': {'street near the': 1.0},
#  'street near the': {'near the but': 1.0},
#  'near the but': {'the but when': 1.0},
#  'the but when': {'but when he': 1.0},
#  'but when he': {'when he entered': 0.25,
#   'when he spoke': 0.25,
#   'when he observed': 0.25,
#   'when he was': 0.25},
#  'when he entered': {'he entered misery': 1.0},
#  'he entered misery': {'entered misery and': 1.0},
#  'entered misery and': {'misery and despair': 1.0},
#  'misery and despair': {'and despair alone': 1.0},
#  'and despair alone': {'despair alone welcomed': 1.0},
#  'despair alone welcomed': {'alone welcomed beaufort': 1.0},
#  'alone welcomed beaufort': {'welcomed beaufort had': 1.0},
#  'welcomed beaufort had': {'beaufort had saved': 1.0},
#  'beaufort had saved': {'had saved but': 1.0},
#  'had saved but': {'saved but a': 1.0},
#  'saved but a': {'but a very': 1.0},
#  'but a very': {'a very small': 0.5, 'a very sorry': 0.5},
#  'a very small': {'very small sum': 1.0},
#  'very small sum': {'small sum of': 1.0},
#  'small sum of': {'sum of money': 1.0},
#  'sum of money': {'of money from': 0.3333333333333333,
#   'of money she': 0.3333333333333333,
#   'of money together': 0.3333333333333333},
#  'of money from': {'money from the': 1.0},
#  'money from the': {'from the wreck': 1.0},
#  'from the wreck': {'the wreck of': 1.0},
#  'the wreck of': {'wreck of his': 1.0},
#  'wreck of his': {'of his fortunes': 1.0},
#  'of his fortunes': {'his fortunes but': 1.0},
#  'his fortunes but': {'fortunes but it': 1.0},
#  'fortunes but it': {'but it was': 1.0},
#  'but it was': {'it was sufficient': 0.09090909090909091,
#   'it was ineffectual': 0.09090909090909091,
#   'it was in': 0.09090909090909091,
#   'it was allied': 0.09090909090909091,
#   'it was excited': 0.09090909090909091,
#   'it was augmented': 0.09090909090909091,
#   'it was dry': 0.09090909090909091,
#   'it was wholesome': 0.09090909090909091,
#   'it was all': 0.09090909090909091,
#   'it was agreed': 0.09090909090909091,
#   'it was not': 0.09090909090909091},
#  'it was sufficient': {'was sufficient to': 1.0},
#  'was sufficient to': {'sufficient to provide': 1.0},
#  'sufficient to provide': {'to provide him': 1.0},
#  'to provide him': {'provide him with': 1.0},
#  'provide him with': {'him with sustenance': 1.0},
#  'him with sustenance': {'with sustenance for': 1.0},
#  'with sustenance for': {'sustenance for some': 1.0},
#  'sustenance for some': {'for some months': 1.0},
#  'for some months': {'some months and': 0.5, 'some months longer': 0.5},
#  'some months and': {'months and in': 1.0},
#  'months and in': {'and in the': 1.0},
#  'and in the': {'in the meantime': 0.3,
#   'in the tenth': 0.1,
#   'in the majestic': 0.1,
#   'in the bitterness': 0.1,
#   'in the general': 0.1,
#   'in the afternoon': 0.1,
#   'in the views': 0.1,
#   'in the bustle': 0.1},
#  'in the meantime': {'the meantime he': 0.3333333333333333,
#   'the meantime been': 0.1111111111111111,
#   'the meantime took': 0.1111111111111111,
#   'the meantime i': 0.2222222222222222,
#   'the meantime for': 0.1111111111111111,
#   'the meantime overjoyed': 0.1111111111111111},
#  'the meantime he': {'meantime he hoped': 0.3333333333333333,
#   'meantime he enjoyed': 0.3333333333333333,
#   'meantime he told': 0.3333333333333333},
#  'meantime he hoped': {'he hoped to': 1.0},
#  'he hoped to': {'hoped to procure': 1.0},
#  'hoped to procure': {'to procure some': 1.0},
#  'to procure some': {'procure some respectable': 1.0},
#  'procure some respectable': {'some respectable employment': 1.0},
#  'some respectable employment': {'respectable employment in': 1.0},
#  'respectable employment in': {'employment in a': 1.0},
#  'employment in a': {'in a merchants': 1.0},
#  'in a merchants': {'a merchants the': 1.0},
#  'a merchants the': {'merchants the interval': 1.0},
#  'merchants the interval': {'the interval was': 1.0},
#  'the interval was': {'interval was consequently': 1.0},
#  'interval was consequently': {'was consequently spent': 1.0},
#  'was consequently spent': {'consequently spent in': 1.0},
#  'consequently spent in': {'spent in inaction': 1.0},
#  'spent in inaction': {'in inaction his': 1.0},
#  'in inaction his': {'inaction his grief': 1.0},
#  'inaction his grief': {'his grief only': 1.0},
#  'his grief only': {'grief only became': 1.0},
#  'grief only became': {'only became more': 1.0},
#  'only became more': {'became more deep': 1.0},
#  'became more deep': {'more deep and': 1.0},
#  'more deep and': {'deep and rankling': 1.0},
#  'deep and rankling': {'and rankling when': 1.0},
#  'and rankling when': {'rankling when he': 1.0},
#  'rankling when he': {'when he had': 1.0},
#  'when he had': {'he had leisure': 0.5, 'he had pronounced': 0.5},
#  'he had leisure': {'had leisure for': 1.0},
#  'had leisure for': {'leisure for reflection': 1.0},
#  'leisure for reflection': {'for reflection and': 1.0},
#  'for reflection and': {'reflection and at': 1.0},
#  'reflection and at': {'and at length': 1.0},
#  'and at length': {'at length it': 0.25,
#   'at length the': 0.25,
#   'at length discovered': 0.25,
#   'at length exhausted': 0.25},
#  'at length it': {'length it took': 1.0},
#  'length it took': {'it took so': 1.0},
#  'it took so': {'took so fast': 1.0},
#  'took so fast': {'so fast hold': 1.0},
#  'so fast hold': {'fast hold of': 1.0},
#  'fast hold of': {'hold of his': 1.0},
#  'hold of his': {'of his mind': 1.0},
#  'of his mind': {'his mind that': 0.5, 'his mind on': 0.5},
#  'his mind that': {'mind that at': 1.0},
#  'mind that at': {'that at the': 1.0},
#  'that at the': {'at the end': 1.0},
#  'at the end': {'the end of': 1.0},
#  'the end of': {'end of three': 0.2,
#   'end of two': 0.2,
#   'end of my': 0.4,
#   'end of i': 0.2},
#  'end of three': {'of three months': 1.0},
#  'of three months': {'three months he': 1.0},
#  'three months he': {'months he lay': 1.0},
#  'months he lay': {'he lay on': 1.0},
#  'he lay on': {'lay on a': 1.0},
#  'lay on a': {'on a bed': 1.0},
#  'on a bed': {'a bed of': 0.5, 'a bed hardly': 0.5},
#  'a bed of': {'bed of sickness': 1.0},
#  'bed of sickness': {'of sickness incapable': 1.0},
#  'of sickness incapable': {'sickness incapable of': 1.0},
#  'sickness incapable of': {'incapable of any': 1.0},
#  'incapable of any': {'of any exertion': 0.3333333333333333,
#   'of any severity': 0.3333333333333333,
#   'of any i': 0.3333333333333333},
#  'of any exertion': {'any exertion his': 1.0},
#  'any exertion his': {'exertion his daughter': 1.0},
#  'exertion his daughter': {'his daughter attended': 1.0},
#  'his daughter attended': {'daughter attended him': 1.0},
#  'daughter attended him': {'attended him with': 1.0},
#  'attended him with': {'him with the': 1.0},
#  'him with the': {'with the greatest': 1.0},
#  'with the greatest': {'the greatest tenderness': 0.2,
#   'the greatest when': 0.2,
#   'the greatest diligence': 0.2,
#   'the greatest your': 0.2,
#   'the greatest affection': 0.2},
#  'the greatest tenderness': {'greatest tenderness but': 1.0},
#  'greatest tenderness but': {'tenderness but she': 1.0},
#  'tenderness but she': {'but she saw': 1.0},
#  'but she saw': {'she saw with': 1.0},
#  'she saw with': {'saw with despair': 1.0},
#  'saw with despair': {'with despair that': 1.0},
#  'with despair that': {'despair that their': 1.0},
#  'despair that their': {'that their little': 1.0},
#  'that their little': {'their little fund': 1.0},
#  'their little fund': {'little fund was': 1.0},
#  'little fund was': {'fund was rapidly': 1.0},
#  'fund was rapidly': {'was rapidly decreasing': 1.0},
#  'was rapidly decreasing': {'rapidly decreasing and': 1.0},
#  'rapidly decreasing and': {'decreasing and that': 1.0},
#  'decreasing and that': {'and that there': 1.0},
#  'and that there': {'that there was': 1.0},
#  'that there was': {'there was no': 0.3333333333333333,
#   'there was but': 0.3333333333333333,
#   'there was some': 0.3333333333333333},
#  'there was no': {'was no other': 0.5, 'was no sign': 0.5},
#  'was no other': {'no other prospect': 1.0},
#  'no other prospect': {'other prospect of': 1.0},
#  'other prospect of': {'prospect of but': 1.0},
#  'prospect of but': {'of but caroline': 1.0},
#  'of but caroline': {'but caroline beaufort': 1.0},
#  'but caroline beaufort': {'caroline beaufort possessed': 1.0},
#  'caroline beaufort possessed': {'beaufort possessed a': 1.0},
#  'beaufort possessed a': {'possessed a mind': 1.0},
#  'possessed a mind': {'a mind of': 1.0},
#  'a mind of': {'mind of an': 0.5, 'mind of moderate': 0.5},
#  'mind of an': {'of an uncommon': 1.0},
#  'of an uncommon': {'an uncommon mould': 1.0},
#  'an uncommon mould': {'uncommon mould and': 1.0},
#  'uncommon mould and': {'mould and her': 1.0},
#  'mould and her': {'and her courage': 1.0},
#  'and her courage': {'her courage rose': 1.0},
#  'her courage rose': {'courage rose to': 1.0},
#  'courage rose to': {'rose to support': 1.0},
#  'rose to support': {'to support her': 1.0},
#  'to support her': {'support her in': 1.0},
#  'support her in': {'her in her': 1.0},
#  'her in her': {'in her she': 1.0},
#  'in her she': {'her she procured': 0.3333333333333333,
#   'her she sometimes': 0.3333333333333333,
#   'her she was': 0.3333333333333333},
#  'her she procured': {'she procured plain': 1.0},
#  'she procured plain': {'procured plain work': 1.0},
#  'procured plain work': {'plain work she': 1.0},
#  'plain work she': {'work she plaited': 1.0},
#  'work she plaited': {'she plaited straw': 1.0},
#  'she plaited straw': {'plaited straw and': 1.0},
#  'plaited straw and': {'straw and by': 1.0},
#  'straw and by': {'and by various': 1.0},
#  'and by various': {'by various means': 1.0},
#  'by various means': {'various means contrived': 1.0},
#  'various means contrived': {'means contrived to': 1.0},
#  'means contrived to': {'contrived to earn': 1.0},
#  'contrived to earn': {'to earn a': 1.0},
#  'to earn a': {'earn a pittance': 1.0},
#  'earn a pittance': {'a pittance scarcely': 1.0},
#  'a pittance scarcely': {'pittance scarcely sufficient': 1.0},
#  'pittance scarcely sufficient': {'scarcely sufficient to': 1.0},
#  'scarcely sufficient to': {'sufficient to support': 1.0},
#  'sufficient to support': {'to support life': 1.0},
#  'to support life': {'support life several': 1.0},
#  'support life several': {'life several months': 1.0},
#  'life several months': {'several months passed': 1.0},
#  'several months passed': {'months passed in': 1.0},
#  'months passed in': {'passed in this': 1.0},
#  'passed in this': {'in this her': 0.5, 'in this manner': 0.5},
#  'in this her': {'this her father': 1.0},
#  'this her father': {'her father grew': 1.0},
#  'her father grew': {'father grew worse': 1.0},
#  'father grew worse': {'grew worse her': 1.0},
#  'grew worse her': {'worse her time': 1.0},
#  'worse her time': {'her time was': 1.0},
#  'her time was': {'time was more': 1.0},
#  'time was more': {'was more entirely': 1.0},
#  'was more entirely': {'more entirely occupied': 1.0},
#  'more entirely occupied': {'entirely occupied in': 1.0},
#  'entirely occupied in': {'occupied in attending': 1.0},
#  'occupied in attending': {'in attending him': 1.0},
#  'in attending him': {'attending him her': 1.0},
#  'attending him her': {'him her means': 1.0},
#  'him her means': {'her means of': 1.0},
#  'her means of': {'means of subsistence': 1.0},
#  'means of subsistence': {'of subsistence decreased': 1.0},
#  'of subsistence decreased': {'subsistence decreased and': 1.0},
#  'subsistence decreased and': {'decreased and in': 1.0},
#  'decreased and in': {'and in the': 1.0},
#  'in the tenth': {'the tenth month': 1.0},
#  'the tenth month': {'tenth month her': 1.0},
#  'tenth month her': {'month her father': 1.0},
#  'month her father': {'her father died': 1.0},
#  'her father died': {'father died in': 1.0},
#  'father died in': {'died in her': 1.0},
#  'died in her': {'in her arms': 1.0},
#  'in her arms': {'her arms leaving': 1.0},
#  'her arms leaving': {'arms leaving her': 1.0},
#  'arms leaving her': {'leaving her an': 1.0},
#  'leaving her an': {'her an orphan': 1.0},
#  'her an orphan': {'an orphan and': 1.0},
#  'an orphan and': {'orphan and a': 1.0},
#  'orphan and a': {'and a this': 0.5, 'and a she': 0.5},
#  'and a this': {'a this last': 1.0},
#  'a this last': {'this last blow': 1.0},
#  'this last blow': {'last blow overcame': 1.0},
#  'last blow overcame': {'blow overcame her': 1.0},
#  'blow overcame her': {'overcame her and': 1.0},
#  'overcame her and': {'her and she': 1.0},
#  'her and she': {'and she knelt': 0.5, 'and she awoke': 0.5},
#  'and she knelt': {'she knelt by': 1.0},
#  'she knelt by': {'knelt by beauforts': 1.0},
#  'knelt by beauforts': {'by beauforts coffin': 1.0},
#  'by beauforts coffin': {'beauforts coffin weeping': 1.0},
#  'beauforts coffin weeping': {'coffin weeping bitterly': 1.0},
#  'coffin weeping bitterly': {'weeping bitterly when': 1.0},
#  'weeping bitterly when': {'bitterly when my': 1.0},
#  'bitterly when my': {'when my father': 1.0},
#  'when my father': {'my father entered': 0.3333333333333333,
#   'my father had': 0.3333333333333333,
#   'my father returned': 0.3333333333333333},
#  'my father entered': {'father entered the': 0.5, 'father entered it': 0.5},
#  'father entered the': {'entered the he': 1.0},
#  'entered the he': {'the he came': 1.0},
#  'the he came': {'he came like': 1.0},
#  'he came like': {'came like a': 1.0},
#  'came like a': {'like a protecting': 1.0},
#  'like a protecting': {'a protecting spirit': 1.0},
#  'a protecting spirit': {'protecting spirit to': 1.0},
#  'protecting spirit to': {'spirit to the': 1.0},
#  'spirit to the': {'to the poor': 0.5, 'to the conversations': 0.5},
#  'to the poor': {'the poor girl': 1.0},
#  'the poor girl': {'poor girl who': 0.3333333333333333,
#   'poor girl confirmed': 0.3333333333333333,
#   'poor girl died': 0.3333333333333333},
#  'poor girl who': {'girl who committed': 1.0},
#  'girl who committed': {'who committed herself': 1.0},
#  'who committed herself': {'committed herself to': 1.0},
#  'committed herself to': {'herself to his': 1.0},
#  'herself to his': {'to his care': 1.0},
#  'to his care': {'his care and': 1.0},
#  'his care and': {'care and after': 1.0},
#  'care and after': {'and after the': 1.0},
#  'and after the': {'after the interment': 0.25,
#   'after the death': 0.25,
#   'after the advocate': 0.25,
#   'after the usual': 0.25},
#  'after the interment': {'the interment of': 1.0},
#  'the interment of': {'interment of his': 1.0},
#  'interment of his': {'of his friend': 1.0},
#  'of his friend': {'his friend he': 1.0},
#  'his friend he': {'friend he conducted': 1.0},
#  'friend he conducted': {'he conducted her': 1.0},
#  'he conducted her': {'conducted her to': 1.0},
#  'conducted her to': {'her to geneva': 1.0},
#  'her to geneva': {'to geneva and': 1.0},
#  'to geneva and': {'geneva and placed': 0.5, 'geneva and i': 0.5},
#  'geneva and placed': {'and placed her': 1.0},
#  'and placed her': {'placed her under': 1.0},
#  'placed her under': {'her under the': 1.0},
#  'her under the': {'under the protection': 1.0},
#  'under the protection': {'the protection of': 1.0},
#  'the protection of': {'protection of a': 0.5, 'protection of some': 0.5},
#  'protection of a': {'of a two': 1.0},
#  'of a two': {'a two years': 1.0},
#  'a two years': {'two years after': 1.0},
#  'two years after': {'years after this': 1.0},
#  'years after this': {'after this event': 1.0},
#  'after this event': {'this event caroline': 1.0},
#  'this event caroline': {'event caroline became': 1.0},
#  'event caroline became': {'caroline became his': 1.0},
#  'caroline became his': {'became his wife': 1.0},
#  'became his wife': {'his wife there': 1.0},
#  'his wife there': {'wife there was': 1.0},
#  'wife there was': {'there was a': 1.0},
#  'there was a': {'was a considerable': 0.16666666666666666,
#   'was a sense': 0.16666666666666666,
#   'was a show': 0.16666666666666666,
#   'was a certain': 0.16666666666666666,
#   'was a task': 0.16666666666666666,
#   'was a frenzy': 0.16666666666666666},
#  'was a considerable': {'a considerable difference': 1.0},
#  'a considerable difference': {'considerable difference between': 1.0},
#  'considerable difference between': {'difference between the': 1.0},
#  'difference between the': {'between the ages': 1.0},
#  'between the ages': {'the ages of': 1.0},
#  'the ages of': {'ages of my': 1.0},
#  'ages of my': {'of my parents': 1.0},
#  'of my parents': {'my parents but': 0.3333333333333333,
#   'my parents house': 0.3333333333333333,
#   'my parents were': 0.3333333333333333},
#  'my parents but': {'parents but this': 1.0},
#  'parents but this': {'but this circumstance': 1.0},
#  'but this circumstance': {'this circumstance seemed': 1.0},
#  'this circumstance seemed': {'circumstance seemed to': 1.0},
#  'circumstance seemed to': {'seemed to unite': 1.0},
#  'seemed to unite': {'to unite them': 1.0},
#  'to unite them': {'unite them only': 1.0},
#  'unite them only': {'them only closer': 1.0},
#  'them only closer': {'only closer in': 1.0},
#  'only closer in': {'closer in bonds': 1.0},
#  'closer in bonds': {'in bonds of': 1.0},
#  'in bonds of': {'bonds of devoted': 1.0},
#  'bonds of devoted': {'of devoted there': 1.0},
#  'of devoted there': {'devoted there was': 1.0},
#  'devoted there was': {'there was a': 1.0},
#  'was a sense': {'a sense of': 1.0},
#  'a sense of': {'sense of justice': 0.3333333333333333,
#   'sense of mortal': 0.3333333333333333,
#   'sense of security': 0.3333333333333333},
#  'sense of justice': {'of justice in': 1.0},
#  'of justice in': {'justice in my': 1.0},
#  'justice in my': {'in my fathers': 1.0},
#  'in my fathers': {'my fathers upright': 0.5, 'my fathers house': 0.5},
#  'my fathers upright': {'fathers upright mind': 1.0},
#  'fathers upright mind': {'upright mind which': 1.0},
#  'upright mind which': {'mind which rendered': 1.0},
#  'mind which rendered': {'which rendered it': 1.0},
#  'which rendered it': {'rendered it necessary': 1.0},
#  'rendered it necessary': {'it necessary that': 1.0},
#  'it necessary that': {'necessary that he': 1.0},
#  'necessary that he': {'that he should': 1.0},
#  'that he should': {'he should approve': 0.3333333333333333,
#   'he should speedily': 0.3333333333333333,
#   'he should live': 0.3333333333333333},
#  'he should approve': {'should approve highly': 1.0},
#  'should approve highly': {'approve highly to': 1.0},
#  'approve highly to': {'highly to love': 1.0},
#  'highly to love': {'to love perhaps': 1.0},
#  'to love perhaps': {'love perhaps during': 1.0},
#  'love perhaps during': {'perhaps during former': 1.0},
#  'perhaps during former': {'during former years': 1.0},
#  'during former years': {'former years he': 1.0},
#  'former years he': {'years he had': 1.0},
#  'years he had': {'he had suffered': 1.0},
#  'he had suffered': {'had suffered from': 1.0},
#  'had suffered from': {'suffered from the': 1.0},
#  'suffered from the': {'from the unworthiness': 1.0},
#  'from the unworthiness': {'the unworthiness of': 1.0},
#  'the unworthiness of': {'unworthiness of one': 1.0},
#  'unworthiness of one': {'of one beloved': 1.0},
#  'of one beloved': {'one beloved and': 1.0},
#  'one beloved and': {'beloved and so': 1.0},
#  'beloved and so': {'and so was': 1.0},
#  'and so was': {'so was disposed': 1.0},
#  'so was disposed': {'was disposed to': 1.0},
#  'was disposed to': {'disposed to set': 1.0},
#  'disposed to set': {'to set a': 1.0},
#  'to set a': {'set a greater': 0.5, 'set a crown': 0.5},
#  'set a greater': {'a greater value': 1.0},
#  'a greater value': {'greater value on': 1.0},
#  'greater value on': {'value on tried': 1.0},
#  'value on tried': {'on tried there': 1.0},
#  'on tried there': {'tried there was': 1.0},
#  'tried there was': {'there was a': 1.0},
#  'was a show': {'a show of': 1.0},
#  'a show of': {'show of gratitude': 1.0},
#  'show of gratitude': {'of gratitude and': 1.0},
#  'of gratitude and': {'gratitude and worship': 1.0},
#  'gratitude and worship': {'and worship in': 1.0},
#  'and worship in': {'worship in his': 1.0},
#  'worship in his': {'in his attachment': 1.0},
#  'in his attachment': {'his attachment to': 1.0},
#  'his attachment to': {'attachment to my': 1.0},
#  'attachment to my': {'to my mother': 1.0},
#  'to my mother': {'my mother differing': 0.3333333333333333,
#   'my mother was': 0.3333333333333333,
#   'my mother and': 0.3333333333333333},
#  'my mother differing': {'mother differing wholly': 1.0},
#  'mother differing wholly': {'differing wholly from': 1.0},
#  'differing wholly from': {'wholly from the': 1.0},
#  'wholly from the': {'from the doting': 1.0},
#  'from the doting': {'the doting fondness': 1.0},
#  'the doting fondness': {'doting fondness of': 1.0},
#  'doting fondness of': {'fondness of age': 1.0},
#  'fondness of age': {'of age for': 1.0},
#  'of age for': {'age for it': 1.0},
#  'age for it': {'for it was': 1.0},
#  'for it was': {'it was inspired': 0.25,
#   'it was the': 0.25,
#   'it was a': 0.25,
#   'it was by': 0.25},
#  'it was inspired': {'was inspired by': 1.0},
#  'was inspired by': {'inspired by reverence': 1.0},
#  'inspired by reverence': {'by reverence for': 1.0},
#  'by reverence for': {'reverence for her': 1.0},
#  'reverence for her': {'for her virtues': 1.0},
#  'for her virtues': {'her virtues and': 1.0},
#  'her virtues and': {'virtues and a': 1.0},
#  'virtues and a': {'and a desire': 1.0},
#  'and a desire': {'a desire to': 1.0},
#  'a desire to': {'desire to be': 0.3333333333333333,
#   'desire to see': 0.3333333333333333,
#   'desire to become': 0.3333333333333333},
#  'desire to be': {'to be the': 1.0},
#  'to be the': {'be the means': 0.125,
#   'be the world': 0.125,
#   'be the wanderings': 0.125,
#   'be the temptation': 0.125,
#   'be the murderer': 0.125,
#   'be the best': 0.125,
#   'be the elizabeth': 0.125,
#   'be the purport': 0.125},
#  'be the means': {'the means of': 1.0},
#  'the means of': {'means of in': 0.25,
#   'means of an': 0.25,
#   'means of obtaining': 0.25,
#   'means of materially': 0.25},
#  'means of in': {'of in some': 1.0},
#  'of in some': {'in some degree': 1.0},
#  'in some degree': {'some degree recompensing': 0.2,
#   'some degree consoled': 0.2,
#   'some degree also': 0.2,
#   'some degree beneficial': 0.2,
#   'some degree alarmed': 0.2},
#  'some degree recompensing': {'degree recompensing her': 1.0},
#  'degree recompensing her': {'recompensing her for': 1.0},
#  'recompensing her for': {'her for the': 1.0},
#  'her for the': {'for the sorrows': 1.0},
#  'for the sorrows': {'the sorrows she': 1.0},
#  'the sorrows she': {'sorrows she had': 1.0},
#  'sorrows she had': {'she had endured': 1.0},
#  'she had endured': {'had endured but': 1.0},
#  'had endured but': {'endured but which': 1.0},
#  'endured but which': {'but which gave': 1.0},
#  'but which gave': {'which gave inexpressible': 1.0},
#  'which gave inexpressible': {'gave inexpressible grace': 1.0},
#  'gave inexpressible grace': {'inexpressible grace to': 1.0},
#  'inexpressible grace to': {'grace to his': 1.0},
#  'grace to his': {'to his behaviour': 1.0},
#  'to his behaviour': {'his behaviour to': 1.0},
#  'his behaviour to': {'behaviour to everything': 1.0},
#  'behaviour to everything': {'to everything was': 1.0},
#  'to everything was': {'everything was made': 1.0},
#  'everything was made': {'was made to': 1.0},
#  'was made to': {'made to yield': 1.0},
#  'made to yield': {'to yield to': 1.0},
#  'to yield to': {'yield to her': 1.0},
#  'yield to her': {'to her wishes': 1.0},
#  'to her wishes': {'her wishes and': 1.0},
#  'her wishes and': {'wishes and her': 1.0},
#  'wishes and her': {'and her he': 1.0},
#  'and her he': {'her he strove': 1.0},
#  'her he strove': {'he strove to': 1.0},
#  'he strove to': {'strove to shelter': 1.0},
#  'strove to shelter': {'to shelter her': 1.0},
#  'to shelter her': {'shelter her as': 1.0},
#  'shelter her as': {'her as a': 1.0},
#  'her as a': {'as a fair': 1.0},
#  'as a fair': {'a fair exotic': 1.0},
#  'a fair exotic': {'fair exotic is': 1.0},
#  'fair exotic is': {'exotic is sheltered': 1.0},
#  'exotic is sheltered': {'is sheltered by': 1.0},
#  'is sheltered by': {'sheltered by the': 1.0},
#  'sheltered by the': {'by the gardener': 1.0},
#  'by the gardener': {'the gardener from': 1.0},
#  'the gardener from': {'gardener from every': 1.0},
#  'gardener from every': {'from every rougher': 1.0},
#  'from every rougher': {'every rougher wind': 1.0},
#  'every rougher wind': {'rougher wind and': 1.0},
#  'rougher wind and': {'wind and to': 1.0},
#  'wind and to': {'and to surround': 1.0},
#  'and to surround': {'to surround her': 1.0},
#  'to surround her': {'surround her with': 1.0},
#  'surround her with': {'her with all': 1.0},
#  'her with all': {'with all that': 1.0},
#  'with all that': {'all that could': 0.5, 'all that affection': 0.5},
#  'all that could': {'that could tend': 1.0},
#  'that could tend': {'could tend to': 1.0},
#  'could tend to': {'tend to excite': 1.0},
#  'tend to excite': {'to excite pleasurable': 1.0},
#  'to excite pleasurable': {'excite pleasurable emotion': 1.0},
#  'excite pleasurable emotion': {'pleasurable emotion in': 1.0},
#  'pleasurable emotion in': {'emotion in her': 1.0},
#  'emotion in her': {'in her soft': 1.0},
#  'in her soft': {'her soft and': 1.0},
#  'her soft and': {'soft and benevolent': 1.0},
#  'soft and benevolent': {'and benevolent her': 1.0},
#  'and benevolent her': {'benevolent her health': 1.0},
#  'benevolent her health': {'her health and': 1.0},
#  'her health and': {'health and even': 1.0},
#  'health and even': {'and even the': 1.0},
#  'and even the': {'even the tranquillity': 0.5, 'even the constant': 0.5},
#  'even the tranquillity': {'the tranquillity of': 1.0},
#  'the tranquillity of': {'tranquillity of her': 0.5,
#   'tranquillity of his': 0.5},
#  'tranquillity of her': {'of her hitherto': 1.0},
#  'of her hitherto': {'her hitherto constant': 1.0},
#  'her hitherto constant': {'hitherto constant spirit': 1.0},
#  'hitherto constant spirit': {'constant spirit had': 1.0},
#  'constant spirit had': {'spirit had been': 1.0},
#  'spirit had been': {'had been shaken': 1.0},
#  'had been shaken': {'been shaken by': 1.0},
#  'been shaken by': {'shaken by what': 1.0},
#  'shaken by what': {'by what she': 1.0},
#  'by what she': {'what she had': 1.0},
#  'what she had': {'she had gone': 0.5, 'she had suffered': 0.5},
#  'she had gone': {'had gone during': 0.5, 'had gone near': 0.5},
#  'had gone during': {'gone during the': 1.0},
#  'gone during the': {'during the two': 1.0},
#  'during the two': {'the two years': 1.0},
#  'the two years': {'two years that': 1.0},
#  'two years that': {'years that had': 1.0},
#  'years that had': {'that had elapsed': 1.0},
#  'that had elapsed': {'had elapsed previous': 1.0},
#  'had elapsed previous': {'elapsed previous to': 1.0},
#  'elapsed previous to': {'previous to their': 1.0},
#  'previous to their': {'to their marriage': 1.0},
#  'to their marriage': {'their marriage my': 1.0},
#  'their marriage my': {'marriage my father': 1.0},
#  'marriage my father': {'my father had': 1.0},
#  'father had gradually': {'had gradually relinquished': 1.0},
#  'had gradually relinquished': {'gradually relinquished all': 1.0},
#  'gradually relinquished all': {'relinquished all his': 1.0},
#  'relinquished all his': {'all his public': 1.0},
#  'all his public': {'his public functions': 1.0},
#  'his public functions': {'public functions and': 1.0},
#  'public functions and': {'functions and immediately': 1.0},
#  'functions and immediately': {'and immediately after': 1.0},
#  'and immediately after': {'immediately after their': 1.0},
#  'immediately after their': {'after their union': 1.0},
#  'after their union': {'their union they': 1.0},
#  'their union they': {'union they sought': 1.0},
#  'union they sought': {'they sought the': 1.0},
#  'they sought the': {'sought the pleasant': 1.0},
#  'sought the pleasant': {'the pleasant climate': 1.0},
#  'the pleasant climate': {'pleasant climate of': 1.0},
#  'pleasant climate of': {'climate of italy': 1.0},
#  'climate of italy': {'of italy and': 1.0},
#  'of italy and': {'italy and the': 1.0},
#  'italy and the': {'and the change': 1.0},
#  'and the change': {'the change of': 0.5, 'the change was': 0.5},
#  'the change of': {'change of scene': 1.0},
#  'change of scene': {'of scene and': 1.0},
#  'of scene and': {'scene and interest': 0.5, 'scene and varied': 0.5},
#  'scene and interest': {'and interest attendant': 1.0},
#  'and interest attendant': {'interest attendant on': 1.0},
#  'interest attendant on': {'attendant on a': 1.0},
#  'attendant on a': {'on a tour': 1.0},
#  'on a tour': {'a tour through': 1.0},
#  'a tour through': {'tour through that': 1.0},
#  'tour through that': {'through that land': 1.0},
#  'through that land': {'that land of': 1.0},
#  'that land of': {'land of wonders': 1.0},
#  'land of wonders': {'of wonders as': 1.0},
#  'of wonders as': {'wonders as a': 1.0},
#  'wonders as a': {'as a restorative': 1.0},
#  'as a restorative': {'a restorative for': 1.0},
#  'a restorative for': {'restorative for her': 1.0},
#  'restorative for her': {'for her weakened': 1.0},
#  'for her weakened': {'her weakened frame': 1.0},
#  'her weakened frame': {'weakened frame from': 1.0},
#  'weakened frame from': {'frame from italy': 1.0},
#  'frame from italy': {'from italy they': 1.0},
#  'from italy they': {'italy they visited': 1.0},
#  'italy they visited': {'they visited germany': 1.0},
#  'they visited germany': {'visited germany and': 1.0},
#  'visited germany and': {'germany and i': 1.0},
#  'germany and i': {'and i their': 1.0},
#  'and i their': {'i their eldest': 1.0},
#  'i their eldest': {'their eldest child': 1.0},
#  'their eldest child': {'eldest child was': 1.0},
#  'eldest child was': {'child was born': 0.5, 'child was but': 0.5},
#  'child was born': {'was born at': 1.0},
#  'was born at': {'born at naples': 1.0},
#  'born at naples': {'at naples and': 1.0},
#  'at naples and': {'naples and as': 1.0},
#  'naples and as': {'and as an': 1.0},
#  'and as an': {'as an infant': 1.0},
#  'as an infant': {'an infant accompanied': 1.0},
#  'an infant accompanied': {'infant accompanied them': 1.0},
#  'infant accompanied them': {'accompanied them in': 1.0},
#  'accompanied them in': {'them in their': 1.0},
#  'them in their': {'in their i': 0.5, 'in their cloudy': 0.5},
#  'in their i': {'their i remained': 0.5, 'their i saw': 0.5},
#  'their i remained': {'i remained for': 1.0},
#  'i remained for': {'remained for several': 1.0},
#  'remained for several': {'for several years': 1.0},
#  'for several years': {'several years their': 1.0},
#  'several years their': {'years their only': 1.0},
#  'years their only': {'their only much': 1.0},
#  'their only much': {'only much as': 1.0},
#  'only much as': {'much as they': 1.0},
#  'much as they': {'as they were': 1.0},
#  'as they were': {'they were attached': 0.3333333333333333,
#   'they were unfolded': 0.3333333333333333,
#   'they were as': 0.3333333333333333},
#  'they were attached': {'were attached to': 1.0},
#  'were attached to': {'attached to each': 1.0},
#  'attached to each': {'to each other': 1.0},
#  'to each other': {'each other they': 0.3333333333333333,
#   'each other here': 0.3333333333333333,
#   'each other from': 0.3333333333333333},
#  'each other they': {'other they seemed': 1.0},
#  'other they seemed': {'they seemed to': 1.0},
#  'they seemed to': {'seemed to draw': 1.0},
#  'seemed to draw': {'to draw inexhaustible': 1.0},
#  'to draw inexhaustible': {'draw inexhaustible stores': 1.0},
#  'draw inexhaustible stores': {'inexhaustible stores of': 1.0},
#  'inexhaustible stores of': {'stores of affection': 1.0},
#  'stores of affection': {'of affection from': 1.0},
#  'of affection from': {'affection from a': 0.5, 'affection from thine': 0.5},
#  'affection from a': {'from a very': 1.0},
#  'from a very': {'a very mine': 1.0},
#  'a very mine': {'very mine of': 1.0},
#  'very mine of': {'mine of love': 1.0},
#  'mine of love': {'of love to': 1.0},
#  'of love to': {'love to bestow': 0.5, 'love to soften': 0.5},
#  'love to bestow': {'to bestow them': 1.0},
#  'to bestow them': {'bestow them upon': 1.0},
#  'bestow them upon': {'them upon my': 1.0},
#  'them upon my': {'upon my mothers': 1.0},
#  'upon my mothers': {'my mothers tender': 1.0},
#  'my mothers tender': {'mothers tender caresses': 1.0},
#  'mothers tender caresses': {'tender caresses and': 1.0},
#  'tender caresses and': {'caresses and my': 1.0},
#  'caresses and my': {'and my fathers': 1.0},
#  'and my fathers': {'my fathers smile': 0.5, 'my fathers woe': 0.5},
#  'my fathers smile': {'fathers smile of': 1.0},
#  'fathers smile of': {'smile of benevolent': 1.0},
#  'smile of benevolent': {'of benevolent pleasure': 1.0},
#  'of benevolent pleasure': {'benevolent pleasure while': 1.0},
#  'benevolent pleasure while': {'pleasure while regarding': 1.0},
#  'pleasure while regarding': {'while regarding me': 1.0},
#  'while regarding me': {'regarding me are': 1.0},
#  'regarding me are': {'me are my': 1.0},
#  'me are my': {'are my first': 1.0},
#  'are my first': {'my first i': 1.0},
#  'my first i': {'first i was': 1.0},
#  'first i was': {'i was their': 0.5, 'i was unable': 0.5},
#  'i was their': {'was their plaything': 0.5, 'was their only': 0.5},
#  'was their plaything': {'their plaything and': 1.0},
#  'their plaything and': {'plaything and their': 1.0},
#  'plaything and their': {'and their idol': 1.0},
#  'and their idol': {'their idol and': 1.0},
#  'their idol and': {'idol and something': 1.0},
#  'idol and something': {'and something better': 1.0},
#  'and something better': {'something better their': 1.0},
#  'something better their': {'better their child': 1.0},
#  'better their child': {'their child the': 1.0},
#  'their child the': {'child the innocent': 1.0},
#  'child the innocent': {'the innocent and': 1.0},
#  'the innocent and': {'innocent and helpless': 1.0},
#  'innocent and helpless': {'and helpless creature': 1.0},
#  'and helpless creature': {'helpless creature bestowed': 1.0},
#  'helpless creature bestowed': {'creature bestowed on': 1.0},
#  'creature bestowed on': {'bestowed on them': 1.0},
#  'bestowed on them': {'on them by': 1.0},
#  'on them by': {'them by heaven': 1.0},
#  'them by heaven': {'by heaven whom': 1.0},
#  'by heaven whom': {'heaven whom to': 1.0},
#  'heaven whom to': {'whom to bring': 1.0},
#  'whom to bring': {'to bring up': 1.0},
#  'to bring up': {'bring up to': 1.0},
#  'bring up to': {'up to good': 1.0},
#  'up to good': {'to good and': 1.0},
#  'to good and': {'good and whose': 1.0},
#  'good and whose': {'and whose future': 1.0},
#  'and whose future': {'whose future lot': 1.0},
#  'whose future lot': {'future lot it': 1.0},
#  'future lot it': {'lot it was': 1.0},
#  'lot it was': {'it was in': 1.0},
#  'it was in': {'was in their': 0.2,
#   'was in vain': 0.2,
#   'was in my': 0.4,
#   'was in the': 0.2},
#  'was in their': {'in their hands': 1.0},
#  'in their hands': {'their hands to': 1.0},
#  'their hands to': {'hands to direct': 1.0},
#  'hands to direct': {'to direct to': 1.0},
#  'to direct to': {'direct to happiness': 1.0},
#  'direct to happiness': {'to happiness or': 1.0},
#  'to happiness or': {'happiness or misery': 1.0},
#  'happiness or misery': {'or misery according': 1.0},
#  'or misery according': {'misery according as': 1.0},
#  'misery according as': {'according as they': 1.0},
#  'according as they': {'as they fulfilled': 1.0},
#  'as they fulfilled': {'they fulfilled their': 1.0},
#  'they fulfilled their': {'fulfilled their duties': 1.0},
#  'fulfilled their duties': {'their duties towards': 1.0},
#  'their duties towards': {'duties towards with': 1.0},
#  'duties towards with': {'towards with this': 1.0},
#  'towards with this': {'with this deep': 1.0},
#  'with this deep': {'this deep consciousness': 1.0},
#  'this deep consciousness': {'deep consciousness of': 1.0},
#  'deep consciousness of': {'consciousness of what': 1.0},
#  'consciousness of what': {'of what they': 1.0},
#  'of what they': {'what they owed': 1.0},
#  'what they owed': {'they owed towards': 1.0},
#  'they owed towards': {'owed towards the': 1.0},
#  'owed towards the': {'towards the being': 1.0},
#  'towards the being': {'the being to': 1.0},
#  'the being to': {'being to which': 0.5, 'being to whom': 0.5},
#  'being to which': {'to which they': 1.0},
#  'to which they': {'which they had': 1.0},
#  'which they had': {'they had given': 0.5, 'they had lived': 0.5},
#  'they had given': {'had given life': 1.0},
#  'had given life': {'given life added': 1.0},
#  'given life added': {'life added to': 1.0},
#  'life added to': {'added to the': 1.0},
#  'added to the': {'to the active': 0.5, 'to the melancholy': 0.5},
#  'to the active': {'the active spirit': 1.0},
#  'the active spirit': {'active spirit of': 1.0},
#  'active spirit of': {'spirit of tenderness': 1.0},
#  'spirit of tenderness': {'of tenderness that': 1.0},
#  'of tenderness that': {'tenderness that animated': 1.0},
#  'tenderness that animated': {'that animated both': 1.0},
#  'that animated both': {'animated both it': 1.0},
#  'animated both it': {'both it may': 1.0},
#  'both it may': {'it may be': 1.0},
#  'it may be': {'may be imagined': 0.25,
#   'may be deemed': 0.25,
#   'may be easily': 0.25,
#   'may be called': 0.25},
#  'may be imagined': {'be imagined that': 1.0},
#  'be imagined that': {'imagined that while': 1.0},
#  'imagined that while': {'that while during': 1.0},
#  'that while during': {'while during every': 1.0},
#  'while during every': {'during every hour': 1.0},
#  'during every hour': {'every hour of': 1.0},
#  'every hour of': {'hour of my': 1.0},
#  'hour of my': {'of my infant': 0.5, 'of my irresolution': 0.5},
#  'of my infant': {'my infant life': 1.0},
#  'my infant life': {'infant life i': 1.0},
#  'infant life i': {'life i received': 1.0},
#  'life i received': {'i received a': 1.0},
#  'i received a': {'received a lesson': 1.0},
#  'received a lesson': {'a lesson of': 1.0},
#  'a lesson of': {'lesson of patience': 1.0},
#  'lesson of patience': {'of patience of': 1.0},
#  'of patience of': {'patience of charity': 1.0},
#  'patience of charity': {'of charity and': 1.0},
#  'of charity and': {'charity and of': 1.0},
#  'charity and of': {'and of i': 1.0},
#  'and of i': {'of i was': 1.0},
#  'of i was': {'i was so': 0.16666666666666666,
#   'i was new': 0.16666666666666666,
#   'i was troubled': 0.16666666666666666,
#   'i was a': 0.16666666666666666,
#   'i was besides': 0.16666666666666666,
#   'i was nourished': 0.16666666666666666},
#  'i was so': {'was so guided': 0.5, 'was so frightful': 0.5},
#  'was so guided': {'so guided by': 1.0},
#  'so guided by': {'guided by a': 1.0},
#  'guided by a': {'by a silken': 0.5, 'by a slight': 0.5},
#  'by a silken': {'a silken cord': 1.0},
#  'a silken cord': {'silken cord that': 1.0},
#  'silken cord that': {'cord that all': 1.0},
#  'cord that all': {'that all seemed': 1.0},
#  'that all seemed': {'all seemed but': 1.0},
#  'all seemed but': {'seemed but one': 1.0},
#  'seemed but one': {'but one train': 1.0},
#  'but one train': {'one train of': 1.0},
#  'one train of': {'train of enjoyment': 1.0},
#  'train of enjoyment': {'of enjoyment to': 1.0},
#  'of enjoyment to': {'enjoyment to for': 1.0},
#  'enjoyment to for': {'to for a': 1.0},
#  'to for a': {'for a long': 1.0},
#  ...}

# %% [markdown]
# Increasing the number of engrams increases the number of possible combinations of words that are considered as "states" in the Markov model. \
# For example, with 1 engram (or unigram), every single word is considered a state. So if you have a text with N different words, you will have approximately N states in your model. \
# With 2 engrams (bigrams), the states are pairs of consecutive words. So, if you have a text with N different words, you will have approximately N^2 states in your model.
#
# As the number of engrams increases, the context considered to predict the next word increases, but the complexity of the model also increases, as the number of possible combinations grows exponentially relative to the number of words in the text.

# %%
# def function
def generate_text(markov_model, limit = 100, start='i am'):
   n = 0
   curr_state = start
   next_state = None
   phrase = ""
   phrase += curr_state + " " # initialise variables before the while loop
   while n<limit:
      # randomly select a state from the possible next states with prob evaluate in Markov Model with random.choice()
      next_state = random.choices(list(markov_model[curr_state].keys()), list(markov_model[curr_state].values()))
      curr_state = next_state[0]
      phrase += curr_state + " "
      n += 1 # update the states
   return phrase

# %%
# try sometimes and see how the model work
for i in range(6):
   print(str(i)+".\t", generate_text(MC4,start= 'by birth a genevese', limit=8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 # try sometimes and see how the model work
#       2 for i in range(6):
# ----> 3    print(str(i)+".\t", generate_text(MC4,start= 'by birth a genevese', limit=8))
#
# Cell In[11], line 10, in generate_text(markov_model, limit, start)
#       7 phrase += curr_state + " " # initialise variables before the while loop
#       8 while n<limit:
#       9    # randomly select a state from the possible next states with prob evaluate in Markov Model with random.choice()
# ---> 10    next_state = random.choices(list(markov_model[curr_state].keys()), list(markov_model[curr_state].values()))
#      11    curr_state = next_state[0]
#      12    phrase += curr_state + " "
#
# KeyError: 'by birth a genevese'

# %% [markdown]
# ## Second try

# %% [markdown]
# here we have a problem: words are not well concatenated because of repetitions. We need to find a solution and modify the model

# %%
def MC_model(cleaned_txt, n_gram=4):
    markov_model = {}
    for i in range(len(cleaned_txt)-n_gram):
        curr_state, next_state = "", ""
        for j in range(n_gram):
            curr_state += cleaned_txt[i+j] + " "
            if j < n_gram - 1:
                next_state += cleaned_txt[i+j+1] + " "
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if curr_state not in markov_model:
            markov_model[curr_state] = {}
            markov_model[curr_state][next_state] = 1
        else:
            if next_state in markov_model[curr_state]:
                markov_model[curr_state][next_state] += 1
            else:
                markov_model[curr_state][next_state] = 1
    
    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count / total
        
    return markov_model

# %%
# def function
def generate_text(markov_model, limit = 100, start='i am'):
   n = 0
   curr_state = start
   next_state = None
   phrase = ""
   phrase += curr_state + " " # initialise variables before the while loop
   while n<limit:
      # randomly select a state from the possible next states with prob evaluate in Markov Model with random.choice()
      next_state = random.choices(list(markov_model[curr_state].keys()), list(markov_model[curr_state].values()))
      curr_state = next_state[0]
      phrase += curr_state + " "
      n += 1 # update the states
   return phrase

# %%
# testing model1 by uploading ours tokenized words list 
MC4 = MC_model(cleaned_txt)
print(f'Number of states:',len(MC4))
# display(MC4)
# Out:
# Number of states: 66230

# %%
display(MC4)
# Out:
# {'chapter i am': {'i am by': 1.0},
#  'i am by': {'am by birth': 0.5, 'am by a': 0.5},
#  'am by birth': {'by birth a': 1.0},
#  'by birth a': {'birth a genevese': 1.0},
#  'birth a genevese': {'a genevese and': 1.0},
#  'a genevese and': {'genevese and my': 1.0},
#  'genevese and my': {'and my family': 1.0},
#  'and my family': {'my family is': 0.5, 'my family have': 0.5},
#  'my family is': {'family is one': 1.0},
#  'family is one': {'is one of': 1.0},
#  'is one of': {'one of the': 0.5, 'one of those': 0.5},
#  'one of the': {'of the most': 0.058823529411764705,
#   'of the phenomena': 0.058823529411764705,
#   'of the servants': 0.058823529411764705,
#   'of the others': 0.058823529411764705,
#   'of the trees': 0.058823529411764705,
#   'of the best': 0.11764705882352941,
#   'of the women': 0.058823529411764705,
#   'of the windows': 0.058823529411764705,
#   'of the causes': 0.058823529411764705,
#   'of the first': 0.11764705882352941,
#   'of the folds': 0.058823529411764705,
#   'of the remotest': 0.058823529411764705,
#   'of the peasants': 0.058823529411764705,
#   'of the men': 0.058823529411764705,
#   'of the turnkeys': 0.058823529411764705},
#  'of the most': {'the most distinguished': 0.2857142857142857,
#   'the most familiar': 0.14285714285714285,
#   'the most miserable': 0.14285714285714285,
#   'the most terrible': 0.14285714285714285,
#   'the most horrible': 0.14285714285714285,
#   'the most hardy': 0.14285714285714285},
#  'the most distinguished': {'most distinguished of': 0.3333333333333333,
#   'most distinguished he': 0.3333333333333333,
#   'most distinguished natural': 0.3333333333333333},
#  'most distinguished of': {'distinguished of that': 1.0},
#  'distinguished of that': {'of that my': 1.0},
#  'of that my': {'that my ancestors': 1.0},
#  'that my ancestors': {'my ancestors had': 1.0},
#  'my ancestors had': {'ancestors had been': 1.0},
#  'ancestors had been': {'had been for': 1.0},
#  'had been for': {'been for many': 1.0},
#  'been for many': {'for many years': 0.5, 'for many months': 0.5},
#  'for many years': {'many years counsellors': 0.25,
#   'many years and': 0.25,
#   'many years in': 0.25,
#   'many years when': 0.25},
#  'many years counsellors': {'years counsellors and': 1.0},
#  'years counsellors and': {'counsellors and syndics': 1.0},
#  'counsellors and syndics': {'and syndics and': 1.0},
#  'and syndics and': {'syndics and my': 1.0},
#  'syndics and my': {'and my father': 1.0},
#  'and my father': {'my father had': 0.3333333333333333,
#   'my father continued': 0.3333333333333333,
#   'my father i': 0.3333333333333333},
#  'my father had': {'father had filled': 0.14285714285714285,
#   'father had gradually': 0.14285714285714285,
#   'father had gone': 0.14285714285714285,
#   'father had taken': 0.42857142857142855,
#   'father had often': 0.14285714285714285},
#  'father had filled': {'had filled several': 1.0},
#  'had filled several': {'filled several public': 1.0},
#  'filled several public': {'several public situations': 1.0},
#  'several public situations': {'public situations with': 1.0},
#  'public situations with': {'situations with honour': 1.0},
#  'situations with honour': {'with honour and': 1.0},
#  'with honour and': {'honour and he': 1.0},
#  'honour and he': {'and he was': 1.0},
#  'and he was': {'he was respected': 0.5, 'he was also': 0.5},
#  'he was respected': {'was respected by': 1.0},
#  'was respected by': {'respected by all': 1.0},
#  'respected by all': {'by all who': 1.0},
#  'by all who': {'all who knew': 1.0},
#  'all who knew': {'who knew him': 0.5, 'who knew her': 0.5},
#  'who knew him': {'knew him for': 1.0},
#  'knew him for': {'him for his': 1.0},
#  'him for his': {'for his integrity': 1.0},
#  'for his integrity': {'his integrity and': 1.0},
#  'his integrity and': {'integrity and indefatigable': 1.0},
#  'integrity and indefatigable': {'and indefatigable attention': 1.0},
#  'and indefatigable attention': {'indefatigable attention to': 1.0},
#  'indefatigable attention to': {'attention to public': 1.0},
#  'attention to public': {'to public he': 1.0},
#  'to public he': {'public he passed': 1.0},
#  'public he passed': {'he passed his': 1.0},
#  'he passed his': {'passed his younger': 1.0},
#  'passed his younger': {'his younger days': 1.0},
#  'his younger days': {'younger days perpetually': 1.0},
#  'younger days perpetually': {'days perpetually occupied': 1.0},
#  'days perpetually occupied': {'perpetually occupied by': 1.0},
#  'perpetually occupied by': {'occupied by the': 1.0},
#  'occupied by the': {'by the affairs': 1.0},
#  'by the affairs': {'the affairs of': 1.0},
#  'the affairs of': {'affairs of his': 1.0},
#  'affairs of his': {'of his country': 1.0},
#  'of his country': {'his country a': 0.5, 'his country and': 0.5},
#  'his country a': {'country a variety': 1.0},
#  'country a variety': {'a variety of': 1.0},
#  'a variety of': {'variety of circumstances': 0.5,
#   'variety of combustibles': 0.5},
#  'variety of circumstances': {'of circumstances had': 1.0},
#  'of circumstances had': {'circumstances had prevented': 1.0},
#  'circumstances had prevented': {'had prevented his': 1.0},
#  'had prevented his': {'prevented his marrying': 1.0},
#  'prevented his marrying': {'his marrying early': 1.0},
#  'his marrying early': {'marrying early nor': 1.0},
#  'marrying early nor': {'early nor was': 1.0},
#  'early nor was': {'nor was it': 1.0},
#  'nor was it': {'was it until': 1.0},
#  'was it until': {'it until the': 1.0},
#  'it until the': {'until the decline': 1.0},
#  'until the decline': {'the decline of': 1.0},
#  'the decline of': {'decline of life': 0.6666666666666666,
#   'decline of that': 0.3333333333333333},
#  'decline of life': {'of life that': 0.5, 'of life having': 0.5},
#  'of life that': {'life that he': 1.0},
#  'life that he': {'that he became': 1.0},
#  'that he became': {'he became a': 1.0},
#  'he became a': {'became a husband': 1.0},
#  'became a husband': {'a husband and': 1.0},
#  'a husband and': {'husband and the': 0.5, 'husband and lovely': 0.5},
#  'husband and the': {'and the father': 1.0},
#  'and the father': {'the father of': 1.0},
#  'the father of': {'father of a': 0.25,
#   'father of their': 0.25,
#   'father of safie': 0.5},
#  'father of a': {'of a family': 1.0},
#  'of a family': {'a family as': 1.0},
#  'a family as': {'family as the': 1.0},
#  'family as the': {'as the circumstances': 1.0},
#  'as the circumstances': {'the circumstances of': 1.0},
#  'the circumstances of': {'circumstances of his': 0.5,
#   'circumstances of the': 0.5},
#  'circumstances of his': {'of his marriage': 1.0},
#  'of his marriage': {'his marriage illustrate': 1.0},
#  'his marriage illustrate': {'marriage illustrate his': 1.0},
#  'marriage illustrate his': {'illustrate his character': 1.0},
#  'illustrate his character': {'his character i': 1.0},
#  'his character i': {'character i can': 1.0},
#  'character i can': {'i can not': 1.0},
#  'i can not': {'can not refrain': 0.045454545454545456,
#   'can not pretend': 0.045454545454545456,
#   'can not go': 0.045454545454545456,
#   'can not live': 0.045454545454545456,
#   'can not describe': 0.18181818181818182,
#   'can not inspire': 0.045454545454545456,
#   'can not consent': 0.045454545454545456,
#   'can not do': 0.045454545454545456,
#   'can not see': 0.045454545454545456,
#   'can not sometimes': 0.045454545454545456,
#   'can not guess': 0.045454545454545456,
#   'can not doubt': 0.045454545454545456,
#   'can not recollect': 0.045454545454545456,
#   'can not forbear': 0.045454545454545456,
#   'can not withstand': 0.045454545454545456,
#   'can not lead': 0.045454545454545456,
#   'can not ask': 0.045454545454545456,
#   'can not find': 0.045454545454545456,
#   'can not believe': 0.045454545454545456},
#  'can not refrain': {'not refrain from': 1.0},
#  'not refrain from': {'refrain from relating': 1.0},
#  'refrain from relating': {'from relating one': 1.0},
#  'from relating one': {'relating one of': 1.0},
#  'relating one of': {'one of his': 1.0},
#  'one of his': {'of his most': 0.5, 'of his own': 0.5},
#  'of his most': {'his most intimate': 1.0},
#  'his most intimate': {'most intimate friends': 1.0},
#  'most intimate friends': {'intimate friends was': 1.0},
#  'intimate friends was': {'friends was a': 1.0},
#  'friends was a': {'was a merchant': 1.0},
#  'was a merchant': {'a merchant who': 1.0},
#  'a merchant who': {'merchant who from': 1.0},
#  'merchant who from': {'who from a': 1.0},
#  'who from a': {'from a flourishing': 1.0},
#  'from a flourishing': {'a flourishing state': 1.0},
#  'a flourishing state': {'flourishing state fell': 1.0},
#  'flourishing state fell': {'state fell through': 1.0},
#  'state fell through': {'fell through numerous': 1.0},
#  'fell through numerous': {'through numerous mischances': 1.0},
#  'through numerous mischances': {'numerous mischances into': 1.0},
#  'numerous mischances into': {'mischances into this': 1.0},
#  'mischances into this': {'into this man': 1.0},
#  'into this man': {'this man whose': 1.0},
#  'this man whose': {'man whose name': 1.0},
#  'man whose name': {'whose name was': 1.0},
#  'whose name was': {'name was beaufort': 1.0},
#  'name was beaufort': {'was beaufort was': 1.0},
#  'was beaufort was': {'beaufort was of': 1.0},
#  'beaufort was of': {'was of a': 1.0},
#  'was of a': {'of a proud': 0.25,
#   'of a calmer': 0.25,
#   'of a nature': 0.25,
#   'of a lustrous': 0.25},
#  'of a proud': {'a proud and': 1.0},
#  'a proud and': {'proud and unbending': 1.0},
#  'proud and unbending': {'and unbending disposition': 1.0},
#  'and unbending disposition': {'unbending disposition and': 1.0},
#  'unbending disposition and': {'disposition and could': 1.0},
#  'disposition and could': {'and could not': 1.0},
#  'and could not': {'could not bear': 0.3333333333333333,
#   'could not such': 0.3333333333333333,
#   'could not free': 0.3333333333333333},
#  'could not bear': {'not bear to': 1.0},
#  'not bear to': {'bear to live': 1.0},
#  'bear to live': {'to live in': 1.0},
#  'to live in': {'live in poverty': 1.0},
#  'live in poverty': {'in poverty and': 1.0},
#  'in poverty and': {'poverty and oblivion': 0.5, 'poverty and want': 0.5},
#  'poverty and oblivion': {'and oblivion in': 1.0},
#  'and oblivion in': {'oblivion in the': 1.0},
#  'oblivion in the': {'in the same': 1.0},
#  'in the same': {'the same country': 0.08333333333333333,
#   'the same pursuit': 0.08333333333333333,
#   'the same place': 0.16666666666666666,
#   'the same house': 0.08333333333333333,
#   'the same manner': 0.25,
#   'the same routine': 0.08333333333333333,
#   'the same language': 0.08333333333333333,
#   'the same incoherent': 0.08333333333333333,
#   'the same ship': 0.08333333333333333},
#  'the same country': {'same country where': 1.0},
#  'same country where': {'country where he': 1.0},
#  'country where he': {'where he had': 1.0},
#  'where he had': {'he had formerly': 0.3333333333333333,
#   'he had lived': 0.3333333333333333,
#   'he had disappeared': 0.3333333333333333},
#  'he had formerly': {'had formerly been': 1.0},
#  'had formerly been': {'formerly been distinguished': 0.5,
#   'formerly been our': 0.5},
#  'formerly been distinguished': {'been distinguished for': 1.0},
#  'been distinguished for': {'distinguished for his': 1.0},
#  'distinguished for his': {'for his rank': 1.0},
#  'for his rank': {'his rank and': 1.0},
#  'his rank and': {'rank and having': 1.0},
#  'rank and having': {'and having paid': 1.0},
#  'and having paid': {'having paid his': 1.0},
#  'having paid his': {'paid his debts': 1.0},
#  'paid his debts': {'his debts therefore': 1.0},
#  'his debts therefore': {'debts therefore in': 1.0},
#  'debts therefore in': {'therefore in the': 1.0},
#  'therefore in the': {'in the most': 1.0},
#  'in the most': {'the most honourable': 0.09090909090909091,
#   'the most melancholy': 0.09090909090909091,
#   'the most comprehensive': 0.09090909090909091,
#   'the most interesting': 0.09090909090909091,
#   'the most cordial': 0.09090909090909091,
#   'the most beautiful': 0.09090909090909091,
#   'the most ardent': 0.09090909090909091,
#   'the most savage': 0.09090909090909091,
#   'the most perfect': 0.09090909090909091,
#   'the most detestable': 0.09090909090909091,
#   'the most imminent': 0.09090909090909091},
#  'the most honourable': {'most honourable manner': 1.0},
#  'most honourable manner': {'honourable manner he': 1.0},
#  'honourable manner he': {'manner he retreated': 1.0},
#  'manner he retreated': {'he retreated with': 1.0},
#  'he retreated with': {'retreated with his': 1.0},
#  'retreated with his': {'with his daughter': 1.0},
#  'with his daughter': {'his daughter to': 0.3333333333333333,
#   'his daughter in': 0.3333333333333333,
#   'his daughter insultingly': 0.3333333333333333},
#  'his daughter to': {'daughter to the': 0.5, 'daughter to think': 0.5},
#  'daughter to the': {'to the town': 1.0},
#  'to the town': {'the town of': 0.5, 'the town for': 0.5},
#  'the town of': {'town of lucerne': 0.5, 'town of from': 0.5},
#  'town of lucerne': {'of lucerne where': 1.0},
#  'of lucerne where': {'lucerne where he': 1.0},
#  'lucerne where he': {'where he lived': 1.0},
#  'where he lived': {'he lived unknown': 1.0},
#  'he lived unknown': {'lived unknown and': 1.0},
#  'lived unknown and': {'unknown and in': 1.0},
#  'unknown and in': {'and in my': 1.0},
#  'and in my': {'in my father': 0.3333333333333333,
#   'in my condition': 0.3333333333333333,
#   'in my dying': 0.3333333333333333},
#  'in my father': {'my father loved': 1.0},
#  'my father loved': {'father loved beaufort': 1.0},
#  'father loved beaufort': {'loved beaufort with': 1.0},
#  'loved beaufort with': {'beaufort with the': 1.0},
#  'beaufort with the': {'with the truest': 1.0},
#  'with the truest': {'the truest friendship': 1.0},
#  'the truest friendship': {'truest friendship and': 1.0},
#  'truest friendship and': {'friendship and was': 1.0},
#  'friendship and was': {'and was deeply': 1.0},
#  'and was deeply': {'was deeply grieved': 1.0},
#  'was deeply grieved': {'deeply grieved by': 1.0},
#  'deeply grieved by': {'grieved by his': 1.0},
#  'grieved by his': {'by his retreat': 1.0},
#  'by his retreat': {'his retreat in': 1.0},
#  'his retreat in': {'retreat in these': 1.0},
#  'retreat in these': {'in these unfortunate': 1.0},
#  'in these unfortunate': {'these unfortunate circumstances': 1.0},
#  'these unfortunate circumstances': {'unfortunate circumstances he': 1.0},
#  'unfortunate circumstances he': {'circumstances he bitterly': 1.0},
#  'circumstances he bitterly': {'he bitterly deplored': 1.0},
#  'he bitterly deplored': {'bitterly deplored the': 1.0},
#  'bitterly deplored the': {'deplored the false': 1.0},
#  'deplored the false': {'the false pride': 1.0},
#  'the false pride': {'false pride which': 1.0},
#  'false pride which': {'pride which led': 1.0},
#  'pride which led': {'which led his': 1.0},
#  'which led his': {'led his friend': 1.0},
#  'led his friend': {'his friend to': 1.0},
#  'his friend to': {'friend to a': 1.0},
#  'friend to a': {'to a conduct': 1.0},
#  'to a conduct': {'a conduct so': 1.0},
#  'a conduct so': {'conduct so little': 1.0},
#  'conduct so little': {'so little worthy': 1.0},
#  'so little worthy': {'little worthy of': 1.0},
#  'little worthy of': {'worthy of the': 1.0},
#  'worthy of the': {'of the affection': 1.0},
#  'of the affection': {'the affection that': 1.0},
#  'the affection that': {'affection that united': 1.0},
#  'affection that united': {'that united he': 1.0},
#  'that united he': {'united he lost': 1.0},
#  'united he lost': {'he lost no': 1.0},
#  'he lost no': {'lost no time': 1.0},
#  'lost no time': {'no time in': 1.0},
#  'no time in': {'time in endeavouring': 1.0},
#  'time in endeavouring': {'in endeavouring to': 1.0},
#  'in endeavouring to': {'endeavouring to seek': 0.5,
#   'endeavouring to bestow': 0.5},
#  'endeavouring to seek': {'to seek him': 0.5, 'to seek a': 0.5},
#  'to seek him': {'seek him out': 1.0},
#  'seek him out': {'him out with': 1.0},
#  'him out with': {'out with the': 1.0},
#  'out with the': {'with the hope': 1.0},
#  'with the hope': {'the hope of': 1.0},
#  'the hope of': {'hope of persuading': 0.5, 'hope of night': 0.5},
#  'hope of persuading': {'of persuading him': 1.0},
#  'of persuading him': {'persuading him to': 1.0},
#  'persuading him to': {'him to begin': 1.0},
#  'him to begin': {'to begin the': 1.0},
#  'to begin the': {'begin the world': 1.0},
#  'begin the world': {'the world again': 1.0},
#  'the world again': {'world again through': 1.0},
#  'world again through': {'again through his': 1.0},
#  'again through his': {'through his credit': 1.0},
#  'through his credit': {'his credit and': 1.0},
#  'his credit and': {'credit and beaufort': 1.0},
#  'credit and beaufort': {'and beaufort had': 1.0},
#  'and beaufort had': {'beaufort had taken': 1.0},
#  'beaufort had taken': {'had taken effectual': 1.0},
#  'had taken effectual': {'taken effectual measures': 1.0},
#  'taken effectual measures': {'effectual measures to': 1.0},
#  'effectual measures to': {'measures to conceal': 1.0},
#  'measures to conceal': {'to conceal himself': 1.0},
#  'to conceal himself': {'conceal himself and': 1.0},
#  'conceal himself and': {'himself and it': 1.0},
#  'himself and it': {'and it was': 1.0},
#  'and it was': {'it was ten': 0.1,
#   'it was with': 0.2,
#   'it was indeed': 0.1,
#   'it was judged': 0.1,
#   'it was understood': 0.1,
#   'it was now': 0.1,
#   'it was likely': 0.1,
#   'it was he': 0.1,
#   'it was during': 0.1},
#  'it was ten': {'was ten months': 1.0},
#  'was ten months': {'ten months before': 1.0},
#  'ten months before': {'months before my': 1.0},
#  'months before my': {'before my father': 0.5, 'before my arrival': 0.5},
#  'before my father': {'my father discovered': 1.0},
#  'my father discovered': {'father discovered his': 1.0},
#  'father discovered his': {'discovered his overjoyed': 1.0},
#  'discovered his overjoyed': {'his overjoyed at': 1.0},
#  'his overjoyed at': {'overjoyed at this': 1.0},
#  'overjoyed at this': {'at this discovery': 1.0},
#  'at this discovery': {'this discovery he': 1.0},
#  'this discovery he': {'discovery he hastened': 1.0},
#  'discovery he hastened': {'he hastened to': 1.0},
#  'he hastened to': {'hastened to the': 0.5, 'hastened to paris': 0.5},
#  'hastened to the': {'to the house': 1.0},
#  'to the house': {'the house which': 0.6666666666666666,
#   'the house about': 0.3333333333333333},
#  'the house which': {'house which was': 0.5, 'house which i': 0.5},
#  'house which was': {'which was situated': 1.0},
#  'which was situated': {'was situated in': 1.0},
#  'was situated in': {'situated in a': 1.0},
#  'situated in a': {'in a mean': 1.0},
#  'in a mean': {'a mean street': 1.0},
#  'a mean street': {'mean street near': 1.0},
#  'mean street near': {'street near the': 1.0},
#  'street near the': {'near the but': 1.0},
#  'near the but': {'the but when': 1.0},
#  'the but when': {'but when he': 1.0},
#  'but when he': {'when he entered': 0.25,
#   'when he spoke': 0.25,
#   'when he observed': 0.25,
#   'when he was': 0.25},
#  'when he entered': {'he entered misery': 1.0},
#  'he entered misery': {'entered misery and': 1.0},
#  'entered misery and': {'misery and despair': 1.0},
#  'misery and despair': {'and despair alone': 1.0},
#  'and despair alone': {'despair alone welcomed': 1.0},
#  'despair alone welcomed': {'alone welcomed beaufort': 1.0},
#  'alone welcomed beaufort': {'welcomed beaufort had': 1.0},
#  'welcomed beaufort had': {'beaufort had saved': 1.0},
#  'beaufort had saved': {'had saved but': 1.0},
#  'had saved but': {'saved but a': 1.0},
#  'saved but a': {'but a very': 1.0},
#  'but a very': {'a very small': 0.5, 'a very sorry': 0.5},
#  'a very small': {'very small sum': 1.0},
#  'very small sum': {'small sum of': 1.0},
#  'small sum of': {'sum of money': 1.0},
#  'sum of money': {'of money from': 0.3333333333333333,
#   'of money she': 0.3333333333333333,
#   'of money together': 0.3333333333333333},
#  'of money from': {'money from the': 1.0},
#  'money from the': {'from the wreck': 1.0},
#  'from the wreck': {'the wreck of': 1.0},
#  'the wreck of': {'wreck of his': 1.0},
#  'wreck of his': {'of his fortunes': 1.0},
#  'of his fortunes': {'his fortunes but': 1.0},
#  'his fortunes but': {'fortunes but it': 1.0},
#  'fortunes but it': {'but it was': 1.0},
#  'but it was': {'it was sufficient': 0.09090909090909091,
#   'it was ineffectual': 0.09090909090909091,
#   'it was in': 0.09090909090909091,
#   'it was allied': 0.09090909090909091,
#   'it was excited': 0.09090909090909091,
#   'it was augmented': 0.09090909090909091,
#   'it was dry': 0.09090909090909091,
#   'it was wholesome': 0.09090909090909091,
#   'it was all': 0.09090909090909091,
#   'it was agreed': 0.09090909090909091,
#   'it was not': 0.09090909090909091},
#  'it was sufficient': {'was sufficient to': 1.0},
#  'was sufficient to': {'sufficient to provide': 1.0},
#  'sufficient to provide': {'to provide him': 1.0},
#  'to provide him': {'provide him with': 1.0},
#  'provide him with': {'him with sustenance': 1.0},
#  'him with sustenance': {'with sustenance for': 1.0},
#  'with sustenance for': {'sustenance for some': 1.0},
#  'sustenance for some': {'for some months': 1.0},
#  'for some months': {'some months and': 0.5, 'some months longer': 0.5},
#  'some months and': {'months and in': 1.0},
#  'months and in': {'and in the': 1.0},
#  'and in the': {'in the meantime': 0.3,
#   'in the tenth': 0.1,
#   'in the majestic': 0.1,
#   'in the bitterness': 0.1,
#   'in the general': 0.1,
#   'in the afternoon': 0.1,
#   'in the views': 0.1,
#   'in the bustle': 0.1},
#  'in the meantime': {'the meantime he': 0.3333333333333333,
#   'the meantime been': 0.1111111111111111,
#   'the meantime took': 0.1111111111111111,
#   'the meantime i': 0.2222222222222222,
#   'the meantime for': 0.1111111111111111,
#   'the meantime overjoyed': 0.1111111111111111},
#  'the meantime he': {'meantime he hoped': 0.3333333333333333,
#   'meantime he enjoyed': 0.3333333333333333,
#   'meantime he told': 0.3333333333333333},
#  'meantime he hoped': {'he hoped to': 1.0},
#  'he hoped to': {'hoped to procure': 1.0},
#  'hoped to procure': {'to procure some': 1.0},
#  'to procure some': {'procure some respectable': 1.0},
#  'procure some respectable': {'some respectable employment': 1.0},
#  'some respectable employment': {'respectable employment in': 1.0},
#  'respectable employment in': {'employment in a': 1.0},
#  'employment in a': {'in a merchants': 1.0},
#  'in a merchants': {'a merchants the': 1.0},
#  'a merchants the': {'merchants the interval': 1.0},
#  'merchants the interval': {'the interval was': 1.0},
#  'the interval was': {'interval was consequently': 1.0},
#  'interval was consequently': {'was consequently spent': 1.0},
#  'was consequently spent': {'consequently spent in': 1.0},
#  'consequently spent in': {'spent in inaction': 1.0},
#  'spent in inaction': {'in inaction his': 1.0},
#  'in inaction his': {'inaction his grief': 1.0},
#  'inaction his grief': {'his grief only': 1.0},
#  'his grief only': {'grief only became': 1.0},
#  'grief only became': {'only became more': 1.0},
#  'only became more': {'became more deep': 1.0},
#  'became more deep': {'more deep and': 1.0},
#  'more deep and': {'deep and rankling': 1.0},
#  'deep and rankling': {'and rankling when': 1.0},
#  'and rankling when': {'rankling when he': 1.0},
#  'rankling when he': {'when he had': 1.0},
#  'when he had': {'he had leisure': 0.5, 'he had pronounced': 0.5},
#  'he had leisure': {'had leisure for': 1.0},
#  'had leisure for': {'leisure for reflection': 1.0},
#  'leisure for reflection': {'for reflection and': 1.0},
#  'for reflection and': {'reflection and at': 1.0},
#  'reflection and at': {'and at length': 1.0},
#  'and at length': {'at length it': 0.25,
#   'at length the': 0.25,
#   'at length discovered': 0.25,
#   'at length exhausted': 0.25},
#  'at length it': {'length it took': 1.0},
#  'length it took': {'it took so': 1.0},
#  'it took so': {'took so fast': 1.0},
#  'took so fast': {'so fast hold': 1.0},
#  'so fast hold': {'fast hold of': 1.0},
#  'fast hold of': {'hold of his': 1.0},
#  'hold of his': {'of his mind': 1.0},
#  'of his mind': {'his mind that': 0.5, 'his mind on': 0.5},
#  'his mind that': {'mind that at': 1.0},
#  'mind that at': {'that at the': 1.0},
#  'that at the': {'at the end': 1.0},
#  'at the end': {'the end of': 1.0},
#  'the end of': {'end of three': 0.2,
#   'end of two': 0.2,
#   'end of my': 0.4,
#   'end of i': 0.2},
#  'end of three': {'of three months': 1.0},
#  'of three months': {'three months he': 1.0},
#  'three months he': {'months he lay': 1.0},
#  'months he lay': {'he lay on': 1.0},
#  'he lay on': {'lay on a': 1.0},
#  'lay on a': {'on a bed': 1.0},
#  'on a bed': {'a bed of': 0.5, 'a bed hardly': 0.5},
#  'a bed of': {'bed of sickness': 1.0},
#  'bed of sickness': {'of sickness incapable': 1.0},
#  'of sickness incapable': {'sickness incapable of': 1.0},
#  'sickness incapable of': {'incapable of any': 1.0},
#  'incapable of any': {'of any exertion': 0.3333333333333333,
#   'of any severity': 0.3333333333333333,
#   'of any i': 0.3333333333333333},
#  'of any exertion': {'any exertion his': 1.0},
#  'any exertion his': {'exertion his daughter': 1.0},
#  'exertion his daughter': {'his daughter attended': 1.0},
#  'his daughter attended': {'daughter attended him': 1.0},
#  'daughter attended him': {'attended him with': 1.0},
#  'attended him with': {'him with the': 1.0},
#  'him with the': {'with the greatest': 1.0},
#  'with the greatest': {'the greatest tenderness': 0.2,
#   'the greatest when': 0.2,
#   'the greatest diligence': 0.2,
#   'the greatest your': 0.2,
#   'the greatest affection': 0.2},
#  'the greatest tenderness': {'greatest tenderness but': 1.0},
#  'greatest tenderness but': {'tenderness but she': 1.0},
#  'tenderness but she': {'but she saw': 1.0},
#  'but she saw': {'she saw with': 1.0},
#  'she saw with': {'saw with despair': 1.0},
#  'saw with despair': {'with despair that': 1.0},
#  'with despair that': {'despair that their': 1.0},
#  'despair that their': {'that their little': 1.0},
#  'that their little': {'their little fund': 1.0},
#  'their little fund': {'little fund was': 1.0},
#  'little fund was': {'fund was rapidly': 1.0},
#  'fund was rapidly': {'was rapidly decreasing': 1.0},
#  'was rapidly decreasing': {'rapidly decreasing and': 1.0},
#  'rapidly decreasing and': {'decreasing and that': 1.0},
#  'decreasing and that': {'and that there': 1.0},
#  'and that there': {'that there was': 1.0},
#  'that there was': {'there was no': 0.3333333333333333,
#   'there was but': 0.3333333333333333,
#   'there was some': 0.3333333333333333},
#  'there was no': {'was no other': 0.5, 'was no sign': 0.5},
#  'was no other': {'no other prospect': 1.0},
#  'no other prospect': {'other prospect of': 1.0},
#  'other prospect of': {'prospect of but': 1.0},
#  'prospect of but': {'of but caroline': 1.0},
#  'of but caroline': {'but caroline beaufort': 1.0},
#  'but caroline beaufort': {'caroline beaufort possessed': 1.0},
#  'caroline beaufort possessed': {'beaufort possessed a': 1.0},
#  'beaufort possessed a': {'possessed a mind': 1.0},
#  'possessed a mind': {'a mind of': 1.0},
#  'a mind of': {'mind of an': 0.5, 'mind of moderate': 0.5},
#  'mind of an': {'of an uncommon': 1.0},
#  'of an uncommon': {'an uncommon mould': 1.0},
#  'an uncommon mould': {'uncommon mould and': 1.0},
#  'uncommon mould and': {'mould and her': 1.0},
#  'mould and her': {'and her courage': 1.0},
#  'and her courage': {'her courage rose': 1.0},
#  'her courage rose': {'courage rose to': 1.0},
#  'courage rose to': {'rose to support': 1.0},
#  'rose to support': {'to support her': 1.0},
#  'to support her': {'support her in': 1.0},
#  'support her in': {'her in her': 1.0},
#  'her in her': {'in her she': 1.0},
#  'in her she': {'her she procured': 0.3333333333333333,
#   'her she sometimes': 0.3333333333333333,
#   'her she was': 0.3333333333333333},
#  'her she procured': {'she procured plain': 1.0},
#  'she procured plain': {'procured plain work': 1.0},
#  'procured plain work': {'plain work she': 1.0},
#  'plain work she': {'work she plaited': 1.0},
#  'work she plaited': {'she plaited straw': 1.0},
#  'she plaited straw': {'plaited straw and': 1.0},
#  'plaited straw and': {'straw and by': 1.0},
#  'straw and by': {'and by various': 1.0},
#  'and by various': {'by various means': 1.0},
#  'by various means': {'various means contrived': 1.0},
#  'various means contrived': {'means contrived to': 1.0},
#  'means contrived to': {'contrived to earn': 1.0},
#  'contrived to earn': {'to earn a': 1.0},
#  'to earn a': {'earn a pittance': 1.0},
#  'earn a pittance': {'a pittance scarcely': 1.0},
#  'a pittance scarcely': {'pittance scarcely sufficient': 1.0},
#  'pittance scarcely sufficient': {'scarcely sufficient to': 1.0},
#  'scarcely sufficient to': {'sufficient to support': 1.0},
#  'sufficient to support': {'to support life': 1.0},
#  'to support life': {'support life several': 1.0},
#  'support life several': {'life several months': 1.0},
#  'life several months': {'several months passed': 1.0},
#  'several months passed': {'months passed in': 1.0},
#  'months passed in': {'passed in this': 1.0},
#  'passed in this': {'in this her': 0.5, 'in this manner': 0.5},
#  'in this her': {'this her father': 1.0},
#  'this her father': {'her father grew': 1.0},
#  'her father grew': {'father grew worse': 1.0},
#  'father grew worse': {'grew worse her': 1.0},
#  'grew worse her': {'worse her time': 1.0},
#  'worse her time': {'her time was': 1.0},
#  'her time was': {'time was more': 1.0},
#  'time was more': {'was more entirely': 1.0},
#  'was more entirely': {'more entirely occupied': 1.0},
#  'more entirely occupied': {'entirely occupied in': 1.0},
#  'entirely occupied in': {'occupied in attending': 1.0},
#  'occupied in attending': {'in attending him': 1.0},
#  'in attending him': {'attending him her': 1.0},
#  'attending him her': {'him her means': 1.0},
#  'him her means': {'her means of': 1.0},
#  'her means of': {'means of subsistence': 1.0},
#  'means of subsistence': {'of subsistence decreased': 1.0},
#  'of subsistence decreased': {'subsistence decreased and': 1.0},
#  'subsistence decreased and': {'decreased and in': 1.0},
#  'decreased and in': {'and in the': 1.0},
#  'in the tenth': {'the tenth month': 1.0},
#  'the tenth month': {'tenth month her': 1.0},
#  'tenth month her': {'month her father': 1.0},
#  'month her father': {'her father died': 1.0},
#  'her father died': {'father died in': 1.0},
#  'father died in': {'died in her': 1.0},
#  'died in her': {'in her arms': 1.0},
#  'in her arms': {'her arms leaving': 1.0},
#  'her arms leaving': {'arms leaving her': 1.0},
#  'arms leaving her': {'leaving her an': 1.0},
#  'leaving her an': {'her an orphan': 1.0},
#  'her an orphan': {'an orphan and': 1.0},
#  'an orphan and': {'orphan and a': 1.0},
#  'orphan and a': {'and a this': 0.5, 'and a she': 0.5},
#  'and a this': {'a this last': 1.0},
#  'a this last': {'this last blow': 1.0},
#  'this last blow': {'last blow overcame': 1.0},
#  'last blow overcame': {'blow overcame her': 1.0},
#  'blow overcame her': {'overcame her and': 1.0},
#  'overcame her and': {'her and she': 1.0},
#  'her and she': {'and she knelt': 0.5, 'and she awoke': 0.5},
#  'and she knelt': {'she knelt by': 1.0},
#  'she knelt by': {'knelt by beauforts': 1.0},
#  'knelt by beauforts': {'by beauforts coffin': 1.0},
#  'by beauforts coffin': {'beauforts coffin weeping': 1.0},
#  'beauforts coffin weeping': {'coffin weeping bitterly': 1.0},
#  'coffin weeping bitterly': {'weeping bitterly when': 1.0},
#  'weeping bitterly when': {'bitterly when my': 1.0},
#  'bitterly when my': {'when my father': 1.0},
#  'when my father': {'my father entered': 0.3333333333333333,
#   'my father had': 0.3333333333333333,
#   'my father returned': 0.3333333333333333},
#  'my father entered': {'father entered the': 0.5, 'father entered it': 0.5},
#  'father entered the': {'entered the he': 1.0},
#  'entered the he': {'the he came': 1.0},
#  'the he came': {'he came like': 1.0},
#  'he came like': {'came like a': 1.0},
#  'came like a': {'like a protecting': 1.0},
#  'like a protecting': {'a protecting spirit': 1.0},
#  'a protecting spirit': {'protecting spirit to': 1.0},
#  'protecting spirit to': {'spirit to the': 1.0},
#  'spirit to the': {'to the poor': 0.5, 'to the conversations': 0.5},
#  'to the poor': {'the poor girl': 1.0},
#  'the poor girl': {'poor girl who': 0.3333333333333333,
#   'poor girl confirmed': 0.3333333333333333,
#   'poor girl died': 0.3333333333333333},
#  'poor girl who': {'girl who committed': 1.0},
#  'girl who committed': {'who committed herself': 1.0},
#  'who committed herself': {'committed herself to': 1.0},
#  'committed herself to': {'herself to his': 1.0},
#  'herself to his': {'to his care': 1.0},
#  'to his care': {'his care and': 1.0},
#  'his care and': {'care and after': 1.0},
#  'care and after': {'and after the': 1.0},
#  'and after the': {'after the interment': 0.25,
#   'after the death': 0.25,
#   'after the advocate': 0.25,
#   'after the usual': 0.25},
#  'after the interment': {'the interment of': 1.0},
#  'the interment of': {'interment of his': 1.0},
#  'interment of his': {'of his friend': 1.0},
#  'of his friend': {'his friend he': 1.0},
#  'his friend he': {'friend he conducted': 1.0},
#  'friend he conducted': {'he conducted her': 1.0},
#  'he conducted her': {'conducted her to': 1.0},
#  'conducted her to': {'her to geneva': 1.0},
#  'her to geneva': {'to geneva and': 1.0},
#  'to geneva and': {'geneva and placed': 0.5, 'geneva and i': 0.5},
#  'geneva and placed': {'and placed her': 1.0},
#  'and placed her': {'placed her under': 1.0},
#  'placed her under': {'her under the': 1.0},
#  'her under the': {'under the protection': 1.0},
#  'under the protection': {'the protection of': 1.0},
#  'the protection of': {'protection of a': 0.5, 'protection of some': 0.5},
#  'protection of a': {'of a two': 1.0},
#  'of a two': {'a two years': 1.0},
#  'a two years': {'two years after': 1.0},
#  'two years after': {'years after this': 1.0},
#  'years after this': {'after this event': 1.0},
#  'after this event': {'this event caroline': 1.0},
#  'this event caroline': {'event caroline became': 1.0},
#  'event caroline became': {'caroline became his': 1.0},
#  'caroline became his': {'became his wife': 1.0},
#  'became his wife': {'his wife there': 1.0},
#  'his wife there': {'wife there was': 1.0},
#  'wife there was': {'there was a': 1.0},
#  'there was a': {'was a considerable': 0.16666666666666666,
#   'was a sense': 0.16666666666666666,
#   'was a show': 0.16666666666666666,
#   'was a certain': 0.16666666666666666,
#   'was a task': 0.16666666666666666,
#   'was a frenzy': 0.16666666666666666},
#  'was a considerable': {'a considerable difference': 1.0},
#  'a considerable difference': {'considerable difference between': 1.0},
#  'considerable difference between': {'difference between the': 1.0},
#  'difference between the': {'between the ages': 1.0},
#  'between the ages': {'the ages of': 1.0},
#  'the ages of': {'ages of my': 1.0},
#  'ages of my': {'of my parents': 1.0},
#  'of my parents': {'my parents but': 0.3333333333333333,
#   'my parents house': 0.3333333333333333,
#   'my parents were': 0.3333333333333333},
#  'my parents but': {'parents but this': 1.0},
#  'parents but this': {'but this circumstance': 1.0},
#  'but this circumstance': {'this circumstance seemed': 1.0},
#  'this circumstance seemed': {'circumstance seemed to': 1.0},
#  'circumstance seemed to': {'seemed to unite': 1.0},
#  'seemed to unite': {'to unite them': 1.0},
#  'to unite them': {'unite them only': 1.0},
#  'unite them only': {'them only closer': 1.0},
#  'them only closer': {'only closer in': 1.0},
#  'only closer in': {'closer in bonds': 1.0},
#  'closer in bonds': {'in bonds of': 1.0},
#  'in bonds of': {'bonds of devoted': 1.0},
#  'bonds of devoted': {'of devoted there': 1.0},
#  'of devoted there': {'devoted there was': 1.0},
#  'devoted there was': {'there was a': 1.0},
#  'was a sense': {'a sense of': 1.0},
#  'a sense of': {'sense of justice': 0.3333333333333333,
#   'sense of mortal': 0.3333333333333333,
#   'sense of security': 0.3333333333333333},
#  'sense of justice': {'of justice in': 1.0},
#  'of justice in': {'justice in my': 1.0},
#  'justice in my': {'in my fathers': 1.0},
#  'in my fathers': {'my fathers upright': 0.5, 'my fathers house': 0.5},
#  'my fathers upright': {'fathers upright mind': 1.0},
#  'fathers upright mind': {'upright mind which': 1.0},
#  'upright mind which': {'mind which rendered': 1.0},
#  'mind which rendered': {'which rendered it': 1.0},
#  'which rendered it': {'rendered it necessary': 1.0},
#  'rendered it necessary': {'it necessary that': 1.0},
#  'it necessary that': {'necessary that he': 1.0},
#  'necessary that he': {'that he should': 1.0},
#  'that he should': {'he should approve': 0.3333333333333333,
#   'he should speedily': 0.3333333333333333,
#   'he should live': 0.3333333333333333},
#  'he should approve': {'should approve highly': 1.0},
#  'should approve highly': {'approve highly to': 1.0},
#  'approve highly to': {'highly to love': 1.0},
#  'highly to love': {'to love perhaps': 1.0},
#  'to love perhaps': {'love perhaps during': 1.0},
#  'love perhaps during': {'perhaps during former': 1.0},
#  'perhaps during former': {'during former years': 1.0},
#  'during former years': {'former years he': 1.0},
#  'former years he': {'years he had': 1.0},
#  'years he had': {'he had suffered': 1.0},
#  'he had suffered': {'had suffered from': 1.0},
#  'had suffered from': {'suffered from the': 1.0},
#  'suffered from the': {'from the unworthiness': 1.0},
#  'from the unworthiness': {'the unworthiness of': 1.0},
#  'the unworthiness of': {'unworthiness of one': 1.0},
#  'unworthiness of one': {'of one beloved': 1.0},
#  'of one beloved': {'one beloved and': 1.0},
#  'one beloved and': {'beloved and so': 1.0},
#  'beloved and so': {'and so was': 1.0},
#  'and so was': {'so was disposed': 1.0},
#  'so was disposed': {'was disposed to': 1.0},
#  'was disposed to': {'disposed to set': 1.0},
#  'disposed to set': {'to set a': 1.0},
#  'to set a': {'set a greater': 0.5, 'set a crown': 0.5},
#  'set a greater': {'a greater value': 1.0},
#  'a greater value': {'greater value on': 1.0},
#  'greater value on': {'value on tried': 1.0},
#  'value on tried': {'on tried there': 1.0},
#  'on tried there': {'tried there was': 1.0},
#  'tried there was': {'there was a': 1.0},
#  'was a show': {'a show of': 1.0},
#  'a show of': {'show of gratitude': 1.0},
#  'show of gratitude': {'of gratitude and': 1.0},
#  'of gratitude and': {'gratitude and worship': 1.0},
#  'gratitude and worship': {'and worship in': 1.0},
#  'and worship in': {'worship in his': 1.0},
#  'worship in his': {'in his attachment': 1.0},
#  'in his attachment': {'his attachment to': 1.0},
#  'his attachment to': {'attachment to my': 1.0},
#  'attachment to my': {'to my mother': 1.0},
#  'to my mother': {'my mother differing': 0.3333333333333333,
#   'my mother was': 0.3333333333333333,
#   'my mother and': 0.3333333333333333},
#  'my mother differing': {'mother differing wholly': 1.0},
#  'mother differing wholly': {'differing wholly from': 1.0},
#  'differing wholly from': {'wholly from the': 1.0},
#  'wholly from the': {'from the doting': 1.0},
#  'from the doting': {'the doting fondness': 1.0},
#  'the doting fondness': {'doting fondness of': 1.0},
#  'doting fondness of': {'fondness of age': 1.0},
#  'fondness of age': {'of age for': 1.0},
#  'of age for': {'age for it': 1.0},
#  'age for it': {'for it was': 1.0},
#  'for it was': {'it was inspired': 0.25,
#   'it was the': 0.25,
#   'it was a': 0.25,
#   'it was by': 0.25},
#  'it was inspired': {'was inspired by': 1.0},
#  'was inspired by': {'inspired by reverence': 1.0},
#  'inspired by reverence': {'by reverence for': 1.0},
#  'by reverence for': {'reverence for her': 1.0},
#  'reverence for her': {'for her virtues': 1.0},
#  'for her virtues': {'her virtues and': 1.0},
#  'her virtues and': {'virtues and a': 1.0},
#  'virtues and a': {'and a desire': 1.0},
#  'and a desire': {'a desire to': 1.0},
#  'a desire to': {'desire to be': 0.3333333333333333,
#   'desire to see': 0.3333333333333333,
#   'desire to become': 0.3333333333333333},
#  'desire to be': {'to be the': 1.0},
#  'to be the': {'be the means': 0.125,
#   'be the world': 0.125,
#   'be the wanderings': 0.125,
#   'be the temptation': 0.125,
#   'be the murderer': 0.125,
#   'be the best': 0.125,
#   'be the elizabeth': 0.125,
#   'be the purport': 0.125},
#  'be the means': {'the means of': 1.0},
#  'the means of': {'means of in': 0.25,
#   'means of an': 0.25,
#   'means of obtaining': 0.25,
#   'means of materially': 0.25},
#  'means of in': {'of in some': 1.0},
#  'of in some': {'in some degree': 1.0},
#  'in some degree': {'some degree recompensing': 0.2,
#   'some degree consoled': 0.2,
#   'some degree also': 0.2,
#   'some degree beneficial': 0.2,
#   'some degree alarmed': 0.2},
#  'some degree recompensing': {'degree recompensing her': 1.0},
#  'degree recompensing her': {'recompensing her for': 1.0},
#  'recompensing her for': {'her for the': 1.0},
#  'her for the': {'for the sorrows': 1.0},
#  'for the sorrows': {'the sorrows she': 1.0},
#  'the sorrows she': {'sorrows she had': 1.0},
#  'sorrows she had': {'she had endured': 1.0},
#  'she had endured': {'had endured but': 1.0},
#  'had endured but': {'endured but which': 1.0},
#  'endured but which': {'but which gave': 1.0},
#  'but which gave': {'which gave inexpressible': 1.0},
#  'which gave inexpressible': {'gave inexpressible grace': 1.0},
#  'gave inexpressible grace': {'inexpressible grace to': 1.0},
#  'inexpressible grace to': {'grace to his': 1.0},
#  'grace to his': {'to his behaviour': 1.0},
#  'to his behaviour': {'his behaviour to': 1.0},
#  'his behaviour to': {'behaviour to everything': 1.0},
#  'behaviour to everything': {'to everything was': 1.0},
#  'to everything was': {'everything was made': 1.0},
#  'everything was made': {'was made to': 1.0},
#  'was made to': {'made to yield': 1.0},
#  'made to yield': {'to yield to': 1.0},
#  'to yield to': {'yield to her': 1.0},
#  'yield to her': {'to her wishes': 1.0},
#  'to her wishes': {'her wishes and': 1.0},
#  'her wishes and': {'wishes and her': 1.0},
#  'wishes and her': {'and her he': 1.0},
#  'and her he': {'her he strove': 1.0},
#  'her he strove': {'he strove to': 1.0},
#  'he strove to': {'strove to shelter': 1.0},
#  'strove to shelter': {'to shelter her': 1.0},
#  'to shelter her': {'shelter her as': 1.0},
#  'shelter her as': {'her as a': 1.0},
#  'her as a': {'as a fair': 1.0},
#  'as a fair': {'a fair exotic': 1.0},
#  'a fair exotic': {'fair exotic is': 1.0},
#  'fair exotic is': {'exotic is sheltered': 1.0},
#  'exotic is sheltered': {'is sheltered by': 1.0},
#  'is sheltered by': {'sheltered by the': 1.0},
#  'sheltered by the': {'by the gardener': 1.0},
#  'by the gardener': {'the gardener from': 1.0},
#  'the gardener from': {'gardener from every': 1.0},
#  'gardener from every': {'from every rougher': 1.0},
#  'from every rougher': {'every rougher wind': 1.0},
#  'every rougher wind': {'rougher wind and': 1.0},
#  'rougher wind and': {'wind and to': 1.0},
#  'wind and to': {'and to surround': 1.0},
#  'and to surround': {'to surround her': 1.0},
#  'to surround her': {'surround her with': 1.0},
#  'surround her with': {'her with all': 1.0},
#  'her with all': {'with all that': 1.0},
#  'with all that': {'all that could': 0.5, 'all that affection': 0.5},
#  'all that could': {'that could tend': 1.0},
#  'that could tend': {'could tend to': 1.0},
#  'could tend to': {'tend to excite': 1.0},
#  'tend to excite': {'to excite pleasurable': 1.0},
#  'to excite pleasurable': {'excite pleasurable emotion': 1.0},
#  'excite pleasurable emotion': {'pleasurable emotion in': 1.0},
#  'pleasurable emotion in': {'emotion in her': 1.0},
#  'emotion in her': {'in her soft': 1.0},
#  'in her soft': {'her soft and': 1.0},
#  'her soft and': {'soft and benevolent': 1.0},
#  'soft and benevolent': {'and benevolent her': 1.0},
#  'and benevolent her': {'benevolent her health': 1.0},
#  'benevolent her health': {'her health and': 1.0},
#  'her health and': {'health and even': 1.0},
#  'health and even': {'and even the': 1.0},
#  'and even the': {'even the tranquillity': 0.5, 'even the constant': 0.5},
#  'even the tranquillity': {'the tranquillity of': 1.0},
#  'the tranquillity of': {'tranquillity of her': 0.5,
#   'tranquillity of his': 0.5},
#  'tranquillity of her': {'of her hitherto': 1.0},
#  'of her hitherto': {'her hitherto constant': 1.0},
#  'her hitherto constant': {'hitherto constant spirit': 1.0},
#  'hitherto constant spirit': {'constant spirit had': 1.0},
#  'constant spirit had': {'spirit had been': 1.0},
#  'spirit had been': {'had been shaken': 1.0},
#  'had been shaken': {'been shaken by': 1.0},
#  'been shaken by': {'shaken by what': 1.0},
#  'shaken by what': {'by what she': 1.0},
#  'by what she': {'what she had': 1.0},
#  'what she had': {'she had gone': 0.5, 'she had suffered': 0.5},
#  'she had gone': {'had gone during': 0.5, 'had gone near': 0.5},
#  'had gone during': {'gone during the': 1.0},
#  'gone during the': {'during the two': 1.0},
#  'during the two': {'the two years': 1.0},
#  'the two years': {'two years that': 1.0},
#  'two years that': {'years that had': 1.0},
#  'years that had': {'that had elapsed': 1.0},
#  'that had elapsed': {'had elapsed previous': 1.0},
#  'had elapsed previous': {'elapsed previous to': 1.0},
#  'elapsed previous to': {'previous to their': 1.0},
#  'previous to their': {'to their marriage': 1.0},
#  'to their marriage': {'their marriage my': 1.0},
#  'their marriage my': {'marriage my father': 1.0},
#  'marriage my father': {'my father had': 1.0},
#  'father had gradually': {'had gradually relinquished': 1.0},
#  'had gradually relinquished': {'gradually relinquished all': 1.0},
#  'gradually relinquished all': {'relinquished all his': 1.0},
#  'relinquished all his': {'all his public': 1.0},
#  'all his public': {'his public functions': 1.0},
#  'his public functions': {'public functions and': 1.0},
#  'public functions and': {'functions and immediately': 1.0},
#  'functions and immediately': {'and immediately after': 1.0},
#  'and immediately after': {'immediately after their': 1.0},
#  'immediately after their': {'after their union': 1.0},
#  'after their union': {'their union they': 1.0},
#  'their union they': {'union they sought': 1.0},
#  'union they sought': {'they sought the': 1.0},
#  'they sought the': {'sought the pleasant': 1.0},
#  'sought the pleasant': {'the pleasant climate': 1.0},
#  'the pleasant climate': {'pleasant climate of': 1.0},
#  'pleasant climate of': {'climate of italy': 1.0},
#  'climate of italy': {'of italy and': 1.0},
#  'of italy and': {'italy and the': 1.0},
#  'italy and the': {'and the change': 1.0},
#  'and the change': {'the change of': 0.5, 'the change was': 0.5},
#  'the change of': {'change of scene': 1.0},
#  'change of scene': {'of scene and': 1.0},
#  'of scene and': {'scene and interest': 0.5, 'scene and varied': 0.5},
#  'scene and interest': {'and interest attendant': 1.0},
#  'and interest attendant': {'interest attendant on': 1.0},
#  'interest attendant on': {'attendant on a': 1.0},
#  'attendant on a': {'on a tour': 1.0},
#  'on a tour': {'a tour through': 1.0},
#  'a tour through': {'tour through that': 1.0},
#  'tour through that': {'through that land': 1.0},
#  'through that land': {'that land of': 1.0},
#  'that land of': {'land of wonders': 1.0},
#  'land of wonders': {'of wonders as': 1.0},
#  'of wonders as': {'wonders as a': 1.0},
#  'wonders as a': {'as a restorative': 1.0},
#  'as a restorative': {'a restorative for': 1.0},
#  'a restorative for': {'restorative for her': 1.0},
#  'restorative for her': {'for her weakened': 1.0},
#  'for her weakened': {'her weakened frame': 1.0},
#  'her weakened frame': {'weakened frame from': 1.0},
#  'weakened frame from': {'frame from italy': 1.0},
#  'frame from italy': {'from italy they': 1.0},
#  'from italy they': {'italy they visited': 1.0},
#  'italy they visited': {'they visited germany': 1.0},
#  'they visited germany': {'visited germany and': 1.0},
#  'visited germany and': {'germany and i': 1.0},
#  'germany and i': {'and i their': 1.0},
#  'and i their': {'i their eldest': 1.0},
#  'i their eldest': {'their eldest child': 1.0},
#  'their eldest child': {'eldest child was': 1.0},
#  'eldest child was': {'child was born': 0.5, 'child was but': 0.5},
#  'child was born': {'was born at': 1.0},
#  'was born at': {'born at naples': 1.0},
#  'born at naples': {'at naples and': 1.0},
#  'at naples and': {'naples and as': 1.0},
#  'naples and as': {'and as an': 1.0},
#  'and as an': {'as an infant': 1.0},
#  'as an infant': {'an infant accompanied': 1.0},
#  'an infant accompanied': {'infant accompanied them': 1.0},
#  'infant accompanied them': {'accompanied them in': 1.0},
#  'accompanied them in': {'them in their': 1.0},
#  'them in their': {'in their i': 0.5, 'in their cloudy': 0.5},
#  'in their i': {'their i remained': 0.5, 'their i saw': 0.5},
#  'their i remained': {'i remained for': 1.0},
#  'i remained for': {'remained for several': 1.0},
#  'remained for several': {'for several years': 1.0},
#  'for several years': {'several years their': 1.0},
#  'several years their': {'years their only': 1.0},
#  'years their only': {'their only much': 1.0},
#  'their only much': {'only much as': 1.0},
#  'only much as': {'much as they': 1.0},
#  'much as they': {'as they were': 1.0},
#  'as they were': {'they were attached': 0.3333333333333333,
#   'they were unfolded': 0.3333333333333333,
#   'they were as': 0.3333333333333333},
#  'they were attached': {'were attached to': 1.0},
#  'were attached to': {'attached to each': 1.0},
#  'attached to each': {'to each other': 1.0},
#  'to each other': {'each other they': 0.3333333333333333,
#   'each other here': 0.3333333333333333,
#   'each other from': 0.3333333333333333},
#  'each other they': {'other they seemed': 1.0},
#  'other they seemed': {'they seemed to': 1.0},
#  'they seemed to': {'seemed to draw': 1.0},
#  'seemed to draw': {'to draw inexhaustible': 1.0},
#  'to draw inexhaustible': {'draw inexhaustible stores': 1.0},
#  'draw inexhaustible stores': {'inexhaustible stores of': 1.0},
#  'inexhaustible stores of': {'stores of affection': 1.0},
#  'stores of affection': {'of affection from': 1.0},
#  'of affection from': {'affection from a': 0.5, 'affection from thine': 0.5},
#  'affection from a': {'from a very': 1.0},
#  'from a very': {'a very mine': 1.0},
#  'a very mine': {'very mine of': 1.0},
#  'very mine of': {'mine of love': 1.0},
#  'mine of love': {'of love to': 1.0},
#  'of love to': {'love to bestow': 0.5, 'love to soften': 0.5},
#  'love to bestow': {'to bestow them': 1.0},
#  'to bestow them': {'bestow them upon': 1.0},
#  'bestow them upon': {'them upon my': 1.0},
#  'them upon my': {'upon my mothers': 1.0},
#  'upon my mothers': {'my mothers tender': 1.0},
#  'my mothers tender': {'mothers tender caresses': 1.0},
#  'mothers tender caresses': {'tender caresses and': 1.0},
#  'tender caresses and': {'caresses and my': 1.0},
#  'caresses and my': {'and my fathers': 1.0},
#  'and my fathers': {'my fathers smile': 0.5, 'my fathers woe': 0.5},
#  'my fathers smile': {'fathers smile of': 1.0},
#  'fathers smile of': {'smile of benevolent': 1.0},
#  'smile of benevolent': {'of benevolent pleasure': 1.0},
#  'of benevolent pleasure': {'benevolent pleasure while': 1.0},
#  'benevolent pleasure while': {'pleasure while regarding': 1.0},
#  'pleasure while regarding': {'while regarding me': 1.0},
#  'while regarding me': {'regarding me are': 1.0},
#  'regarding me are': {'me are my': 1.0},
#  'me are my': {'are my first': 1.0},
#  'are my first': {'my first i': 1.0},
#  'my first i': {'first i was': 1.0},
#  'first i was': {'i was their': 0.5, 'i was unable': 0.5},
#  'i was their': {'was their plaything': 0.5, 'was their only': 0.5},
#  'was their plaything': {'their plaything and': 1.0},
#  'their plaything and': {'plaything and their': 1.0},
#  'plaything and their': {'and their idol': 1.0},
#  'and their idol': {'their idol and': 1.0},
#  'their idol and': {'idol and something': 1.0},
#  'idol and something': {'and something better': 1.0},
#  'and something better': {'something better their': 1.0},
#  'something better their': {'better their child': 1.0},
#  'better their child': {'their child the': 1.0},
#  'their child the': {'child the innocent': 1.0},
#  'child the innocent': {'the innocent and': 1.0},
#  'the innocent and': {'innocent and helpless': 1.0},
#  'innocent and helpless': {'and helpless creature': 1.0},
#  'and helpless creature': {'helpless creature bestowed': 1.0},
#  'helpless creature bestowed': {'creature bestowed on': 1.0},
#  'creature bestowed on': {'bestowed on them': 1.0},
#  'bestowed on them': {'on them by': 1.0},
#  'on them by': {'them by heaven': 1.0},
#  'them by heaven': {'by heaven whom': 1.0},
#  'by heaven whom': {'heaven whom to': 1.0},
#  'heaven whom to': {'whom to bring': 1.0},
#  'whom to bring': {'to bring up': 1.0},
#  'to bring up': {'bring up to': 1.0},
#  'bring up to': {'up to good': 1.0},
#  'up to good': {'to good and': 1.0},
#  'to good and': {'good and whose': 1.0},
#  'good and whose': {'and whose future': 1.0},
#  'and whose future': {'whose future lot': 1.0},
#  'whose future lot': {'future lot it': 1.0},
#  'future lot it': {'lot it was': 1.0},
#  'lot it was': {'it was in': 1.0},
#  'it was in': {'was in their': 0.2,
#   'was in vain': 0.2,
#   'was in my': 0.4,
#   'was in the': 0.2},
#  'was in their': {'in their hands': 1.0},
#  'in their hands': {'their hands to': 1.0},
#  'their hands to': {'hands to direct': 1.0},
#  'hands to direct': {'to direct to': 1.0},
#  'to direct to': {'direct to happiness': 1.0},
#  'direct to happiness': {'to happiness or': 1.0},
#  'to happiness or': {'happiness or misery': 1.0},
#  'happiness or misery': {'or misery according': 1.0},
#  'or misery according': {'misery according as': 1.0},
#  'misery according as': {'according as they': 1.0},
#  'according as they': {'as they fulfilled': 1.0},
#  'as they fulfilled': {'they fulfilled their': 1.0},
#  'they fulfilled their': {'fulfilled their duties': 1.0},
#  'fulfilled their duties': {'their duties towards': 1.0},
#  'their duties towards': {'duties towards with': 1.0},
#  'duties towards with': {'towards with this': 1.0},
#  'towards with this': {'with this deep': 1.0},
#  'with this deep': {'this deep consciousness': 1.0},
#  'this deep consciousness': {'deep consciousness of': 1.0},
#  'deep consciousness of': {'consciousness of what': 1.0},
#  'consciousness of what': {'of what they': 1.0},
#  'of what they': {'what they owed': 1.0},
#  'what they owed': {'they owed towards': 1.0},
#  'they owed towards': {'owed towards the': 1.0},
#  'owed towards the': {'towards the being': 1.0},
#  'towards the being': {'the being to': 1.0},
#  'the being to': {'being to which': 0.5, 'being to whom': 0.5},
#  'being to which': {'to which they': 1.0},
#  'to which they': {'which they had': 1.0},
#  'which they had': {'they had given': 0.5, 'they had lived': 0.5},
#  'they had given': {'had given life': 1.0},
#  'had given life': {'given life added': 1.0},
#  'given life added': {'life added to': 1.0},
#  'life added to': {'added to the': 1.0},
#  'added to the': {'to the active': 0.5, 'to the melancholy': 0.5},
#  'to the active': {'the active spirit': 1.0},
#  'the active spirit': {'active spirit of': 1.0},
#  'active spirit of': {'spirit of tenderness': 1.0},
#  'spirit of tenderness': {'of tenderness that': 1.0},
#  'of tenderness that': {'tenderness that animated': 1.0},
#  'tenderness that animated': {'that animated both': 1.0},
#  'that animated both': {'animated both it': 1.0},
#  'animated both it': {'both it may': 1.0},
#  'both it may': {'it may be': 1.0},
#  'it may be': {'may be imagined': 0.25,
#   'may be deemed': 0.25,
#   'may be easily': 0.25,
#   'may be called': 0.25},
#  'may be imagined': {'be imagined that': 1.0},
#  'be imagined that': {'imagined that while': 1.0},
#  'imagined that while': {'that while during': 1.0},
#  'that while during': {'while during every': 1.0},
#  'while during every': {'during every hour': 1.0},
#  'during every hour': {'every hour of': 1.0},
#  'every hour of': {'hour of my': 1.0},
#  'hour of my': {'of my infant': 0.5, 'of my irresolution': 0.5},
#  'of my infant': {'my infant life': 1.0},
#  'my infant life': {'infant life i': 1.0},
#  'infant life i': {'life i received': 1.0},
#  'life i received': {'i received a': 1.0},
#  'i received a': {'received a lesson': 1.0},
#  'received a lesson': {'a lesson of': 1.0},
#  'a lesson of': {'lesson of patience': 1.0},
#  'lesson of patience': {'of patience of': 1.0},
#  'of patience of': {'patience of charity': 1.0},
#  'patience of charity': {'of charity and': 1.0},
#  'of charity and': {'charity and of': 1.0},
#  'charity and of': {'and of i': 1.0},
#  'and of i': {'of i was': 1.0},
#  'of i was': {'i was so': 0.16666666666666666,
#   'i was new': 0.16666666666666666,
#   'i was troubled': 0.16666666666666666,
#   'i was a': 0.16666666666666666,
#   'i was besides': 0.16666666666666666,
#   'i was nourished': 0.16666666666666666},
#  'i was so': {'was so guided': 0.5, 'was so frightful': 0.5},
#  'was so guided': {'so guided by': 1.0},
#  'so guided by': {'guided by a': 1.0},
#  'guided by a': {'by a silken': 0.5, 'by a slight': 0.5},
#  'by a silken': {'a silken cord': 1.0},
#  'a silken cord': {'silken cord that': 1.0},
#  'silken cord that': {'cord that all': 1.0},
#  'cord that all': {'that all seemed': 1.0},
#  'that all seemed': {'all seemed but': 1.0},
#  'all seemed but': {'seemed but one': 1.0},
#  'seemed but one': {'but one train': 1.0},
#  'but one train': {'one train of': 1.0},
#  'one train of': {'train of enjoyment': 1.0},
#  'train of enjoyment': {'of enjoyment to': 1.0},
#  'of enjoyment to': {'enjoyment to for': 1.0},
#  'enjoyment to for': {'to for a': 1.0},
#  'to for a': {'for a long': 1.0},
#  ...}

# %%
for i in range(6):
   print(str(i)+".\t", generate_text(MC4,start= 'genevese', limit=8))
# Out:
# 0.	 genevese
# 1.	 genevese
# 2.	 genevese
# 3.	 genevese
# 4.	 genevese
# 5.	 genevese

# %% [markdown]
# ## Generate text using NLP models

# %%
# pip install transformers

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# upload tokenizer GPT-2 pre-trained
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Definisci l'input
input_text = "I am by birth a Genevese; and my family is one of the most distinguished of that republic. My ancestors had been for many years counsellors and syndics; and my father had filled several public situations with honour and reputation. He was respected by all who knew him for his integrity and indefatigable attention to public business. He passed his younger days perpetually occupied by the affairs of his country; a variety of circumstances had prevented his marrying early, nor was it until the decline of life that he became a husband and the father of a family. As the circumstances of his marriage illustrate his character, I cannot refrain from relating them. One of his most intimate friends was a merchant, who, from a flourishing state, fell, through numerous mischances, into poverty. This man, whose name was Beaufort, was of a proud and unbending disposition, and could not bear to live in poverty and oblivion in the same country where he had formerly been distinguished for his rank and magnificence. Having paid his debts, therefore, in the most honourable manner, he retreated with his daughter to the town of Lucerne, where he lived unknown and in wretchedness. My father loved Beaufort with the truest friendship, and was deeply grieved by his retreat in these unfortunate circumstances. He bitterly deplored the false pride which led his friend to a conduct so little worthy of the affection that united them. He lost no time in endeavouring to seek him out, with the hope of persuading him to begin the world again through his credit and assistance."

# Tokenizza l'input
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Genera del testo basato sull'input
output = model.generate(input_ids, max_length=500, num_return_sequences=1, temperature=0.7, pad_token_id=tokenizer.eos_token_id)

# Decodifica il testo generato
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print("Testo generato:", generated_text)
# Out:
# Testo generato: I am by birth a Genevese; and my family is one of the most distinguished of that republic. My ancestors had been for many years counsellors and syndics; and my father had filled several public situations with honour and reputation. He was respected by all who knew him for his integrity and indefatigable attention to public business. He passed his younger days perpetually occupied by the affairs of his country; a variety of circumstances had prevented his marrying early, nor was it until the decline of life that he became a husband and the father of a family. As the circumstances of his marriage illustrate his character, I cannot refrain from relating them. One of his most intimate friends was a merchant, who, from a flourishing state, fell, through numerous mischances, into poverty. This man, whose name was Beaufort, was of a proud and unbending disposition, and could not bear to live in poverty and oblivion in the same country where he had formerly been distinguished for his rank and magnificence. Having paid his debts, therefore, in the most honourable manner, he retreated with his daughter to the town of Lucerne, where he lived unknown and in wretchedness. My father loved Beaufort with the truest friendship, and was deeply grieved by his retreat in these unfortunate circumstances. He bitterly deplored the false pride which led his friend to a conduct so little worthy of the affection that united them. He lost no time in endeavouring to seek him out, with the hope of persuading him to begin the world again through his credit and assistance. He was a man of great character, and a man of great character, and a man of great character, and a man of great character. He was a man of great character, and a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and a man of great character. He was a man of great character, and
